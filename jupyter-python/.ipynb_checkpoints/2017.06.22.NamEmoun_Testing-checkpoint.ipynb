# %%
import json
import pandas as pd

# %%
# open Data Organizer

#   how to select project or projects?
from DataOrganizer import CouchbaseSelector
# make this notebook script compaible with previous
ne1 = 'geotechnical'
db = CouchbaseSelector('localhost',ne1)

# %%
# query Data Organizer records for 'parameter' = E measured as Es

# initialize variables
nem_data_es=[]
# unsorted lists for checking
Es=[]
lithology=[]  
laboratory_test_code=[]
sample_depth=[]

parameter = 'E'
fields = ['borehole_code', 'lithology','laboratory', 'laboratory_test_code', 'sample_depth_top_m', 
          'value', 'value_unit']
selector = {'project_code': 'NEM', 'data_source': 'Laboratory', 'measurement_convention': 'Es'}
sort = ['borehole_code','sample_depth_top_m']
# db.setDebug(True)

# write selected fields to lists
for rec in db.get_parameter(parameter, fields, selector, sort):
    # print rec['borehole_code']
    # print rec 
    # write rec to nem_data_es   
    nem_data_es.append(rec)
    try:
        Es.append(rec['value'])
    except:
        print "check value data for E=", rec['value']
    try:
        lithology.append(rec['lithology'])
    except:
        print "check lithology data for E=", rec['value']
    try:
        laboratory_test_code.append(rec['laboratory_test_code'])
    except:
        print "check laboratory_test_code data for E=", rec['value']
    try:
        sample_depth.append(rec['sample_depth_top_m'])
    except:
        print "check sample_depth data for E=", rec['value']
    # there must be a more elegant way of checking that data exists                               Todo JK  
    # how to mark missing data as 'NaN'?

# %%
# sort data by sample_depth

##from operator import itemgetter

#nem_data_es_s = sorted(nem_data_es, key=lambda k: k['sample_depth_top_m']) 
##nem_data_es_s = sorted(nem_data_es, key=itemgetter('sample_depth_top_m'))

# %%
# data report
#   report should also provide count information (see below "reference from Alan")

# read nem_data_es into pandas data frame    
# nem_data_es_s_df = pd.DataFrame(data=nem_data_es_s)
nem_data_es_s_df = pd.DataFrame(data=nem_data_es)
#nem_data_df = nem_data_df.fillna('NaN').T

# display nem_data_df as html using pandas df.to_html()
from IPython.core.display import display, HTML
display(HTML('<h4>NEM data for Es </h4>'))
display(HTML(nem_data_es_s_df.to_html()))
# Out:
# <h4>NEM data for Es </h4>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>borehole_code</th>
#       <th>laboratory</th>
#       <th>laboratory_test_code</th>
#       <th>lithology</th>
#       <th>sample_depth_top_m</th>
#       <th>value</th>
#       <th>value_unit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>NE1-01</td>
#       <td>KhonKaen University</td>
#       <td>10</td>
#       <td>Diorite</td>
#       <td>22.80-23.10</td>
#       <td>12800</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>NE1-02</td>
#       <td>KhonKaen University</td>
#       <td>11</td>
#       <td>Diorite</td>
#       <td>19.80-20.00</td>
#       <td>18100</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NE1-02</td>
#       <td>KhonKaen University</td>
#       <td>12</td>
#       <td>Pegmatite</td>
#       <td>25.15-25.25</td>
#       <td>29700</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NE1-02</td>
#       <td>KhonKaen University</td>
#       <td>13</td>
#       <td>Diorite</td>
#       <td>28.80-28.90</td>
#       <td>18300</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>NE1-03</td>
#       <td>KhonKaen University</td>
#       <td>14</td>
#       <td>Pegmatite</td>
#       <td>19.50-19.60</td>
#       <td>5650</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>NE1-04</td>
#       <td>LTEC</td>
#       <td>26</td>
#       <td>Granodiorite</td>
#       <td>100.45-100.55</td>
#       <td>5769.2</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>NE1-04</td>
#       <td>LTEC</td>
#       <td>27</td>
#       <td>Granodiorite</td>
#       <td>24.1-24.25</td>
#       <td>2574.3</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>NE1-04</td>
#       <td>LTEC</td>
#       <td>28</td>
#       <td>Granodiorite</td>
#       <td>98.20-98.3</td>
#       <td>8076.9</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>NE1-07</td>
#       <td>KhonKaen University</td>
#       <td>15</td>
#       <td>Sandstone</td>
#       <td>28.00-28.25</td>
#       <td>14600</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>NE1-07</td>
#       <td>KhonKaen University</td>
#       <td>16</td>
#       <td>Sandstone</td>
#       <td>32.60-33.00</td>
#       <td>16800</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>NE1-07</td>
#       <td>KhonKaen University</td>
#       <td>17</td>
#       <td>Sandstone</td>
#       <td>32.60-33.00</td>
#       <td>13300</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>NE1-07</td>
#       <td>KhonKaen University</td>
#       <td>18</td>
#       <td>Sandstone</td>
#       <td>34.05-34.20</td>
#       <td>30500</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>NE1-07</td>
#       <td>KhonKaen University</td>
#       <td>19</td>
#       <td>Sandstone</td>
#       <td>44.80-45.00</td>
#       <td>22100</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>NE1-08</td>
#       <td>LTEC</td>
#       <td>31</td>
#       <td>Sericite</td>
#       <td>16.3-16.45</td>
#       <td>3891.9</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>NE1-08</td>
#       <td>LTEC</td>
#       <td>32</td>
#       <td>Sericite</td>
#       <td>24.25-25.37</td>
#       <td>6375</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>NE1-09</td>
#       <td>LTEC</td>
#       <td>29</td>
#       <td>Sericite</td>
#       <td>19.15-19.25</td>
#       <td>10769.2</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>NE1-09</td>
#       <td>LTEC</td>
#       <td>30</td>
#       <td>Sericite</td>
#       <td>23.45-23.55</td>
#       <td>8139.5</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>NE1-12</td>
#       <td>KhonKaen University</td>
#       <td>24</td>
#       <td>Granodiorite</td>
#       <td>33.40-33.50</td>
#       <td>21500</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>NE1-12</td>
#       <td>KhonKaen University</td>
#       <td>21</td>
#       <td>Granodiorite</td>
#       <td>34.05-34.20</td>
#       <td>15700</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>NE1-12</td>
#       <td>KhonKaen University</td>
#       <td>20</td>
#       <td>Granodiorite</td>
#       <td>46.75-46.85</td>
#       <td>30600</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>NE1-12</td>
#       <td>KhonKaen University</td>
#       <td>22</td>
#       <td>Granodiorite</td>
#       <td>87.15-87.25</td>
#       <td>19300</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>NE1-12</td>
#       <td>KhonKaen University</td>
#       <td>23</td>
#       <td>Diorite</td>
#       <td>99.80-99.90</td>
#       <td>14800</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>NE1-15</td>
#       <td>KhonKaen University</td>
#       <td>25</td>
#       <td>Diorite</td>
#       <td>29.40-29.50</td>
#       <td>19200</td>
#       <td>MPa</td>
#     </tr>
#   </tbody>
# </table>

# %%
# query Data Organizer records for 'parameter' = E measured as E50 and Et (appear to be same measurement)

# initialize variables
nem_data_e50=[]
# unsorted lists for checking
E50=[]
lithology=[]
laboratory_test_code=[]
sample_depth=[]

# query Data Organiser for E50 records
parameter = 'E'
fields = ['borehole_code','lithology','laboratory', 'laboratory_test_code', 'sample_depth_top_m', 
          'measurement_convention', 'value', 'value_unit']
selector = {'project_code': 'NEM', 'data_source': 'Laboratory'}
sort = ['borehole_code','sample_depth_top_m']

# write selected fields to lists

#records = []
#for rec in db.get_parameter(parameter, fields, selector, sort):
# if rec['measurement_convention'] != 'Es':
#   records.append(rec)


for rec in db.get_parameter(parameter, fields, selector, sort):
    if rec['measurement_convention'] != 'Es':
        # print rec
        # write rec to nem_data_e
        nem_data_e50.append(rec)

        
# query Data Organiser for Et records
##parameter = 'E'
##fields = ['lithology','laboratory', 'laboratory_test_code', 'sample_depth_top_m', 
##          'measurement_convention', 'value', 'value_unit']
##selector = {'project_code': 'NEM', 'data_source': 'Laboratory', 'measurement_convention': 'Et'}
##sort = ['borehole_code','sample_depth_top_m']

# write selected fields to lists
##for rec in db.get_parameter(parameter, fields, selector):
    # print rec
    # write rec to nem_data_e
##    nem_data_e50.append(rec)

print len(nem_data_e50)
# Out:
# 77

# %%
# sort data by sample_depth

##nem_data_e50_s = sorted(nem_data_e50, key=lambda k: k['sample_depth_top_m'])

# %%
# data report
#   report should also provide count information (see below "reference from Alan")

# read nem_data_e into pandas data frame    
nem_data_e50_s_df = pd.DataFrame(data=nem_data_e50)
#nem_data_df = nem_data_df.fillna('NaN').T

# display nem_data_df as html using pandas df.to_html()
from IPython.core.display import display, HTML
display(HTML('<h4>NEM data for E50 </h4>'))
display(HTML(nem_data_e50_s_df.to_html()))
# Out:
# <h4>NEM data for E50 </h4>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>borehole_code</th>
#       <th>laboratory</th>
#       <th>laboratory_test_code</th>
#       <th>lithology</th>
#       <th>measurement_convention</th>
#       <th>sample_depth_top_m</th>
#       <th>value</th>
#       <th>value_unit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>NE1-01</td>
#       <td>KhonKaen University</td>
#       <td>10</td>
#       <td>Diorite</td>
#       <td>E50</td>
#       <td>22.80-23.10</td>
#       <td>15850</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>NE1-02</td>
#       <td>KhonKaen University</td>
#       <td>11</td>
#       <td>Diorite</td>
#       <td>E50</td>
#       <td>19.80-20.00</td>
#       <td>24630</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NE1-02</td>
#       <td>KhonKaen University</td>
#       <td>12</td>
#       <td>Pegmatite</td>
#       <td>E50</td>
#       <td>25.15-25.25</td>
#       <td>52930</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NE1-02</td>
#       <td>KhonKaen University</td>
#       <td>13</td>
#       <td>Diorite</td>
#       <td>E50</td>
#       <td>28.80-28.90</td>
#       <td>21560</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>NE1-03</td>
#       <td>KhonKaen University</td>
#       <td>14</td>
#       <td>Pegmatite</td>
#       <td>E50</td>
#       <td>19.50-19.60</td>
#       <td>14460</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>NE1-04</td>
#       <td>LTEC</td>
#       <td>26</td>
#       <td>Granodiorite</td>
#       <td>Et</td>
#       <td>100.45-100.55</td>
#       <td>8475</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>NE1-04</td>
#       <td>LTEC</td>
#       <td>27</td>
#       <td>Granodiorite</td>
#       <td>Et</td>
#       <td>24.1-24.25</td>
#       <td>4799.2</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>NE1-04</td>
#       <td>LTEC</td>
#       <td>28</td>
#       <td>Granodiorite</td>
#       <td>Et</td>
#       <td>98.20-98.3</td>
#       <td>11968.7</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>NE1-07</td>
#       <td>KhonKaen University</td>
#       <td>15</td>
#       <td>Sandstone</td>
#       <td>E50</td>
#       <td>28.00-28.25</td>
#       <td>21290</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>NE1-07</td>
#       <td>KhonKaen University</td>
#       <td>16</td>
#       <td>Sandstone</td>
#       <td>E50</td>
#       <td>32.60-33.00</td>
#       <td>20800</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>NE1-07</td>
#       <td>KhonKaen University</td>
#       <td>17</td>
#       <td>Sandstone</td>
#       <td>E50</td>
#       <td>32.60-33.00</td>
#       <td>19170</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>NE1-07</td>
#       <td>KhonKaen University</td>
#       <td>18</td>
#       <td>Sandstone</td>
#       <td>E50</td>
#       <td>34.05-34.20</td>
#       <td>30450</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>NE1-07</td>
#       <td>KhonKaen University</td>
#       <td>19</td>
#       <td>Sandstone</td>
#       <td>E50</td>
#       <td>44.80-45.00</td>
#       <td>44310</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>NE1-08</td>
#       <td>LTEC</td>
#       <td>31</td>
#       <td>Sericite</td>
#       <td>Et</td>
#       <td>16.3-16.45</td>
#       <td>7963.4</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>NE1-08</td>
#       <td>LTEC</td>
#       <td>32</td>
#       <td>Sericite</td>
#       <td>Et</td>
#       <td>24.25-25.37</td>
#       <td>9053.3</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>NE1-09</td>
#       <td>LTEC</td>
#       <td>29</td>
#       <td>Sericite</td>
#       <td>Et</td>
#       <td>19.15-19.25</td>
#       <td>14813.1</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>NE1-09</td>
#       <td>LTEC</td>
#       <td>30</td>
#       <td>Sericite</td>
#       <td>Et</td>
#       <td>23.45-23.55</td>
#       <td>11893.5</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>NE1-12</td>
#       <td>KhonKaen University</td>
#       <td>24</td>
#       <td>Granodiorite</td>
#       <td>E50</td>
#       <td>33.40-33.50</td>
#       <td>29530</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>NE1-12</td>
#       <td>KhonKaen University</td>
#       <td>21</td>
#       <td>Granodiorite</td>
#       <td>E50</td>
#       <td>34.05-34.20</td>
#       <td>21790</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>NE1-12</td>
#       <td>KhonKaen University</td>
#       <td>20</td>
#       <td>Granodiorite</td>
#       <td>E50</td>
#       <td>46.75-46.85</td>
#       <td>71420</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>NE1-12</td>
#       <td>KhonKaen University</td>
#       <td>22</td>
#       <td>Granodiorite</td>
#       <td>E50</td>
#       <td>87.15-87.25</td>
#       <td>20940</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>NE1-12</td>
#       <td>KhonKaen University</td>
#       <td>23</td>
#       <td>Diorite</td>
#       <td>E50</td>
#       <td>99.80-99.90</td>
#       <td>19080</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>NE1-15</td>
#       <td>KhonKaen University</td>
#       <td>25</td>
#       <td>Diorite</td>
#       <td>E50</td>
#       <td>29.40-29.50</td>
#       <td>27420</td>
#       <td>MPa</td>
#     </tr>
#   </tbody>
# </table>

# %%
# query Data Organizer records for 'parameter' = sigma_c

# initialize variables
nem_data_sigma_c=[]
# unsorted lists for checking
sigma_c=[]
lithology=[]  
laboratory_test_code=[]
sample_depth=[]

parameter = 'sigma_c'
fields = ['borehole_code','lithology','laboratory', 'laboratory_test_code', 'sample_depth_top_m', 'value', 'value_unit']
selector = {'project_code': 'NEM', 'data_source': 'Laboratory'}
sort = ['borehole_code','sample_depth_top_m']

# write selected fields to lists
for rec in db.get_parameter(parameter, fields, selector, sort):
    # print rec 
    # write rec to nem_data_e   
    nem_data_sigma_c.append(rec)
    try:
        sigma_c.append(rec['value'])
    except:
        print "check value data for sigma_c=", rec['value']
    try:
        lithology.append(rec['lithology'])
    except:
        print "check lithology data for sigma_c=", rec['value']
    try:
        laboratory_test_code.append(rec['laboratory_test_code'])
    except:
        print "check laboratory_test_code data for sigma_c=", rec['value']
    try:
        sample_depth.append(rec['sample_depth_top_m'])
    except:
        print "check sample_depth data for sigma_c=", rec['value']

# %%
# sort data by sample_depth

##nem_data_sigma_c_s = sorted(nem_data_sigma_c, key=lambda k: k['sample_depth_top_m'])

# %%
# data report
#   report should also provide count information (see below "reference from Alan")

# read nem_data_e into pandas data frame    
#nem_data_sigma_c_s_df = pd.DataFrame(data=nem_data_sigma_c_s)#nem_data_df = nem_data_df.fillna('NaN').T
nem_data_sigma_c_s_df = pd.DataFrame(data=nem_data_sigma_c)#nem_data_df = nem_data_df.fillna('NaN').T

# display nem_data_df as html using pandas df.to_html()
from IPython.core.display import display, HTML
display(HTML('<h4>NEM data for sigma_c </h4>'))
display(HTML(nem_data_sigma_c_s_df.to_html()))
# Out:
# <h4>NEM data for sigma_c </h4>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>borehole_code</th>
#       <th>laboratory</th>
#       <th>laboratory_test_code</th>
#       <th>lithology</th>
#       <th>sample_depth_top_m</th>
#       <th>value</th>
#       <th>value_unit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>NE1-01</td>
#       <td>KhonKaen University</td>
#       <td>4</td>
#       <td>Diorite</td>
#       <td>13.45-13.55</td>
#       <td>93.13</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>NE1-01</td>
#       <td>KhonKaen University</td>
#       <td>5</td>
#       <td>Diorite</td>
#       <td>13.55-13.65</td>
#       <td>223.71</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NE1-01</td>
#       <td>KhonKaen University</td>
#       <td>6</td>
#       <td>Diorite</td>
#       <td>13.75-13.85</td>
#       <td>175.22</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NE1-01</td>
#       <td>KhonKaen University</td>
#       <td>10</td>
#       <td>Diorite</td>
#       <td>22.80-23.10</td>
#       <td>84.78</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>NE1-02</td>
#       <td>KhonKaen University</td>
#       <td>11</td>
#       <td>Diorite</td>
#       <td>19.80-20.00</td>
#       <td>153.5</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>NE1-02</td>
#       <td>KhonKaen University</td>
#       <td>8</td>
#       <td>Diorite</td>
#       <td>23.00-23.70</td>
#       <td>172.15</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>NE1-02</td>
#       <td>KhonKaen University</td>
#       <td>9</td>
#       <td>Diorite</td>
#       <td>23.00-23.70</td>
#       <td>222.84</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>NE1-02</td>
#       <td>KhonKaen University</td>
#       <td>7</td>
#       <td>Diorite</td>
#       <td>23.00-23.70</td>
#       <td>182.67</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>NE1-02</td>
#       <td>KhonKaen University</td>
#       <td>12</td>
#       <td>Pegmatite</td>
#       <td>25.15-25.25</td>
#       <td>211.63</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>NE1-02</td>
#       <td>KhonKaen University</td>
#       <td>13</td>
#       <td>Diorite</td>
#       <td>28.80-28.90</td>
#       <td>167.37</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>NE1-03</td>
#       <td>KhonKaen University</td>
#       <td>14</td>
#       <td>Pegmatite</td>
#       <td>19.50-19.60</td>
#       <td>122.42</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>NE1-04</td>
#       <td>LTEC</td>
#       <td>26</td>
#       <td>Granodiorite</td>
#       <td>100.45-100.55</td>
#       <td>60.26</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>NE1-04</td>
#       <td>LTEC</td>
#       <td>27</td>
#       <td>Granodiorite</td>
#       <td>24.1-24.25</td>
#       <td>9.71</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>NE1-04</td>
#       <td>LTEC</td>
#       <td>28</td>
#       <td>Granodiorite</td>
#       <td>98.20-98.3</td>
#       <td>84.46</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>NE1-07</td>
#       <td>KhonKaen University</td>
#       <td>1</td>
#       <td>Sandstone</td>
#       <td>26.75-27.80</td>
#       <td>140.66</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>NE1-07</td>
#       <td>KhonKaen University</td>
#       <td>2</td>
#       <td>Sandstone</td>
#       <td>27.60-27.80</td>
#       <td>151.22</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>NE1-07</td>
#       <td>KhonKaen University</td>
#       <td>15</td>
#       <td>Sandstone</td>
#       <td>28.00-28.25</td>
#       <td>104.25</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>NE1-07</td>
#       <td>KhonKaen University</td>
#       <td>3</td>
#       <td>Sandstone</td>
#       <td>31.00-31.15</td>
#       <td>215.07</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>NE1-07</td>
#       <td>KhonKaen University</td>
#       <td>17</td>
#       <td>Sandstone</td>
#       <td>32.60-33.00</td>
#       <td>134.33</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>NE1-07</td>
#       <td>KhonKaen University</td>
#       <td>16</td>
#       <td>Sandstone</td>
#       <td>32.60-33.00</td>
#       <td>158.28</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>NE1-07</td>
#       <td>KhonKaen University</td>
#       <td>18</td>
#       <td>Sandstone</td>
#       <td>34.05-34.20</td>
#       <td>153.02</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>NE1-07</td>
#       <td>KhonKaen University</td>
#       <td>19</td>
#       <td>Sandstone</td>
#       <td>44.80-45.00</td>
#       <td>193.46</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>NE1-08</td>
#       <td>LTEC</td>
#       <td>31</td>
#       <td>Sericite</td>
#       <td>16.3-16.45</td>
#       <td>28.58</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>NE1-08</td>
#       <td>LTEC</td>
#       <td>32</td>
#       <td>Sericite</td>
#       <td>24.25-25.37</td>
#       <td>41.28</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>NE1-09</td>
#       <td>LTEC</td>
#       <td>29</td>
#       <td>Sericite</td>
#       <td>19.15-19.25</td>
#       <td>115.72</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>NE1-09</td>
#       <td>LTEC</td>
#       <td>30</td>
#       <td>Sericite</td>
#       <td>23.45-23.55</td>
#       <td>73.36</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>NE1-12</td>
#       <td>KhonKaen University</td>
#       <td>24</td>
#       <td>Granodiorite</td>
#       <td>33.40-33.50</td>
#       <td>193.52</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>NE1-12</td>
#       <td>KhonKaen University</td>
#       <td>21</td>
#       <td>Granodiorite</td>
#       <td>34.05-34.20</td>
#       <td>204.34</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>NE1-12</td>
#       <td>KhonKaen University</td>
#       <td>20</td>
#       <td>Granodiorite</td>
#       <td>46.75-46.85</td>
#       <td>268.27</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>NE1-12</td>
#       <td>KhonKaen University</td>
#       <td>22</td>
#       <td>Granodiorite</td>
#       <td>87.15-87.25</td>
#       <td>117.59</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>NE1-12</td>
#       <td>KhonKaen University</td>
#       <td>23</td>
#       <td>Diorite</td>
#       <td>99.80-99.90</td>
#       <td>183.13</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>NE1-15</td>
#       <td>KhonKaen University</td>
#       <td>25</td>
#       <td>Diorite</td>
#       <td>29.40-29.50</td>
#       <td>193.52</td>
#       <td>MPa</td>
#     </tr>
#   </tbody>
# </table>

# %%
# remove records for sigma_c if no record for E at the sample_depth
#   note that it is not check if there are E values with no record for sigma_c at the sample_depth

nem_data_sigma_c_s_adj = []  # adjusted list
i=0

#for item in nem_data_sigma_c_s:
for item in nem_data_sigma_c:
    # check if a record exists with an E value at the sample_depth of the item
    # and append to the adjusted list if record exists 
#    if any(d['sample_depth_top_m'] == (nem_data_sigma_c_s[i]['sample_depth_top_m']) for d in nem_data_e_s):
    if any(d['sample_depth_top_m'] == (nem_data_sigma_c[i]['sample_depth_top_m']) for d in nem_data_es):
        #print i
        #print nem_data_sigma_c_s[i]['sample_depth_top_m']
        nem_data_sigma_c_s_adj.append(item)
        i+=1
    else:
        i=1+i
        pass

# %%
# data report
#   report should also provide count information (see below "reference from Alan")

# read nem_data_e into pandas data frame    
nem_data_sigma_c_s_adj_df = pd.DataFrame(data=nem_data_sigma_c_s_adj)#nem_data_df = nem_data_df.fillna('NaN').T

# display nem_data_df as html using pandas df.to_html()
from IPython.core.display import display, HTML
display(HTML('<h4>NEM data for sigma_c </h4>'))
display(HTML(nem_data_sigma_c_s_adj_df.to_html()))
# Out:
# <h4>NEM data for sigma_c </h4>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>borehole_code</th>
#       <th>laboratory</th>
#       <th>laboratory_test_code</th>
#       <th>lithology</th>
#       <th>sample_depth_top_m</th>
#       <th>value</th>
#       <th>value_unit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>NE1-01</td>
#       <td>KhonKaen University</td>
#       <td>10</td>
#       <td>Diorite</td>
#       <td>22.80-23.10</td>
#       <td>84.78</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>NE1-02</td>
#       <td>KhonKaen University</td>
#       <td>11</td>
#       <td>Diorite</td>
#       <td>19.80-20.00</td>
#       <td>153.5</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NE1-02</td>
#       <td>KhonKaen University</td>
#       <td>12</td>
#       <td>Pegmatite</td>
#       <td>25.15-25.25</td>
#       <td>211.63</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NE1-02</td>
#       <td>KhonKaen University</td>
#       <td>13</td>
#       <td>Diorite</td>
#       <td>28.80-28.90</td>
#       <td>167.37</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>NE1-03</td>
#       <td>KhonKaen University</td>
#       <td>14</td>
#       <td>Pegmatite</td>
#       <td>19.50-19.60</td>
#       <td>122.42</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>NE1-04</td>
#       <td>LTEC</td>
#       <td>26</td>
#       <td>Granodiorite</td>
#       <td>100.45-100.55</td>
#       <td>60.26</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>NE1-04</td>
#       <td>LTEC</td>
#       <td>27</td>
#       <td>Granodiorite</td>
#       <td>24.1-24.25</td>
#       <td>9.71</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>NE1-04</td>
#       <td>LTEC</td>
#       <td>28</td>
#       <td>Granodiorite</td>
#       <td>98.20-98.3</td>
#       <td>84.46</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>NE1-07</td>
#       <td>KhonKaen University</td>
#       <td>15</td>
#       <td>Sandstone</td>
#       <td>28.00-28.25</td>
#       <td>104.25</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>NE1-07</td>
#       <td>KhonKaen University</td>
#       <td>17</td>
#       <td>Sandstone</td>
#       <td>32.60-33.00</td>
#       <td>134.33</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>NE1-07</td>
#       <td>KhonKaen University</td>
#       <td>16</td>
#       <td>Sandstone</td>
#       <td>32.60-33.00</td>
#       <td>158.28</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>NE1-07</td>
#       <td>KhonKaen University</td>
#       <td>18</td>
#       <td>Sandstone</td>
#       <td>34.05-34.20</td>
#       <td>153.02</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>NE1-07</td>
#       <td>KhonKaen University</td>
#       <td>19</td>
#       <td>Sandstone</td>
#       <td>44.80-45.00</td>
#       <td>193.46</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>NE1-08</td>
#       <td>LTEC</td>
#       <td>31</td>
#       <td>Sericite</td>
#       <td>16.3-16.45</td>
#       <td>28.58</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>NE1-08</td>
#       <td>LTEC</td>
#       <td>32</td>
#       <td>Sericite</td>
#       <td>24.25-25.37</td>
#       <td>41.28</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>NE1-09</td>
#       <td>LTEC</td>
#       <td>29</td>
#       <td>Sericite</td>
#       <td>19.15-19.25</td>
#       <td>115.72</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>NE1-09</td>
#       <td>LTEC</td>
#       <td>30</td>
#       <td>Sericite</td>
#       <td>23.45-23.55</td>
#       <td>73.36</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>NE1-12</td>
#       <td>KhonKaen University</td>
#       <td>24</td>
#       <td>Granodiorite</td>
#       <td>33.40-33.50</td>
#       <td>193.52</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>NE1-12</td>
#       <td>KhonKaen University</td>
#       <td>21</td>
#       <td>Granodiorite</td>
#       <td>34.05-34.20</td>
#       <td>204.34</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>NE1-12</td>
#       <td>KhonKaen University</td>
#       <td>20</td>
#       <td>Granodiorite</td>
#       <td>46.75-46.85</td>
#       <td>268.27</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>NE1-12</td>
#       <td>KhonKaen University</td>
#       <td>22</td>
#       <td>Granodiorite</td>
#       <td>87.15-87.25</td>
#       <td>117.59</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>NE1-12</td>
#       <td>KhonKaen University</td>
#       <td>23</td>
#       <td>Diorite</td>
#       <td>99.80-99.90</td>
#       <td>183.13</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>NE1-15</td>
#       <td>KhonKaen University</td>
#       <td>25</td>
#       <td>Diorite</td>
#       <td>29.40-29.50</td>
#       <td>193.52</td>
#       <td>MPa</td>
#     </tr>
#   </tbody>
# </table>

# %%
# prepare Es values for histogram 
data_e=[]

for item in nem_data_es:
    data_e.append(float(item['value']))
print data_e
# Out:
# [12800.0, 18100.0, 29700.0, 18300.0, 5650.0, 5769.2, 2574.3, 8076.9, 14600.0, 16800.0, 13300.0, 30500.0, 22100.0, 3891.9, 6375.0, 10769.2, 8139.5, 21500.0, 15700.0, 30600.0, 19300.0, 14800.0, 19200.0]

# %%
# plot histogram of all Es values

import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
from scipy.stats import norm

# input: E containing 'values' of 'parameter' E
E = data_e

# plot histogram of E values for all rock lithologies
# plt.hist(values, number of bins, additional named parameters)
hist,bin_edges,patches = plt.hist(E, 20, normed=1, facecolor='green', alpha=0.75)
# just guessing at distribution
#mu, sigma = 15000, 10000
#y = mlab.normpdf( bin_edges, mu, sigma)
#l = plt.plot(bin_edges, y, 'b--', linewidth=1)

# calculating distribution of E values using scipy
param = norm.fit(E) 
# now, param[0] and param[1] are the mean and 
# the standard deviation of the fitted distribution
y = mlab.normpdf( bin_edges, param[0], param[1])
ll = plt.plot(bin_edges, y, 'r--', linewidth=1)

# plot axis labels and grid
plt.ylabel('Probability')
plt.xlabel('ALL LITHOLIGIES E-Modulus Es (MPa)')
plt.grid(True)
plt.show()

print(param[0])  # mean
print(param[1])  # standard deviation
len(E) # one more check

# "added value": results show one of the problems facing an 'uneducate' view of getoechnical data statistics:
#   lower tail goes negative, which is pysically impossible! 
#   e--> we need a skew distribution --> can be significant difference in outcomes
# Out:
# 15154.173913
# 8069.82420353
# 23

# %%
# prepare E50 values for histogram 
data_e=[]

for item in nem_data_e50:
    data_e.append(float(item['value']))
print data_e
# Out:
# [15850.0, 24630.0, 52930.0, 21560.0, 14460.0, 8475.0, 4799.2, 11968.7, 21290.0, 20800.0, 19170.0, 30450.0, 44310.0, 7963.4, 9053.3, 14813.1, 11893.5, 29530.0, 21790.0, 71420.0, 20940.0, 19080.0, 27420.0]

# %%
# plot histogram of all E50 values

# input: E containing 'values' of 'parameter' E
E = data_e

# plot histogram of E values for all rock lithologies
# plt.hist(values, number of bins, additional named parameters)
hist,bin_edges,patches = plt.hist(E, 20, normed=1, facecolor='green', alpha=0.75)
# just guessing at distribution
#mu, sigma = 15000, 10000
#y = mlab.normpdf( bin_edges, mu, sigma)
#l = plt.plot(bin_edges, y, 'b--', linewidth=1)

# calculating distribution of E values using scipy
param = norm.fit(E) 
# now, param[0] and param[1] are the mean and 
# the standard deviation of the fitted distribution
y = mlab.normpdf( bin_edges, param[0], param[1])
ll = plt.plot(bin_edges, y, 'r--', linewidth=1)

# plot axis labels and grid
plt.ylabel('Probability')
plt.xlabel('ALL LITHOLIGIES E-Modulus E50 (MPa)')
plt.grid(True)
plt.show()

print(param[0])  # mean
print(param[1])  # standard deviation
len(E) # one more check
# Out:
# 22808.5304348
# 15120.4863707
# 23

# %%
data_lithology=[]

#for item in nem_data_e50_s:
for item in nem_data_e50:   
    data_lithology.append(item['lithology'])
print data_lithology
print len(data_lithology)
# Out:
# [u'Diorite', u'Diorite', u'Pegmatite', u'Diorite', u'Pegmatite', u'Granodiorite', u'Granodiorite', u'Granodiorite', u'Sandstone', u'Sandstone', u'Sandstone', u'Sandstone', u'Sandstone', u'Sericite', u'Sericite', u'Sericite', u'Sericite', u'Granodiorite', u'Granodiorite', u'Granodiorite', u'Granodiorite', u'Diorite', u'Diorite']
# 23

# %%
# prepare E50 values for sandstone for histogram 

# select E values where 'lithology' is Sandstone
sandstone_i=[]
E_i=[]

for i in range(0,len(data_lithology)):
    if data_lithology[i]=='Sandstone':
        sandstone_i.append(i)
        print i, data_lithology[i]
        E_i.append(float(nem_data_e50[i]['value']))
        print nem_data_e50[i]['lithology']

print(sandstone_i)
print(E_i)
# Out:
# 8 Sandstone
# Sandstone
# 9 Sandstone
# Sandstone
# 10 Sandstone
# Sandstone
# 11 Sandstone
# Sandstone
# 12 Sandstone
# Sandstone
# [8, 9, 10, 11, 12]
# [21290.0, 20800.0, 19170.0, 30450.0, 44310.0]

# %%
data_sigma_c=[]

for item in nem_data_sigma_c_s_adj:
    data_sigma_c.append(item['value'])
print data_sigma_c
print len(data_sigma_c)
# Out:
# [u'84.78', u'153.5', u'211.63', u'167.37', u'122.42', u'60.26', u'9.71', u'84.46', u'104.25', u'134.33', u'158.28', u'153.02', u'193.46', u'28.58', u'41.28', u'115.72', u'73.36', u'193.52', u'204.34', u'268.27', u'117.59', u'183.13', u'193.52']
# 23

# %%
E_i
# Out:
# [21290.0, 20800.0, 19170.0, 30450.0, 44310.0]

# %%
# input: E containing 'values' of 'parameter' E

# plot histogram for E values of Sandstones
n, bins, patches = plt.hist(E_i, 20, normed=1, facecolor='orange', alpha=0.75)
#n, bins, patches = plt.hist(E_i, 20,facecolor='orange', alpha=0.75)
#   without 'normed=1', don't get sensible distribution fit

# calculating distribution with data using scipy
param = norm.fit(E_i) 
# now, param[0] and param[1] are the mean and 
# the standard deviation of the fitted distribution
y = mlab.normpdf( bins, param[0], param[1])
ll = plt.plot(bins, y, 'r--', linewidth=1)

plt.ylabel('Probability')
plt.xlabel('SANDSTONE E-Modulus (MPa)')
plt.grid(True)
plt.show()
print(param[0])
print(param[1])
#len(E_i)
# added value: results show one of the problems facing an 'uneducate' view of getoechnical data statistics:
#   lower tail goes negative, which is pysically impossible! 
#   e--> we need a skew distribution --> can be significant difference in outcomes
# Out:
# 27204.0
# 9420.01613587

# %%
# check number or records same for all data lists
print(len(data_e))
print(len(data_sigma_c))   
print(len(data_lithology))

# assign colors to lithologies for use in scatterplot
colors=[]
for i in range(0,len(data_lithology)):
    if data_lithology[i]=='Sandstone':
        colors.append('orange')
    elif data_lithology[i]=='Diorite':
        colors.append('black')
    elif data_lithology[i]=='Pegmatite':
        colors.append('blue')
    elif data_lithology[i]=='Granodiorite':
        colors.append('gray')
    elif data_lithology[i]=='Sericite':
        colors.append('green')
    else:
        colors.append('red')
print(colors)
# Out:
# 23
# 23
# 23
# ['black', 'black', 'blue', 'black', 'blue', 'gray', 'gray', 'gray', 'orange', 'orange', 'orange', 'orange', 'orange', 'green', 'green', 'green', 'green', 'gray', 'gray', 'gray', 'gray', 'black', 'black']

# %%
from matplotlib.lines import Line2D

# input: data_e, data_sigma_c containing 'values' of 'parameter' E and sigma_c
#        colors containg list of colors for lithologies in records (colors previously assigned lithologies)

# scatterplot of E against sigma_c for all rock lithologies
rock_plot=plt.scatter([data_e],[data_sigma_c],color=colors,marker='^')

# legend
sym1 = Line2D([0], [0], linestyle="none", marker="^", alpha=1.0, color="orange")
sym2 = Line2D([0], [0], linestyle="none", marker="^", alpha=1.0, color="black")
sym3 = Line2D([0], [0], linestyle="none", marker="^", alpha=1.0, color="blue")
sym4 = Line2D([0], [0], linestyle="none", marker="^", alpha=1.0, color="gray")
sym5 = Line2D([0], [0], linestyle="none", marker="^", alpha=1.0, color="green")
plt.legend((sym1,sym2,sym3,sym4,sym5),("Sandstone","Diorite","Pegmatite","Granodiorite","Sericite"),
           numpoints=1,loc="best")

# axis labels
plt.ylabel('sigma_c (MPa)')
plt.xlabel('E-Modulus[E50] (MPa)')
plt.plot((2000,20000,40000,60000),(10,100,200,300), color="gray")

# a reference trend line
plt.annotate("200:1",xy=(50000,250),xytext=(50000,285),rotation=35)

plt.show()
