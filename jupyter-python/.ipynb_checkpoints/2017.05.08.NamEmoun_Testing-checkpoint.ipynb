# %% [markdown]
# # Example of  using Data Oganizer for geotechnical anaysis and plotting

# %% [markdown]
# ### Query Data Organizer for parameters Es, E50, sigma_c, then write to lists and show report tables

# %%
# set upspatial python ecosystem

import json
import pandas as pd

# %%
# open Data Organizer

#   how to select project or projects?
from DataOrganizer import CouchbaseSelector
# make this notebook script compaible with previous
ne1 = 'geotechnical'
db = CouchbaseSelector('localhost',ne1)

# %%
# query Data Organizer records for 'parameter' = E measured as Es
#  sorting by borehole_cod and sample_depth

# initialize variables
nem_data_es=[]
# unsorted lists for checking
Es=[]
lithology=[]  
laboratory_test_code=[]
sample_depth=[]

parameter = 'E'
fields = ['borehole_code', 'lithology','laboratory', 'laboratory_test_code', 'sample_depth_top_m', 
          'value', 'value_unit']
selector = {'data_source': 'Laboratory', 'measurement_convention': 'Es'}
sort = ['borehole_code','sample_depth_top_m']
# db.setDebug(True)

# write selected fields to lists
for rec in db.get_parameter(parameter, fields, selector, sort):
    # print rec['borehole_code']
    # print rec 
    # write rec to nem_data_es
    nem_data_es.append(rec)
    try:
        Es.append(rec['value'])
    except:
        print "check value data for E=", rec['value']
    try:
        lithology.append(rec['lithology'])
    except:
        print "check lithology data for E=", rec['value']
    try:
        laboratory_test_code.append(rec['laboratory_test_code'])
    except:
        print "check laboratory_test_code data for E=", rec['value']
    try:
        sample_depth.append(rec['sample_depth_top_m'])
    except:
        print "check sample_depth data for E=", rec['value']
    # there must be a more elegant way of checking that data exists                               Todo JK  
    # how to mark missing data as 'NaN'?

# %%
# data report
# input: nem_data_es
#   report should also provide count information (see below "reference from Alan")                Todo JK

# write returned Data Organizer list to a pandas data frame
nem_data_es_s_df = pd.DataFrame(data=nem_data_es)

# display nem_data_df as html using pandas df.to_html()
from IPython.core.display import display, HTML
display(HTML('<h4>NEM data for Es </h4>'))
display(HTML(nem_data_es_s_df.to_html()))
# Out:
# <h4>NEM data for Es </h4>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>borehole_code</th>
#       <th>laboratory</th>
#       <th>laboratory_test_code</th>
#       <th>lithology</th>
#       <th>sample_depth_top_m</th>
#       <th>value</th>
#       <th>value_unit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>NE1-01</td>
#       <td>KhonKaen University</td>
#       <td>10</td>
#       <td>Diorite</td>
#       <td>22.80-23.10</td>
#       <td>12800</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>NE1-02</td>
#       <td>KhonKaen University</td>
#       <td>11</td>
#       <td>Diorite</td>
#       <td>19.80-20.00</td>
#       <td>18100</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NE1-02</td>
#       <td>KhonKaen University</td>
#       <td>12</td>
#       <td>Pegmatite</td>
#       <td>25.15-25.25</td>
#       <td>29700</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NE1-02</td>
#       <td>KhonKaen University</td>
#       <td>13</td>
#       <td>Diorite</td>
#       <td>28.80-28.90</td>
#       <td>18300</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>NE1-03</td>
#       <td>KhonKaen University</td>
#       <td>14</td>
#       <td>Pegmatite</td>
#       <td>19.50-19.60</td>
#       <td>5650</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>NE1-04</td>
#       <td>LTEC</td>
#       <td>26</td>
#       <td>Granodiorite</td>
#       <td>100.45-100.55</td>
#       <td>5769.2</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>NE1-04</td>
#       <td>LTEC</td>
#       <td>27</td>
#       <td>Granodiorite</td>
#       <td>24.1-24.25</td>
#       <td>2574.3</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>NE1-04</td>
#       <td>LTEC</td>
#       <td>28</td>
#       <td>Granodiorite</td>
#       <td>98.20-98.3</td>
#       <td>8076.9</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>NE1-07</td>
#       <td>KhonKaen University</td>
#       <td>15</td>
#       <td>Sandstone</td>
#       <td>28.00-28.25</td>
#       <td>14600</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>NE1-07</td>
#       <td>KhonKaen University</td>
#       <td

#   u'value_unit': u'MPa'},
#  {u'borehole_code': u'NE1-02',
#   u'laboratory': u'KhonKaen University',
#   u'laboratory_test_code': u'11',
#   u'lithology': u'Diorite',
#   u'sample_depth_top_m': u'19.80-20.00',
#   u'value': u'18100',
#   u'value_unit': u'MPa'},
#  {u'borehole_code': u'NE1-02',
#   u'laboratory': u'KhonKaen University',
#   u'laboratory_test_code': u'12',
#   u'lithology': u'Pegmatite',
#   u'sample_depth_top_m': u'25.15-25.25',
#   u'value': u'29700',
#   u'value_unit': u'MPa'},
#  {u'borehole_code': u'NE1-02',
#   u'laboratory': u'KhonKaen University',
#   u'laboratory_test_code': u'13',
#   u'lithology': u'Diorite',
#   u'sample_depth_top_m': u'28.80-28.90',
#   u'value': u'18300',
#   u'value_unit': u'MPa'},
#  {u'borehole_code': u'NE1-03',
#   u'laboratory': u'KhonKaen University',
#   u'laboratory_test_code': u'14',
#   u'lithology': u'Pegmatite',
#   u'sample_depth_top_m': u'19.50-19.60',
#   u'value': u'5650',
#   u'value_unit': u'MPa'},
#  {u'borehole_code': u'NE1-04',
#   u'laboratory': u'LTEC',
#   u'laboratory_test_code': u'26',
#   u'lithology': u'Granodiorite',
#   u'sample_depth_top_m': u'100.45-100.55',
#   u'value': u'5769.2',
#   u'value_unit': u'MPa'},
#  {u'borehole_code': u'NE1-04',
#   u'laboratory': u'LTEC',
#   u'laboratory_test_code': u'27',
#   u'lithology': u'Granodiorite',
#   u'sample_depth_top_m': u'24.1-24.25',
#   u'value': u'2574.3',
#   u'value_unit': u'MPa'},
#  {u'borehole_code': u'NE1-04',
#   u'laboratory': u'LTEC',
#   u'laboratory_test_code': u'28',
#   u'lithology': u'Granodiorite',
#   u'sample_depth_top_m': u'98.20-98.3',
#   u'value': u'8076.9',
#   u'value_unit': u'MPa'},
#  {u'borehole_code': u'NE1-07',
#   u'laboratory': u'KhonKaen University',
#   u'laboratory_test_code': u'15',
#   u'lithology': u'Sandstone',
#   u'sample_depth_top_m': u'28.00-28.25',
#   u'value': u'14600',
#   u'value_unit': u'MPa'},
#  {u'borehole_code': u'NE1-07',
#   u'laboratory': u'KhonKaen University',
#   u'laboratory_test_code': u'17',
#   u'lithology': u'Sandstone',
#   u'sample_depth_top_m': u'32.60-33.00',
#   u'value': u'13300',
#   u'value_unit': u'MPa'},
#  {u'borehole_code': u'NE1-07',
#   u'laboratory': u'KhonKaen University',
#   u'laboratory_test_code': u'16',
#   u'lithology': u'Sandstone',
#   u'sample_depth_top_m': u'32.60-33.00',
#   u'value': u'16800',
#   u'value_unit': u'MPa'},
#  {u'borehole_code': u'NE1-07',
#   u'laboratory': u'KhonKaen University',
#   u'laboratory_test_code': u'18',
#   u'lithology': u'Sandstone',
#   u'sample_depth_top_m': u'34.05-34.20',
#   u'value': u'30500',
#   u'value_unit': u'MPa'},
#  {u'borehole_code': u'NE1-07',
#   u'laboratory': u'KhonKaen University',
#   u'laboratory_test_code': u'19',
#   u'lithology': u'Sandstone',
#   u'sample_depth_top_m': u'44.80-45.00',
#   u'value': u'22100',
#   u'value_unit': u'MPa'},
#  {u'borehole_code': u'NE1-08',
#   u'laboratory': u'LTEC',
#   u'laboratory_test_code': u'31',
#   u'lithology': u'Sericite',
#   u'sample_depth_top_m': u'16.3-16.45 ',
#   u'value': u'3891.9',
#   u'value_unit': u'MPa'},
#  {u'borehole_code': u'NE1-08',
#   u'laboratory': u'LTEC',
#   u'laboratory_test_code': u'32',
#   u'lithology': u'Sericite',
#   u'sample_depth_top_m': u'24.25-25.37',
#   u'value': u'6375',
#   u'value_unit': u'MPa'},
#  {u'borehole_code': u'NE1-09',
#   u'laboratory': u'LTEC',
#   u'laboratory_test_code': u'29',
#   u'lithology': u'Sericite',
#   u'sample_depth_top_m': u'19.15-19.25',
#   u'value': u'10769.2',
#   u'value_unit': u'MPa'},
#  {u'borehole_code': u'NE1-09',
#   u'laboratory': u'LTEC',
#   u'laboratory_test_code': u'30',
#   u'lithology': u'Sericite',
#   u'sample_depth_top_m': u'23.45-23.55',
#   u'value': u'8139.5',
#   u'value_unit': u'MPa'},
#  {u'borehole_code': u'NE1-12',
#   u'laboratory': u'KhonKaen University',
#   u'laboratory_test_code': u'24',
#   u'lithology': u'Granodiorite',
#   u'sample_depth_top_m': u'33.40-33.50',
#   u'value': u'21500',
#   u'value_unit': u'MPa'},
#  {u'borehole_code': u'NE1-12',
#   u'laboratory': u'KhonKaen University',
#   u'laboratory_test_code': u'21',
#   u'lithology': u'Granodiorite',
#   u'sample_depth_top_m': u'34.05-34.20',
#   u'value': u'15700',
#   u'value_unit': u'MPa'},
#  {u'borehole_code': u'NE1-12',
#   u'laboratory': u'KhonKaen University',
#   u'laboratory_test_code': u'20',
#   u'lithology': u'Granodiorite',
#   u'sample_depth_top_m': u'46.75-46.85',
#   u'value': u'30600',
#   u'value_unit': u'MPa'},
#  {u'borehole_code': u'NE1-12',
#   u'laboratory': u'KhonKaen University',
#   u'laboratory_test_code': u'22',
#   u'lithology': u'Granodiorite',
#   u'sample_depth_top_m': u'87.15-87.25',
#   u'value': u'19300',
#   u'value_unit': u'MPa'},
#  {u'borehole_code': u'NE1-12',
#   u'laboratory': u'KhonKaen University',
#   u'laboratory_test_code': u'23',
#   u'lithology': u'Diorite',
#   u'sample_depth_top_m': u'99.80-99.90',
#   u'value': u'14800',
#   u'value_unit': u'MPa'},
#  {u'borehole_code': u'NE1-15',
#   u'laboratory': u'KhonKaen University',
#   u'laboratory_test_code': u'25',
#   u'lithology': u'Diorite',
#   u'sample_depth_top_m': u'29.40-29.50',
#   u'value': u'19200',
#   u'value_unit': u'MPa'},
#  {u'borehole_code': u'NT1-15',
#   u'laboratory': u'KhonKaen University',
#   u'laboratory_test_code': u'90',
#   u'lithology': u'Siltstone',
#   u'sample_depth_top_m': u'36.08',
#   u'value': u'4500.00',
#   u'value_unit': u'MPa'},
#  {u'borehole_code': u'NT1-15',
#   u'laboratory': u'KhonKaen University',
#   u'laboratory_test_code': u'91',
#   u'lithology': u'Siltstone',
#   u'sample_depth_top_m': u'36.08',
#   u'value': u'6400.00',
#   u'value_unit': u'MPa'},
#  {u'borehole_code': u'NT1-15',
#   u'laboratory': u'KhonKaen University',
#   u'laboratory_test_code': u'92',
#   u'lithology': u'Siltstone',
#   u'sample_depth_top_m': u'36.08',
#   u'value': u'8210.00',
#   u'value_unit': u'MPa'},
#  {u'borehole_code': u'NT1-19',
#   u'laboratory': u'KhonKaen University',
#   u'laboratory_test_code': u'89',
#   u'lithology': u'Siltstone',
#   u'sample_depth_top_m': u'58.60',
#   u'value': u'5820.00',
#   u'value_unit': u'MPa'},
#  {u'borehole_code': u'NT1-19',
#   u'laboratory': u'KhonKaen University',
#   u'laboratory_test_code': u'88',
#   u'lithology': u'Siltstone',
#   u'sample_depth_top_m': u'58.60',
#   u'value': u'7680.00',
#   u'value_unit': u'MPa'},
#  {u'borehole_code': u'NT1-19',
#   u'laboratory': u'KhonKaen University',
#   u'laboratory_test_code': u'87',
#   u'lithology': u'Siltstone',
#   u'sample_depth_top_m': u'58.60',
#   u'value': u'10800.00',
#   u'value_unit': u'MPa'},
#  {u'borehole_code': u'NT1-A19',
#   u'laboratory': u'KhonKaen University',
#   u'laboratory_test_code': u'81',
#   u'lithology': u'Siltstone',
#   u'sample_depth_top_m': u'',
#   u'value': u'5250.00',
#   u'value_unit': u'MPa'},
#  {u'borehole_code': u'NT1-A21',
#   u'laboratory': u'KhonKaen University',
#   u'laboratory_test_code': u'80',
#   u'lithology': u'Siltstone',
#   u'sample_depth_top_m': u'',
#   u'value': u'6240.00',
#   u'value_unit': u'MPa'},
#  {u'borehole_code': u'NT1-A22',
#   u'laboratory': u'KhonKaen University',
#   u'laboratory_test_code': u'86',
#   u'lithology': u'Siltstone',
#   u'sample_depth_top_m': u'',
#   u'value': u'3940.00',
#   u'value_unit': u'MPa'},
#  {u'borehole_code': u'NT1-A24',
#   u'laboratory': u'KhonKaen University',
#   u'laboratory_test_code': u'83',
#   u'lithology': u'Siltstone',
#   u'sample_depth_top_m': u'',
#   u'value': u'6460.00',
#   u'value_unit': u'MPa'},
#  {u'borehole_code': u'NT1-A25',
#   u'laboratory': u'KhonKaen University',
#   u'laboratory_test_code': u'85',
#   u'lithology': u'Siltstone',
#   u'sample_depth_top_m': u'',
#   u'value': u'4180.00',
#   u'value_unit': u'MPa'},
#  {u'borehole_code': u'NT1-A6',
#   u'laboratory': u'KhonKaen University',
#   u'laboratory_test_code': u'84',
#   u'lithology': u'Siltstone',
#   u'sample_depth_top_m': u'',
#   u'value': u'4680.00',
#   u'value_unit': u'MPa'},
#  {u'borehole_code': u'NT1-A?',
#   u'laboratory': u'KhonKaen University',
#   u'laboratory_test_code': u'82',
#   u'lithology': u'Siltstone',
#   u'sample_depth_top_m': u'',
#   u'value': u'8070.00',
#   u'value_unit': u'MPa'}]

# %%
# query Data Organizer records for 'parameter' = E measured as E50 and Et (appear to be same measurement)
#  sorting by borehole_cod and sample_depth, where measurement_convention = E50 or Et (!= Es)

# initialize variables
nem_data_e50=[]
# unsorted lists for checking
E50=[]
lithology=[]
laboratory_test_code=[]
sample_depth=[]

# query Data Organiser for E50 records
parameter = 'E'
fields = ['borehole_code','lithology','laboratory', 'laboratory_test_code', 'sample_depth_top_m', 
          'measurement_convention', 'value', 'value_unit']
selector = {'data_source': 'Laboratory'}
sort = ['borehole_code','sample_depth_top_m']

# write selected fields to lists, where measurement_convention = Es
for rec in db.get_parameter(parameter, fields, selector, sort):
    if rec['measurement_convention'] != 'Es':
        # write rec to nem_data_e50
        nem_data_e50.append(rec)

print len(nem_data_e50)
# Out:
# 77

# %%
# data report
# input: nem_data_e50

nem_data_e50_s_df = pd.DataFrame(data=nem_data_e50)

# display nem_data_df as html using pandas df.to_html()
from IPython.core.display import display, HTML
display(HTML('<h4>NEM data for E50 </h4>'))
display(HTML(nem_data_e50_s_df.to_html()))
# Out:
# <h4>NEM data for E50 </h4>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>borehole_code</th>
#       <th>laboratory</th>
#       <th>laboratory_test_code</th>
#       <th>lithology</th>
#       <th>measurement_convention</th>
#       <th>sample_depth_top_m</th>
#       <th>value</th>
#       <th>value_unit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>
00</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>NT1-1</td>
#       <td></td>
#       <td>57</td>
#       <td>Conglomerate</td>
#       <td></td>
#       <td>61.50</td>
#       <td>3532.00</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>NT1-11</td>
#       <td></td>
#       <td>70</td>
#       <td>Sandstone</td>
#       <td></td>
#       <td>15.65</td>
#       <td>3142.00</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>NT1-14</td>
#       <td>KhonKaen University</td>
#       <td>33</td>
#       <td>Red Sandstone</td>
#       <td>E50</td>
#       <td>28.90</td>
#       <td>13200.00</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>NT1-14</td>
#       <td>KhonKaen University</td>
#       <td>34</td>
#       <td>Red Sandstone</td>
#       <td>E50</td>
#       <td>36.80</td>
#       <td>51400.00</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>NT1-14</td>
#       <td>KhonKaen University</td>
#       <td>36</td>
#       <td>Red Sandstone</td>
#       <td>E50</td>
#       <td>37.30</td>
#       <td>19700.00</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>NT1-14</td>
#       <td>KhonKaen University</td>
#       <td>35</td>
#       <td>Red Sandstone</td>
#       <td>E50</td>
#       <td>37.30</td>
#       <td>17800.00</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>NT1-14</td>
#       <td>KhonKaen University</td>
#       <td>37</td>
#       <td>Red Sandstone</td>
#       <td>E50</td>
#       <td>56.80</td>
#       <td>22100.00</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>NT1-15</td>
#       <td>KhonKaen University</td>
#       <td>38</td>
#       <td>Siltstone</td>
#       <td>E50</td>
#       <td>32.20</td>
#       <td>4170.00</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>NT1-15</td>
#       <td>KhonKaen University</td>
#       <td>92</td>
#       <td>Siltstone</td>
#       <td>E50</td>
#       <td>36.08</td>
#       <td>9579.00</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>NT1-15</td>
#       <td>KhonKaen University</td>
#       <td>90</td>
#       <td>Siltstone</td>
#       <td>E50</td>
#       <td>36.08</td>
#       <td>6867.00</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>NT1-15</td>
#       <td>KhonKaen University</td>
#       <td>91</td>
#       <td>Siltstone</td>
#       <td>E50</td>
#       <td>36.08</td>
#       <td>11800.00</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>35<

# %%
# query Data Organizer records for 'parameter' = sigma_c
#  sorting by borehole_cod and sample_depth

# initialize variables
nem_data_sigma_c=[]
# unsorted lists for checking
sigma_c=[]
lithology=[]  
laboratory_test_code=[]
sample_depth=[]

parameter = 'sigma_c'
fields = ['borehole_code','lithology','laboratory', 'laboratory_test_code', 'sample_depth_top_m', 'value', 'value_unit']
selector = {'data_source': 'Laboratory'}
sort = ['borehole_code','sample_depth_top_m']

# write selected fields to lists
for rec in db.get_parameter(parameter, fields, selector, sort):
    # print rec 
    # write rec to nem_data_e   
    nem_data_sigma_c.append(rec)

print len(nem_data_sigma_c)
# Out:
# 92

# %%
# data report
# input: nem_data_sigma_c

nem_data_sigma_c_s_df = pd.DataFrame(data=nem_data_sigma_c)#nem_data_df = nem_data_df.fillna('NaN').T

# display nem_data_df as html using pandas df.to_html()
from IPython.core.display import display, HTML
display(HTML('<h4>NEM data for sigma_c </h4>'))
display(HTML(nem_data_sigma_c_s_df.to_html()))
# Out:
# <h4>NEM data for sigma_c </h4>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>borehole_code</th>
#       <th>laboratory</th>
#       <th>laboratory_test_code</th>
#       <th>lithology</th>
#       <th>sample_depth_top_m</th>
#       <th>value</th>
#       <th>value_unit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>NE1-01</td>
#       <td>KhonKaen University</td>
#       <td>4</td>
#       <td>Diorite</td>
#       <td>13.45-13.55</td>
#       <td>93.13</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>
td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>NE1-12</td>
#       <td>KhonKaen University</td>
#       <td>22</td>
#       <td>Granodiorite</td>
#       <td>87.15-87.25</td>
#       <td>117.59</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>NE1-12</td>
#       <td>KhonKaen University</td>
#       <td>23</td>
#       <td>Diorite</td>
#       <td>99.80-99.90</td>
#       <td>183.13</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>NE1-15</td>
#       <td>KhonKaen University</td>
#       <td>25</td>
#       <td>Diorite</td>
#       <td>29.40-29.50</td>
#       <td>193.52</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>NT1-1</td>
#       <td></td>
#       <td>56</td>
#       <td>Conglomerate</td>
#       <td>27.10</td>
#       <td>86.82</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>NT1-1</td>
#       <td></td>
#       <td>57</td>
#       <td>Conglomerate</td>
#       <td>61.50</td>
#       <td>75.15</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>NT1-11</td>
#       <td></td>
#       <td>70</td>
#       <td>Sandstone</td>
#       <td>15.65</td>
#       <td>85.02</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>NT1-14</td>
#       <td>KhonKaen University</td>
#       <td>52</td>
#       <td>Red Sandstone</td>
#       <td>28.90</td>
#       <td>128.55</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>NT1-14</td>
#       <td>KhonKaen University</td>
#       <td>51</td>
#       <td>Red Sandstone</td>
#       <td>28.90</td>
#       <td>127.17</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>NT1-14</td>
#       <td>KhonKaen University</td>
#       <td>50</td>
#       <td>Red Sandstone</td>
#       <td>28.90</td>
#       <td>90.54</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>NT1-14</td>
#       <td>KhonKaen University</td>
#       <td>33</td>

# %%
# remove records for sigma_c if no record for Es at the sample_depth
#   note that it is not checked if there are E values with no record for sigma_c at the sample_depth
# input: nem_data_sigma_c

nem_data_sigma_c_s_adj = []  # adjusted list
i=0

#for item in nem_data_sigma_c:
for item in nem_data_sigma_c:
    # check if a record exists with an E value at the sample_depth of the item
    # and append to the adjusted list if record exists 
    if any(d['sample_depth_top_m'] == (nem_data_sigma_c[i]['sample_depth_top_m']) for d in nem_data_es):
        #print nem_data_sigma_c[i]['borehole_code']
        nem_data_sigma_c_s_adj.append(item)
        i+=1
    else:
        i=1+i
        pass

# %%
# data report
#   report should also provide count information (see below "reference from Alan")
# input: nem_data_sigma_c_s_adj

nem_data_sigma_c_s_adj_df = pd.DataFrame(data=nem_data_sigma_c_s_adj)#nem_data_df = nem_data_df.fillna('NaN').T

# display nem_data_sigma_c_adj_df as html using pandas df.to_html()
from IPython.core.display import display, HTML
display(HTML('<h4>NEM data for sigma_c </h4>'))
display(HTML(nem_data_sigma_c_s_adj_df.to_html()))
# Out:
# <h4>NEM data for sigma_c </h4>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>borehole_code</th>
#       <th>laboratory</th>
#       <th>laboratory_test_code</th>
#       <th>lithology</th>
#       <th>sample_depth_top_m</th>
#       <th>value</th>
#       <th>value_unit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>NE1-01</td>
#       <td>KhonKaen University</td>
#       <td>10</td>
#       <td>Diorite</td>
#       <td>22.80-23.10</td>
#       <td>84.78</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>NE1-02</td>
#       <td>KhonKaen University</td>
#       <td>11</td>
#       <td>Diorite</td>
#       <td>19.80-20.00</td>
#       <td>153.5</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NE1-02</td>
#       <td>KhonKaen University</td>
#       <td>12</td>
#       <td>Pegmatite</td>
#       <td>25.15-25.25</td>
#       <td>211.63</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NE1-02</td>
#       <td>KhonKaen University</td>
#       <td>13</td>
#       <td>Diorite</td>
#       <td>28.80-28.90</td>
#       <td>167.37</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>NE1-03</td>
#       <td>KhonKaen University</td>
#       <td>14</td>
#       <td>Pegmatite</td>
#       <td>19.50-19.60</td>
#       <td>122.42</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>NE1-04</td>
#       <td>LTEC</td>
#       <td>26</td>
#       <td>Granodiorite</td>
#       <td>100.45-100.55</td>
#       <td>60.26</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>
td>
#       <td>Siltstone</td>
#       <td></td>
#       <td>50.75</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>NT1-A24</td>
#       <td>KhonKaen University</td>
#       <td>83</td>
#       <td>Siltstone</td>
#       <td></td>
#       <td>46.33</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>NT1-A25</td>
#       <td>KhonKaen University</td>
#       <td>85</td>
#       <td>Siltstone</td>
#       <td></td>
#       <td>40.88</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>NT1-A6</td>
#       <td>KhonKaen University</td>
#       <td>84</td>
#       <td>Siltstone</td>
#       <td></td>
#       <td>39.38</td>
#       <td>MPa</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>NT1-A?</td>
#       <td>KhonKaen University</td>
#       <td>82</td>
#       <td>Siltstone</td>
#       <td></td>
#       <td>56.97</td>
#       <td>MPa</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Plot histograms for Es, E50 data including a plot for only sandstone lithology data

# %%
# prepare Es values for histogram 
# input: nem_data_es

data_e=[]

for item in nem_data_es:
    data_e.append(float(item['value']))
    
print data_e
# Out:
# [12800.0, 18100.0, 29700.0, 18300.0, 5650.0, 5769.2, 2574.3, 8076.9, 14600.0, 13300.0, 16800.0, 30500.0, 22100.0, 3891.9, 6375.0, 10769.2, 8139.5, 21500.0, 15700.0, 30600.0, 19300.0, 14800.0, 19200.0, 4500.0, 6400.0, 8210.0, 5820.0, 7680.0, 10800.0, 5250.0, 6240.0, 3940.0, 6460.0, 4180.0, 4680.0, 8070.0]

# %%
# plot histogram of all E50 values
# input: data_e containing 'values' of 'parameter' E

import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
from scipy.stats import norm

# input: E containing 'values' of 'parameter' E
E = data_e

# plot histogram of E values for all rock lithologies
#   plt.hist(values, number of bins, additional named parameters)
hist,bin_edges,patches = plt.hist(E, 20, normed=1, facecolor='green', alpha=0.75)

# just guessing at distribution
#mu, sigma = 15000, 10000
#y = mlab.normpdf( bin_edges, mu, sigma)
#l = plt.plot(bin_edges, y, 'b--', linewidth=1)

# calculate distribution of E values using scipy
param = norm.fit(E) 
# now, param[0] and param[1] are the mean and the standard deviation of the fitted distribution
y = mlab.normpdf( bin_edges, param[0], param[1])
ll = plt.plot(bin_edges, y, 'r--', linewidth=1)

# plot axis labels and grid
plt.ylabel('Probability')
plt.xlabel('ALL LITHOLIGIES E-Modulus Es (MPa)')
plt.grid(True)
plt.show()

print(param[0])  # mean
print(param[1])  # standard deviation
len(E) # one more check

# Note that we really need to introduce a skewed distribution
# Out:
# 11966.0
# 7802.12297718
# 36

# %%
# prepare E50 values for histogram 
# input: nem_data_e50

data_e=[]

for item in nem_data_e50:
    data_e.append(float(item['value']))
    
#print data_e
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-30-cf9e35f16a43> in <module>()
#       5
#       6 for item in nem_data_e50:
# ----> 7     data_e.append(float(item['value']))
#       8
#       9 #print data_e
#
# ValueError: could not convert string to float:

# %%
# plot histogram of all E50 values
# input: data_e containing 'values' of 'parameter' E

E = data_e

# plot histogram of E values for all rock lithologies
hist,bin_edges,patches = plt.hist(E, 20, normed=1, facecolor='green', alpha=0.75)

# calculating distribution of E values using scipy
param = norm.fit(E) 
y = mlab.normpdf( bin_edges, param[0], param[1])
ll = plt.plot(bin_edges, y, 'r--', linewidth=1)

# plot axis labels and grid
plt.ylabel('Probability')
plt.xlabel('ALL LITHOLIGIES E-Modulus E50 (MPa)')
plt.grid(True)
plt.show()

print(param[0])  # mean
print(param[1])  # standard deviation
len(E) # one more check

# %%
# prepare lithology data to select sandstone lithologes for histogram 
# input: nem_data_e50

data_lithology=[]

for item in nem_data_e50:   
    data_lithology.append(item['lithology'])

#print data_lithology
print len(data_lithology)

# %%
# prepare E50 values for sandstone for histogram 
# input: nem_data_e50
#        data_lithology

sandstone_i=[]
sandstone_E=[]

# select E values where 'lithology' is Sandstone
for i in range(0,len(data_lithology)):
    if data_lithology[i]=='Sandstone':
        sandstone_i.append(i)
        #print i, data_lithology[i]
        sandstone_E.append(float(nem_data_e50[i]['value']))
        #print nem_data_e50[i]['lithology']

print(sandstone_i)
print(sandstone_E)

# %%
# plot histogram of all E50 values for sandstone 
# input: sandstone_E containing 'values' of 'parameter' E for sandstone

# plot histogram for E values of Sandstones
n, bins, patches = plt.hist(sandstone_E, 20, normed=1, facecolor='orange', alpha=0.75)
#n, bins, patches = plt.hist(sandstone_E, 20,facecolor='orange', alpha=0.75)
#   without 'normed=1', don't get sensible distribution fit

# calculating distribution with data using scipy
param = norm.fit(sandstone_E) 
# now, param[0] and param[1] are the mean and 
# the standard deviation of the fitted distribution
y = mlab.normpdf( bins, param[0], param[1])
ll = plt.plot(bins, y, 'r--', linewidth=1)

plt.ylabel('Probability')
plt.xlabel('SANDSTONE E-Modulus E50 (MPa)')
plt.grid(True)
plt.show()

print(param[0])
print(param[1])
len(sandstone_E)

# %% [markdown]
# ## Scatterplot of E50 vs sigma_c data

# %%
# prepare sigma_c values for scatterplot 
# input: nem_data_sigma-c

data_sigma_c=[]

for item in nem_data_sigma_c_s_adj:
    data_sigma_c.append(item['value'])
    
#print data_sigma_c
print len(data_sigma_c)

# %%
# check data and prepare scatterplot

# check number or records same for all data lists
print(len(data_e))
print(len(data_sigma_c))   
print(len(data_lithology))

# assign colors to lithologies for use in scatterplot
colors=[]
for i in range(0,len(data_lithology)):
    if data_lithology[i]=='Sandstone':
        colors.append('orange')
    elif data_lithology[i]=='Diorite':
        colors.append('black')
    elif data_lithology[i]=='Pegmatite':
        colors.append('blue')
    elif data_lithology[i]=='Granodiorite':
        colors.append('gray')
    elif data_lithology[i]=='Sericite':
        colors.append('green')
    else:
        colors.append('red')
        
#print(colors)

# %%
# scatterplot of E50 against sigma_c for all rock lithologies
# input: data_e, data_sigma_c containing 'values' of 'parameter' E and sigma_c
#        colors containg list of colors for lithologies in records (colors previously assigned lithologies)

from matplotlib.lines import Line2D

# scatterplot
rock_plot=plt.scatter([data_e],[data_sigma_c],color=colors,marker='^')

# legend
sym1 = Line2D([0], [0], linestyle="none", marker="^", alpha=1.0, color="orange")
sym2 = Line2D([0], [0], linestyle="none", marker="^", alpha=1.0, color="black")
sym3 = Line2D([0], [0], linestyle="none", marker="^", alpha=1.0, color="blue")
sym4 = Line2D([0], [0], linestyle="none", marker="^", alpha=1.0, color="gray")
sym5 = Line2D([0], [0], linestyle="none", marker="^", alpha=1.0, color="green")
plt.legend((sym1,sym2,sym3,sym4,sym5),("Sandstone","Diorite","Pegmatite","Granodiorite","Sericite"),
           numpoints=1,loc="best")

# axis labels
plt.ylabel('sigma_c (MPa)')
plt.xlabel('E-Modulus[E50] (MPa)')
plt.plot((2000,20000,40000,60000),(10,100,200,300), color="gray")

# a reference trend line
plt.annotate("200:1",xy=(50000,250),xytext=(50000,285),rotation=35)

plt.show()
