# %%
# setup sparqlwrapper

from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd
import geopandas as gpd

import sys
if sys.version_info[0] < 3: 
    from StringIO import StringIO
else:
    from io import StringIO

# %%
# 'alignment_ontology.p2.ttl'
sparql = SPARQLWrapper("http://34.76.178.181:3031/ds/query")
sparql.setMethod('GET')
sparql.setQuery("""
     PREFIX geo:        <http://www.opengis.net/ont/geosparql#>
     PREFIX sf:         <http://www.opengis.net/ont/sf#>
     PREFIX schema:     <https://schema.topografical.org/>
     
     SELECT 
            # ?point ?code (strafter(str(?wkt),'>') AS ?wkt_)
     WHERE {
           # ?point a  sf:Point.  
           # ?point geo:asWKT ?wkt.
           # ?point schema:hasPointCode ?code
           }     
""")
sparql.setReturnFormat('csv')
results = sparql.query().convert()

# %%
results_df = pd.read_csv(StringIO(results))
pd.set_option('display.max_colwidth', 200)

results_df
# Out:
#   point       code                            wkt_
# 0  _:b0        BEG   POINT(8.780072 47.154579 890)
# 1  _:b1        END   POINT(8.811266 47.194275 410)
# 2  _:b2  TEST_9999   POINT(47.194275 8.811266 410)
# 3  _:b3   bh_depth   POINT(8.798864 47.175901 900)

# %%
# from shapely import wkt
# results_df['Coordinates'] = results_df['wkt_'].apply(wkt.loads)
# geo_results_df = gpd.GeoDataFrame(results_df, geometry='Coordinates')

# %%
from shapely import wkt
results_df['Coordinates'] = results_df['wkt_'].apply(wkt.loads)
geo_results_df = gpd.GeoDataFrame(results_df, geometry='Coordinates', crs={'init':'epsg:4326'})

# WKT format is x,y -> long,lat 
# since the TDB data is CRS84, it is long,lat, defining crs as epsg:4326 (WGS84) is therefore required

# %%
geo_results_df_LV95 = geo_results_df.to_crs(epsg=2056)  #Swiss LV95 CRS

# %%
geo_results_df_LV95
# Out:
#   point       code                            wkt_  \
# 0  _:b0        BEG   POINT(8.780072 47.154579 890)
# 1  _:b1        END   POINT(8.811266 47.194275 410)
# 2  _:b2  TEST_9999   POINT(47.194275 8.811266 410)
# 3  _:b3   bh_depth   POINT(8.798864 47.175901 900)
#
#                                                         Coordinates
# 0   POINT Z (2701726.641154907 1223492.277107534 842.1823477949947)
# 1   POINT Z (2704014.763008328 1227945.768788799 362.3179863644764)
# 2  POINT Z (7611094.994633947 -1878131.224156877 622.4722905177623)
# 3   POINT Z (2703110.473296562 1225886.944396708 852.2572804633528)

# %%
geo_results_df_LV95.distance(geo_results_df_LV95.shift()) #ok, same values as checked below
# Out:
# 0             NaN
# 1    5.006904e+03
# 2    5.807508e+06
# 3    5.807172e+06
# dtype: float64

# %%
geo_results_df_LV95["Northing"] = geo_results_df_LV95.Coordinates.y
geo_results_df_LV95["Easting"] = geo_results_df_LV95.Coordinates.x
geo_results_df_LV95['Elevation'] = geo_results_df_LV95.apply(lambda q: q['Coordinates'].z, axis=1)  #ok
geo_results_df_LV95
# Out:
#   point       code                            wkt_  \
# 0  _:b0        BEG   POINT(8.780072 47.154579 890)
# 1  _:b1        END   POINT(8.811266 47.194275 410)
# 2  _:b2  TEST_9999   POINT(47.194275 8.811266 410)
# 3  _:b3   bh_depth   POINT(8.798864 47.175901 900)
#
#                                                         Coordinates  \
# 0   POINT Z (2701726.641154907 1223492.277107534 842.1823477949947)
# 1   POINT Z (2704014.763008328 1227945.768788799 362.3179863644764)
# 2  POINT Z (7611094.994633947 -1878131.224156877 622.4722905177623)
# 3   POINT Z (2703110.473296562 1225886.944396708 852.2572804633528)
#
#        Northing       Easting   Elevation
# 0  1.223492e+06  2.701727e+06  842.182348
# 1  1.227946e+06  2.704015e+06  362.317986
# 2 -1.878131e+06  7.611095e+06  622.472291
# 3  1.225887e+06  2.703110e+06  852.257280

# %%
# testing sparql update
# using 'alignment_ontology.p2.ttl'

# %%
sparql = SPARQLWrapper("http://34.76.178.181:3031/ds/update")
sparql.setMethod('POST')  #POST method required for updating
sparql.setQuery("""
     PREFIX rdfs:    <http://www.w3.org/2000/01/rdf-schema#>                                           
     PREFIX geo:        <http://www.opengis.net/ont/geosparql#>
     ##PREFIX sf:         <http://www.opengis.net/ont/sf#>
     PREFIX schema:     <https://schema.topografical.org/>
     PREFIX alignments: <https://data.topografical.org/alignments/>                                     

  INSERT DATA { 
    alignments:NamHydro_Headrace                                                                                    
      schema:hasAlignmentPoint  [    
        ##a  sf:Point ;
        a schema:AlignmentPoint ;                                                                               
        schema:hasPointId 99.0 ;                                                                                 
        schema:hasPointCode "TEST_9999" ;                                                                             
        geo:asWKT                                                                                               
        #  "<http://www.opengis.net/def/crs/OGC/1.3/CRS84> POINT(8.780999 47.154999 999)"^^geo:wktLiteral ;
        "<http://www.opengis.net/def/crs/EPSG/0/4326> POINT(47.194275 8.811266 410)"^^geo:wktLiteral ; 
        rdfs:comment "upstream end of Headrace at Intake sill centerline" ] .                       
        } 
""")
sparql.query()

# %%
sparql = SPARQLWrapper("http://34.76.178.181:3031/ds/query")
sparql.setMethod('GET')
sparql.setQuery("""
     PREFIX rdfs:    <http://www.w3.org/2000/01/rdf-schema#>                                           
     PREFIX geo:        <http://www.opengis.net/ont/geosparql#>
     PREFIX schema:     <https://schema.topografical.org/>
     PREFIX alignments: <https://data.topografical.org/alignments/>                                     
     PREFIX sf:         <http://www.opengis.net/ont/sf#>

     SELECT ?s ?code ?point ?comment ?type
        
     WHERE {
          # ?s ?p schema:AlignmentPoint .
          # ?s schema:hasPointCode ?code .
          # ?s geo:asWKT ?point .
          # ?s rdfs:comment ?comment .
          # ?s a ?type .
        }     
""")

sparql.setReturnFormat('csv')
results = sparql.query().convert()

# %%
results_update_df = pd.read_csv(StringIO(results))
pd.set_option('display.max_colwidth', 200)

results_update_df
# Out:
#         s       code  \
# 0    _:b0  TEST_9999
# 1    _:b1  TEST_9999
# 2    _:b2   TEST_999
# 3    _:b3        BEG
# 4    _:b3        BEG
# 5    _:b3        BEG
# 6    _:b3        BEG
# 7    _:b3        BEG
# 8    _:b4  TEST_9999
# 9    _:b5  TEST_9999
# 10   _:b6     TEST_1
# 11   _:b7    TEST_99
# 12   _:b8  TEST_9999
# 13   _:b9    TEST_99
# 14  _:b10  TEST_9999
# 15  _:b11  TEST_9999
# 16  _:b12  TEST_9999
# 17  _:b13  TEST_9999
# 18  _:b13  TEST_9999
# 19  _:b14  TEST_9999
# 20  _:b14  TEST_9999
# 21  _:b15  TEST_9999
# 22  _:b16  TEST_9999
# 23  _:b17        END
# 24  _:b17        END
# 25  _:b17        END
# 26  _:b17        END
# 27  _:b17        END
# 28  _:b18  TEST_9999
#
#                                                                            point  \
# 0   <http://www.opengis.net/def/crs/OGC/1.3/CRS84> POINT(8.780999 47.154999 999)
# 1     <http://www.opengis.net/def/crs/EPSG/0/4326> POINT(47.194275 8.811266 410)
# 2   <http://www.opengis.net/def/crs/OGC/1.3/CRS84> POINT(8.780999 47.154999 999)
# 3   <http://www.opengis.net/def/crs/OGC/1.3/CRS84> POINT(8.780072 47.154579 890)
# 4   <http://www.opengis.net/def/crs/OGC/1.3/CRS84> POINT(8.780072 47.154579 890)
# 5   <http://www.opengis.net/def/crs/OGC/1.3/CRS84> POINT(8.780072 47.154579 890)
# 6   <http://www.opengis.net/def/crs/OGC/1.3/CRS84> POINT(8.780072 47.154579 890)
# 7   <http://www.opengis.net/def/crs/OGC/1.3/CRS84> POINT(8.780072 47.154579 890)
# 8     <http://www.opengis.net/def/crs/EPSG/0/4326> POINT(47.194275 8.811266 410)
# 9     <http://www.opengis.net/def/crs/EPSG/0/4326> POINT(47.194275 8.811266 410)
# 10  <http://www.opengis.net/def/crs/OGC/1.3/CRS84> POINT(8.780072 47.154579 890)
# 11  <http://www.opengis.net/def/crs/OGC/1.3/CRS84> POINT(8.780999 47.154999 999)
# 12  <http://www.opengis.net/def/crs/OGC/1.3/CRS84> POINT(8.780999 47.154999 999)
# 13  <http://www.opengis.net/def/crs/OGC/1.3/CRS84> POINT(8.780072 47.154579 890)
# 14  <http://www.opengis.net/def/crs/OGC/1.3/CRS84> POINT(8.780999 47.154999 999)
# 15  <http://www.opengis.net/def/crs/OGC/1.3/CRS84> POINT(8.780999 47.154999 999)
# 16  <http://www.opengis.net/def/crs/OGC/1.3/CRS84> POINT(8.780999 47.154999 999)
# 17    <http://www.opengis.net/def/crs/EPSG/0/4326> POINT(47.194275 8.811266 410)
# 18    <http://www.opengis.net/def/crs/EPSG/0/4326> POINT(47.194275 8.811266 410)
# 19    <http://www.opengis.net/def/crs/EPSG/0/4326> POINT(47.194275 8.811266 410)
# 20    <http://www.opengis.net/def/crs/EPSG/0/4326> POINT(47.194275 8.811266 410)
# 21  <http://www.opengis.net/def/crs/OGC/1.3/CRS84> POINT(8.780999 47.154999 999)
# 22  <http://www.opengis.net/def/crs/OGC/1.3/CRS84> POINT(8.780999 47.154999 999)
# 23  <http://www.opengis.net/def/crs/OGC/1.3/CRS84> POINT(8.811266 47.194275 410)
# 24  <http://www.opengis.net/def/crs/OGC/1.3/CRS84> POINT(8.811266 47.194275 410)
# 25  <http://www.opengis.net/def/crs/OGC/1.3/CRS84> POINT(8.811266 47.194275 410)
# 26  <http://www.opengis.net/def/crs/OGC/1.3/CRS84> POINT(8.811266 47.194275 410)
# 27  <http://www.opengis.net/def/crs/OGC/1.3/CRS84> POINT(8.811266 47.194275 410)
# 28    <http://www.opengis.net/def/crs/EPSG/0/4326> POINT(47.194275 8.811266 410)
#
#                                                comment  \
# 0   upstream end of Headrace at Intake sill centerline
# 1   upstream end of Headrace at Intake sill centerline
# 2   upstream end of Headrace at Intake sill centerline
# 3   upstream end of Headrace at Intake sill centerline
# 4   upstream end of Headrace at Intake sill centerline
# 5   upstream end of Headrace at Intake sill centerline
# 6   upstream end of Headrace at Intake sill centerline
# 7   upstream end of Headrace at Intake sill centerline
# 8   upstream end of Headrace at Intake sill centerline
# 9   upstream end of Headrace at Intake sill centerline
# 10  upstream end of Headrace at Intake sill centerline
# 11  upstream end of Headrace at Intake sill centerline
# 12  upstream end of Headrace at Intake sill centerline
# 13  upstream end of Headrace at Intake sill centerline
# 14  upstream end of Headrace at Intake sill centerline
# 15  upstream end of Headrace at Intake sill centerline
# 16  upstream end of Headrace at Intake sill centerline
# 17  upstream end of Headrace at Intake sill centerline
# 18  upstream end of Headrace at Intake sill centerline
# 19  upstream end of Headrace at Intake sill centerline
# 20  upstream end of Headrace at Intake sill centerline
# 21  upstream end of Headrace at Intake sill centerline
# 22  upstream end of Headrace at Intake sill centerline
# 23        downstream end of Headrace at MIV to turbine
# 24        downstream end of Headrace at MIV to turbine
# 25        downstream end of Headrace at MIV to turbine
# 26        downstream end of Headrace at MIV to turbine
# 27        downstream end of Headrace at MIV to turbine
# 28  upstream end of Headrace at Intake sill centerline
#
#                                                   type
# 0       https://schema.topografical.org/AlignmentPoint
# 1       https://schema.topografical.org/AlignmentPoint
# 2       https://schema.topografical.org/AlignmentPoint
# 3                  http://www.opengis.net/ont/sf#Point
# 4       https://schema.topografical.org/AlignmentPoint
# 5        http://www.opengis.net/ont/geosparql#Geometry
# 6   http://www.opengis.net/ont/geosparql#SpatialObject
# 7        http://www.w3.org/2000/01/rdf-schema#Resource
# 8       https://schema.topografical.org/AlignmentPoint
# 9       https://schema.topografical.org/AlignmentPoint
# 10      https://schema.topografical.org/AlignmentPoint
# 11      https://schema.topografical.org/AlignmentPoint
# 12      https://schema.topografical.org/AlignmentPoint
# 13      https://schema.topografical.org/AlignmentPoint
# 14      https://schema.topografical.org/AlignmentPoint
# 15      https://schema.topografical.org/AlignmentPoint
# 16      https://schema.topografical.org/AlignmentPoint
# 17      https://schema.topografical.org/AlignmentPoint
# 18                 http://www.opengis.net/ont/sf#Point
# 19      https://schema.topografical.org/AlignmentPoint
# 20                 http://www.opengis.net/ont/sf#point
# 21      https://schema.topografical.org/AlignmentPoint
# 22      https://schema.topografical.org/AlignmentPoint
# 23  http://www.opengis.net/ont/geosparql#SpatialObject
# 24                 http://www.opengis.net/ont/sf#Point
# 25       http://www.w3.org/2000/01/rdf-schema#Resource
# 26       http://www.opengis.net/ont/geosparql#Geometry
# 27      https://schema.topografical.org/AlignmentPoint
# 28      https://schema.topografical.org/AlignmentPoint

# %%
# GeoSARPQL test with "surface-model-test.ttl" (from ifc data)
#   ./bin/geosparql-fuseki --port 3033 --loopback False -rf "surface-model-test_a.ttl" -i true

# %%
sparql = SPARQLWrapper("http://34.76.178.181:3033/ds/query")
sparql.setMethod('GET')
sparql.setQuery("""
        PREFIX ifcowl4: <http://www.buildingsmart-tech.org/ifcOWL/IFC4_ADD1#>
        SELECT ?point ?x_coord ?y_coord    
        WHERE {
          # ?point a  ifcowl4:IfcCartesianPoint.  
          # ?point ifcowl4:coordinates_IfcCartesianPoint ?list.
          # ?list <https://w3id.org/list#hasNext> ?nextlist.
          # ?list <https://w3id.org/list#hasContents> ?contents.
          # ?nextlist <https://w3id.org/list#hasContents> ?nextcontents.
          # ?contents <https://w3id.org/express#hasDouble> ?x_coord.
          # ?nextcontents <https://w3id.org/express#hasDouble> ?y_coord.
        }
        LIMIT 1000
""")
sparql.setReturnFormat('csv')
results = sparql.query().convert()

# %%
results_df = pd.read_csv(StringIO(results))
pd.set_option('display.max_colwidth', 200)

results_df
# Out:
#                                                                                point  \
# 0  http://linkedbuildingdata.net/ifc/resources20190405_103214/IfcCartesianPoint_1201
# 1  http://linkedbuildingdata.net/ifc/resources20190405_103214/IfcCartesianPoint_1202
# 2  http://linkedbuildingdata.net/ifc/resources20190405_103214/IfcCartesianPoint_1207
# 3   http://linkedbuildingdata.net/ifc/resources20190405_103214/IfcCartesianPoint_901
# 4  http://linkedbuildingdata.net/ifc/resources20190405_103214/IfcCartesianPoint_1208
# 5  http://linkedbuildingdata.net/ifc/resources20190405_103214/IfcCartesianPoint_1003
# 6  http://linkedbuildingdata.net/ifc/resources20190405_103214/IfcCartesianPoint_1205
# 7  http://linkedbuildingdata.net/ifc/resources20190405_103214/IfcCartesianPoint_1203
# 8  http://linkedbuildingdata.net/ifc/resources20190405_103214/IfcCartesianPoint_1206
# 9  http://linkedbuildingdata.net/ifc/resources20190405_103214/IfcCartesianPoint_1204
#
#    x_coord  y_coord
# 0   -500.0   -500.0
# 1    500.0   -500.0
# 2    500.0    500.0
# 3      0.0      0.0
# 4   -500.0    500.0
# 5   1000.0      0.0
# 6   -500.0   -500.0
# 7    500.0    500.0
# 8    500.0   -500.0
# 9   -500.0    500.0
