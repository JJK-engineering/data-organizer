# %%
#!sudo pip install --upgrade pixiedust

# %%
# set up python ecosystem
import json
from math import *
import pandas as pd
import numpy as np
from IPython.core.display import HTML, display
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from scipy.stats import norm
from scipy.stats import lognorm
from scipy import stats

import pixiedust
from pixiedust.display import *
# Out:
# Pixiedust database opened successfully
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-watson-data-lab/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-watson-data-lab/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 1.1.10</span>
#         </div>

# %%
# set maximum number of rows to display from a pandas data frame
pd.set_option('display.max_rows', 5000)
pd.set_option('display.max_columns', 50)

# %%
#datafile = 'data/Rogun/2018.05.20.Grouting_Data.csv'
datafile = 'data/SM2/2018.05.RockParameters.SM2.csv'

# rename column Source.1 to Source_2  # !!!

# %%
#df = pd.read_csv(datafile, names=names)
#data_df = pd.read_csv(datafile, parse_dates=True, dayfirst=True)
data_df = pd.read_csv(datafile, dayfirst=True)
print(data_df.count())
data_df = data_df.dropna(subset=['UCS_avg_2'])     #drop all rows that have any NaN values
print(data_df.count())
# Out:
# ID                   14
# Source               14
# Rock Unit            14
# Rock Unit Code       14
# Rock Type            14
# chainage             14
# UCS_min              14
# UCS_max              14
# UCS_avg              14
# GSI_min              14
# GSI_max              14
# GSI_avg              14
# GW_inflow             0
# GW_pressure           0
# sigma_ratio           0
# SRF                   0
# sta_top               0
# sta_bottom            0
# azimuth               0
# dip                   0
# Risk Situations       0
# SM classification     0
# SM ground rating      0
# Excv. Class           0
# Source_2              9
# UCS_avg_2             9
# E_intact              9
# MR                    9
# GSI_avg_2             9
# UCS_m                 9
# E_m                   9
# sigma_t               9
# UCS_ratio             9
# E_ratio               9
# dtype: int64
# ID                   9
# Source               9
# Rock Unit            9
# Rock Unit Code       9
# Rock Type            9
# chainage             9
# UCS_min              9
# UCS_max              9
# UCS_avg              9
# GSI_min              9
# GSI_max              9
# GSI_avg              9
# GW_inflow            0
# GW_pressure          0
# sigma_ratio          0
# SRF                  0
# sta_top              0
# sta_bottom           0
# azimuth              0
# dip                  0
# Risk Situations      0
# SM classification    0
# SM ground rating     0
# Excv. Class          0
# Source_2             9
# UCS_avg_2            9
# E_intact             9
# MR                   9
# GSI_avg_2            9
# UCS_m                9
# E_m                  9
# sigma_t              9
# UCS_ratio            9
# E_ratio              9
# dtype: int64

# %%
data_df
#data_df.head()
# Out:
#     ID                         Source               Rock Unit Rock Unit Code  \
# 0    1  Feasibility Study Report 2017  Kellys Plain Volcanics            Dkv
# 1    2  Feasibility Study Report 2017    Tantangara Formation          Syn-I
# 2    3  Feasibility Study Report 2017    Tantangara Formation         Syn-II
# 4    5  Feasibility Study Report 2017    Temperance Formation         Oitd-I
# 6    7  Feasibility Study Report 2017    Boggy Plains Granite         Dgk2-I
# 8    9  Feasibility Study Report 2017      Gooandra Volcanics         Oigl-I
# 10  11  Feasibility Study Report 2017        Shaw Hill Gabbro            Og5
# 12  13  Feasibility Study Report 2017             Ravine Beds         Ss2-II
# 13  14  Feasibility Study Report 2017             Ravine Beds          Ss2-I
#
#                                             Rock Type              chainage  \
# 0                              dacite, rhyolite, tuff                 0–600
# 1                         sandstone, siltstone, shale              600–3000
# 2                         sandstone, siltstone, shale             3000–7740
# 4                                tuff, chert, arenite             7740–9850
# 6                                             granite  8100–8300, 8850–9330
# 8   basalt pillow lava, rhyolite, schist, sandston...            9850–14250
# 10                        gabbro, diorite, pyroxenite           14250–14700
# 12                        shale, siltstone, sandstone           15100-16200
# 13                        shale, siltstone, sandstone           16200–26300
#
#     UCS_min  UCS_max  UCS_avg  GSI_min  GSI_max  GSI_avg  GW_inflow  \
# 0        80      200      120       55       70       60        NaN
# 1        20      100       50       20       55       40        NaN
# 2        50      100       65       35       55       45        NaN
# 4        80      150      100       40       70       65        NaN
# 6        80      150      100       40       70       65        NaN
# 8        60      200      120       45       75       65        NaN
# 10       75      150      100       40       70       60        NaN
# 12       20       60       35       20       40       35        NaN
# 13       60      200      100       35       70       50        NaN
#
#     GW_pressure  sigma_ratio  SRF  sta_top  sta_bottom  azimuth  dip  \
# 0           NaN          NaN  NaN      NaN         NaN      NaN  NaN
# 1           NaN          NaN  NaN      NaN         NaN      NaN  NaN
# 2           NaN          NaN  NaN      NaN         NaN      NaN  NaN
# 4           NaN          NaN  NaN      NaN         NaN      NaN  NaN
# 6           NaN          NaN  NaN      NaN         NaN      NaN  NaN
# 8           NaN          NaN  NaN      NaN         NaN      NaN  NaN
# 10          NaN          NaN  NaN      NaN         NaN      NaN  NaN
# 12          NaN          NaN  NaN      NaN         NaN      NaN  NaN
# 13          NaN          NaN  NaN      NaN         NaN      NaN  NaN
#
#     Risk Situations  SM classification  SM ground rating  Excv. Class  \
# 0               NaN                NaN               NaN          NaN
# 1               NaN                NaN               NaN          NaN
# 2               NaN                NaN               NaN          NaN
# 4               NaN                NaN               NaN          NaN
# 6               NaN                NaN               NaN          NaN
# 8               NaN                NaN               NaN          NaN
# 10              NaN                NaN               NaN          NaN
# 12              NaN                NaN               NaN          NaN
# 13              NaN                NaN               NaN          NaN
#
#                        Source_2  UCS_avg_2  E_intact     MR  GSI_avg_2  UCS_m  \
# 0   Pells Sullivan Meynink 2018       80.0   32000.0  400.0       75.0   20.0
# 1   Pells Sullivan Meynink 2018       50.0   12500.0  250.0       60.0    5.0
# 2   Pells Sullivan Meynink 2018       50.0   12500.0  250.0       60.0    5.0
# 4   Pells Sullivan Meynink 2018      100.0   35000.0  350.0       80.0   33.0
# 6   Pells Sullivan Meynink 2018      100.0   42500.0  425.0       80.0   33.0
# 8   Pells Sullivan Meynink 2018       50.0   19000.0  380.0       60.0    5.0
# 10  Pells Sullivan Meynink 2018       80.0   36000.0  450.0       60.0    9.0
# 12  Pells Sullivan Meynink 2018       80.0   24000.0  300.0       60.0    9.0
# 13  Pells Sullivan Meynink 2018       80.0   24000.0  300.0       60.0    9.0
#
#         E_m  sigma_t  UCS_ratio  E_ratio
# 0   26000.0      0.5        0.3      0.8
# 1    6500.0      0.2        0.1      0.5
# 2    6500.0      0.2        0.1      0.5
# 4   31000.0      1.1        0.3      0.9
# 6   37000.0      0.7        0.3      0.9
# 8   10000.0      0.1        0.1      0.5
# 10  19000.0      0.1        0.1      0.5
# 12  12500.0      0.3        0.1      0.5
# 13  12500.0      0.3        0.1      0.5

# %%
data_sel_df = data_df[
['ID','Source','Rock Unit','Rock Unit Code','Rock Type','UCS_min','UCS_max','UCS_avg',
 'GSI_min','GSI_max','GSI_avg','Source_2','UCS_avg_2','E_intact','MR','GSI_avg_2','UCS_m','E_m',
 'sigma_t','UCS_ratio','E_ratio']
]

#data_sel_df

# %%
import sys
reload(sys)
sys.setdefaultencoding('utf8')

# %%
display(data_sel_df)  #pixiedustinspections = pixiedust.sampleData display
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#             Snowy Mountains 2.0 PSP
#         </div>
#     <div id="chartFigure6ab409bc" class="pd_save is-viewer-good" style="overflow-x:auto">
#
#
#                             <center><img style="max-width:initial !important" src="data:image/png;base64,..." class="pd_save"></center>
#
#
#                         <div>Filtered option clusterby with value Hole. Reason Cluster By value is already used in keys or values for this chart</div>
#
#
#         </div>
