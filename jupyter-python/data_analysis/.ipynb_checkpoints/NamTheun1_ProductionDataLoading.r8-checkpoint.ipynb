# %% [markdown]
# # Production Data Loading
#
#  1. Access Couchbase Database
#  1. Load CSV files and convert into JSON structure
#  1. Store the JSON data in Couchbase

# %% [markdown]
# ## Access Couchbase Database
#
#   * Created new Couchbase _bucket_ called _geotechnical_ using the Couchbase web browser interface

# %%
from couchbase.bucket import Bucket
cb = Bucket('couchbase://localhost/geotechnical')  # If no errors then the access works

# %% [markdown]
# ## Load CSV Data

# %%
# modified JK 2017.06.22

import json

from GeopyUtils import CsvDataReader

##projects_cdr = CsvDataReader('project', 'data/NEM/projects.csv')
##projects = projects_cdr.read()

##borehole_cdr = CsvDataReader('borehole', 'data/NEM/boreholes.csv')
##boreholes = borehole_cdr.read()

# data folder moved to  
parameter_cdr = CsvDataReader('parameter', 
                    '/home/kaelin_joseph/projects/NT1/data/in/2018.10.04.NT1.DataOrganiser.Parameters.R8.csv')
parameters = parameter_cdr.read()

print "Record counts: "
##print "  projects:   " + str(len(projects))
##print "  boreholes:  " + str(len(boreholes))
print "  parameters: " + str(len(parameters))
##print "TOTAL: "+str(len(projects)+len(boreholes)+len(parameters))
##print "\nExample JSON data: project[0]"
##print json.dumps(projects[0], indent=2)

##print "\nExample JSON data: borehole[0]"
##print json.dumps(boreholes[0], indent=2)

print "\nExample JSON data: parameters[180]"
print json.dumps(parameters[180], indent=2)
# Out:
# Record counts:
#   parameters: 375
#
# Example JSON data: parameters[180]
# {
#   "sample_description": "Basic Design",
#   "sample_state": "",
#   "measurement_convention": "",
#   "test_standard": "ASTM D7012 D",
#   "sample_code": "11",
#   "test_parameters": [
#     {
#       "units": "",
#       "description": "",
#       "value": ""
#     },
#     {
#       "units": "",
#       "description": "",
#       "value": ""
#     }
#   ],
#   "laboratory": "",
#   "test_comment": "",
#   "sample_orientation": "80",
#   "project_code": "NT1.r6",
#   "type": "parameter",
#   "laboratory_test_code": "62",
#   "test_type": "Uniaxial compression",
#   "value_scale": "Laboratory",
#   "id": "parameter-20181004-122935-46014883",
#   "parameter": "sigma_c",
#   "revision": "r6",
#   "lithology": "Conglomerate",
#   "sample_depth_top_m": "39.25",
#   "input_id": "185",
#   "value_likelihood": "Data point",
#   "data_source": "Laboratory",
#   "borehole_code": "NT1-6",
#   "value": "113.55",
#   "test_date": "",
#   "value_unit": "MPa"
# }

# %% [markdown]
# # Store in Couchbase
#
#  * Only run this once!
#  * Then comment out the *cb.insert* statement

# %%
from couchbase.bucket import Bucket
cb = Bucket('couchbase://localhost/geotechnical')

def load_records(records):
    for record in records:
        id = record['id']
        cb.upsert(id,record)  # DISABLED!!!
        print "record: "+id+" ..inserted"

##print "\nLoading: projects"
##load_records(projects)

##print "\nLoading: boreholes"
##load_records(boreholes)

print "\nLoading: parameters"
load_records(parameters)
# Out:
# Loading: parameters
# record: parameter-20181004-122935-85955669 ..inserted
# record: parameter-20181004-122935-05333161 ..inserted
# record: parameter-20181004-122935-93013391 ..inserted
# record: parameter-20181004-122935-47464760 ..inserted
# record: parameter-20181004-122935-77772547 ..inserted
# record: parameter-20181004-122935-50860633 ..inserted
# record: parameter-20181004-122935-81375417 ..inserted
# record: parameter-20181004-122935-19340063 ..inserted
# record: parameter-20181004-122935-60778191 ..inserted
# record: parameter-20181004-122935-11375988 ..inserted
# record: parameter-20181004-122935-38464526 ..inserted
# record: parameter-20181004-122935-87481788 ..inserted
# record: parameter-20181004-122935-78733157 ..inserted
# record: parameter-20181004-122935-75914558 ..inserted
# record: parameter-20181004-122935-99615078 ..inserted
# record: parameter-20181004-122935-31074455 ..inserted
# record: parameter-20181004-122935-75120452 ..inserted
# record: parameter-20181004-122935-54111931 ..inserted
# record: parameter-20181004-122935-05281261 ..inserted
# record: parameter-20181004-122935-26715276 ..inserted
# record: parameter-20181004-122935-13800086 ..inserted
# record: parameter-20181004-122935-92937141 ..inserted
# record: parameter-20181004-122935-66244487 ..inserted
# record: parameter-20181004-122935-11409212 ..inserted
# record: parameter-20181004-122935-06670314 ..inserted
# record: parameter-20181004-122935-83545665 ..inserted
# record: parameter-20181004-122935-41154383 ..inserted
# record: parameter-20181004-122935-23148798 ..inserted
# record: parameter-20181004-122935-91218321 ..inserted
# record: parameter-20181004-122935-30509929 ..inserted
# record: parameter-20181004-122935-49055186 ..inserted
# record: parameter-20181004-122935-35894273 ..inserted
# record: parameter-20181004-122935-02264606 ..inserted
# record: parameter-20181004-122935-17848210 ..inserted
# record: parameter-20181004-122935-87234382 ..inserted
# record: parameter-20181004-122935-99569387 ..inserted
# record: parameter-20181004-122935-90645966 ..inserted
# record: parameter-20181004-122935-06172987 ..inserted
# record: parameter-20181004-122935-87771526 ..inserted
# record: parameter-20181004-122935-60802687 ..inserted
# record: parameter-20181004-122935-88927103 ..inserted
# record: parameter-20181004-122935-13269851 ..inserted
# record: parameter-20181004-122935-78646867 ..inserted
# record: parameter-20181004-122935-48227618 ..inserted
# record: parameter-20181004-122935-83065195 ..inserted
# record: parameter-20181004-122935-84170419 ..inserted
# record: parameter-20181004-122935-02046915 ..inserted
# record: parameter-20181004-122935-57525454 ..inserted
# record: parameter-20181004-122935-62483803 ..inserted
# record: parameter-20181004-122935-04482627 ..inserted
# record: parameter-20181004-122935-26920638 ..inserted
# record: parameter-20181004-122935-74850820 ..inserted
# record: parameter-20181004-122935-01005174 ..inserted
# record: parameter-20181004-122935-19435595 ..inserted
# record: parameter-20181004-122935-65809875 ..inserted
# record: parameter-20181004-122935-53990493 ..inserted
# record: parameter-20181004-122935-36497751 ..inserted
# record: parameter-20181004-122935-40540056 ..inserted
# record: parameter-20181004-122935-99573390 ..inserted
# record: parameter-20181004-122935-24212421 ..inserted
# record: parameter-20181004-122935-81072399 ..inserted
# record: parameter-20181004-122935-19271811 ..inserted
# record: parameter-20181004-122935-43783530 ..inserted
# record: parameter-20181004-122935-04379198 ..inserted
# record: parameter-20181004-122935-79196008 ..inserted
# record: parameter-20181004-122935-48711803 ..inserted
# record: parameter-20181004-122935-54392769 ..inserted
# record: parameter-20181004-122935-74545158 ..inserted
# record: parameter-20181004-122935-02221483 ..inserted
# record: parameter-20181004-122935-96871413 ..inserted
# record: parameter-20181004-122935-65378964 ..inserted
# record: parameter-20181004-122935-77817061 ..inserted
# record: parameter-20181004-122935-40488579 ..inserted
# record: parameter-20181004-122935-38121934 ..inserted
# record: parameter-20181004-122935-15611930 ..inserted
# record: parameter-20181004-122935-19941183 ..inserted
# record: parameter-20181004-122935-17831318 ..inserted
# record: parameter-20181004-122935-36882502 ..inserted
# record: parameter-20181004-122935-57250334 ..inserted
# record: parameter-20181004-122935-13139470 ..inserted
# record: parameter-20181004-122935-39112391 ..inserted
# record: parameter-20181004-122935-13736802 ..inserted
# record: parameter-20181004-122935-06346262 ..inserted
# record: parameter-20181004-122935-63618318 ..inserted
# record: parameter-20181004-122935-93002860 ..inserted
# record: parameter-20181004-122935-48692813 ..inserted
# record: parameter-20181004-122935-15485624 ..inserted
# record: parameter-20181004-122935-21384872 ..inserted
# record: parameter-20181004-122935-86575195 ..inserted
# record: parameter-20181004-122935-91973627 ..inserted
# record: parameter-20181004-122935-39359735 ..inserted
# record: parameter-20181004-122935-34433416 ..inserted
# record: parameter-20181004-122935-99434961 ..inserted
# record: parameter-20181004-122935-33940658 ..inserted
# record: parameter-20181004-122935-88306807 ..inserted
# record: parameter-20181004-122935-19376561 ..inserted
# record: parameter-20181004-122935-77681793 ..inserted
# record: parameter-20181004-122935-74628801 ..inserted
# record: parameter-20181004-122935-17611810 ..inserted
# record: parameter-20181004-122935-69670673 ..inserted
# record: parameter-20181004-122935-41379288 ..inserted
# record: parameter-20181004-122935-09864961 ..inserted
# record: parameter-20181004-122935-92309738 ..inserted
# record: parameter-20181004-122935-50841806 ..inserted
# record: parameter-20181004-122935-45807281 ..inserted
# record: parameter-20181004-122935-67460119 ..inserted
# record: parameter-20181004-122935-77508614 ..inserted
# record: parameter-20181004-122935-25548163 ..inserted
# record: parameter-20181004-122935-12522693 ..inserted
# record: parameter-20181004-122935-46728522 ..inserted
# record: parameter-20181004-122935-70781579 ..inserted
# record: parameter-20181004-122935-14065905 ..inserted
# record: parameter-20181004-122935-59958316 ..inserted
# record: parameter-20181004-122935-40818028 ..inserted
# record: parameter-20181004-122935-34423846 ..inserted
# record: parameter-20181004-122935-23341345 ..inserted
# record: parameter-20181004-122935-11600443 ..inserted
# record: parameter-20181004-122935-13834364 ..inserted
# record: parameter-20181004-122935-52781304 ..inserted
# record: parameter-20181004-122935-57490198 ..inserted
# record: parameter-20181004-122935-66247103 ..inserted
# record: parameter-20181004-122935-09368371 ..inserted
# record: parameter-20181004-122935-07786460 ..inserted
# record: parameter-20181004-122935-03876213 ..inserted
# record: parameter-20181004-122935-68967535 ..inserted
# record: parameter-20181004-122935-84875584 ..inserted
# record: parameter-20181004-122935-43686425 ..inserted
# record: parameter-20181004-122935-96479220 ..inserted
# record: parameter-20181004-122935-15710023 ..inserted
# record: parameter-20181004-122935-39435753 ..inserted
# record: parameter-20181004-122935-78826008 ..inserted
# record: parameter-20181004-122935-17554657 ..inserted
# record: parameter-20181004-122935-10679385 ..inserted
# record: parameter-20181004-122935-48930160 ..inserted
# record: parameter-20181004-122935-15097290 ..inserted
# record: parameter-20181004-122935-49961488 ..inserted
# record: parameter-20181004-122935-54005806 ..inserted
# record: parameter-20181004-122935-81416706 ..inserted
# record: parameter-20181004-122935-40295499 ..inserted
# record: parameter-20181004-122935-58683363 ..inserted
# record: parameter-20181004-122935-89578960 ..inserted
# record: parameter-20181004-122935-34125136 ..inserted
# record: parameter-20181004-122935-49506149 ..inserted
# record: parameter-20181004-122935-25319050 ..inserted
# record: parameter-20181004-122935-28197059 ..inserted
# record: parameter-20181004-122935-79839226 ..inserted
# record: parameter-20181004-122935-96948809 ..inserted
# record: parameter-20181004-122935-21425833 ..inserted
# record: parameter-20181004-122935-27411184 ..inserted
# record: parameter-20181004-122935-81772655 ..inserted
# record: parameter-20181004-122935-61605800 ..inserted
# record: parameter-20181004-122935-06815024 ..inserted
# record: parameter-20181004-122935-59189587 ..inserted
# record: parameter-20181004-122935-18088075 ..inserted
# record: parameter-20181004-122935-94585709 ..inserted
# record: parameter-20181004-122935-49925754 ..inserted
# record: parameter-20181004-122935-45907089 ..inserted
# record: parameter-20181004-122935-91740932 ..inserted
# record: parameter-20181004-122935-58498993 ..inserted
# record: parameter-20181004-122935-83542574 ..inserted
# record: parameter-20181004-122935-57248771 ..inserted
# record: parameter-20181004-122935-04212810 ..inserted
# record: parameter-20181004-122935-94522045 ..inserted
# record: parameter-20181004-122935-68374794 ..inserted
# record: parameter-20181004-122935-22421225 ..inserted
# record: parameter-20181004-122935-44172369 ..inserted
# record: parameter-20181004-122935-98199695 ..inserted
# record: parameter-20181004-122935-49465880 ..inserted
# record: parameter-20181004-122935-32193638 ..inserted
# record: parameter-20181004-122935-40428460 ..inserted
# record: parameter-20181004-122935-74286004 ..inserted
# record: parameter-20181004-122935-90220755 ..inserted
# record: parameter-20181004-122935-97378721 ..inserted
# record: parameter-20181004-122935-88389461 ..inserted
# record: parameter-20181004-122935-85143688 ..inserted
# record: parameter-20181004-122935-73053992 ..inserted
# record: parameter-20181004-122935-04014436 ..inserted
# record: parameter-20181004-122935-22916983 ..inserted
# record: parameter-20181004-122935-78234016 ..inserted
# record: parameter-20181004-122935-82007816 ..inserted
# record: parameter-20181004-122935-46014883 ..inserted
# record: parameter-20181004-122935-41217758 ..inserted
# record: parameter-20181004-122935-85170142 ..inserted
# record: parameter-20181004-122935-76692642 ..inserted
# record: parameter-20181004-122935-37064772 ..inserted
# record: parameter-20181004-122935-72684276 ..inserted
# record: parameter-20181004-122935-84620107 ..inserted
# record: parameter-20181004-122935-39601214 ..inserted
# record: parameter-20181004-122935-35646379 ..inserted
# record: parameter-20181004-122935-57016861 ..inserted
# record: parameter-20181004-122935-44301952 ..inserted
# record: parameter-20181004-122935-75041863 ..inserted
# record: parameter-20181004-122935-88722395 ..inserted
# record: parameter-20181004-122935-04279309 ..inserted
# record: parameter-20181004-122935-05393984 ..inserted
# record: parameter-20181004-122935-74031288 ..inserted
# record: parameter-20181004-122935-19733175 ..inserted
# record: parameter-20181004-122935-51401416 ..inserted
# record: parameter-20181004-122935-14478871 ..inserted
# record: parameter-20181004-122935-36607570 ..inserted
# record: parameter-20181004-122935-40508138 ..inserted
# record: parameter-20181004-122935-05385103 ..inserted
# record: parameter-20181004-122935-41198470 ..inserted
# record: parameter-20181004-122935-22938409 ..inserted
# record: parameter-20181004-122935-71365614 ..inserted
# record: parameter-20181004-122935-68685006 ..inserted
# record: parameter-20181004-122935-32444963 ..inserted
# record: parameter-20181004-122935-95279163 ..inserted
# record: parameter-20181004-122935-53998499 ..inserted
# record: parameter-20181004-122935-46059091 ..inserted
# record: parameter-20181004-122935-03399212 ..inserted
# record: parameter-20181004-122935-67168318 ..inserted
# record: parameter-20181004-122935-08127088 ..inserted
# record: parameter-20181004-122935-55539176 ..inserted
# record: parameter-20181004-122935-44771930 ..inserted
# record: parameter-20181004-122935-16979458 ..inserted
# record: parameter-20181004-122935-38490978 ..inserted
# record: parameter-20181004-122935-88592194 ..inserted
# record: parameter-20181004-122935-26736759 ..inserted
# record: parameter-20181004-122935-87306977 ..inserted
# record: parameter-20181004-122935-99254323 ..inserted
# record: parameter-20181004-122935-05355919 ..inserted
# record: parameter-20181004-122935-29584898 ..inserted
# record: parameter-20181004-122935-30062362 ..inserted
# record: parameter-20181004-122935-50720988 ..inserted
# record: parameter-20181004-122935-35123500 ..inserted
# record: parameter-20181004-122935-90601649 ..inserted
# record: parameter-20181004-122935-59375123 ..inserted
# record: parameter-20181004-122935-75897823 ..inserted
# record: parameter-20181004-122935-78294170 ..inserted
# record: parameter-20181004-122935-55533774 ..inserted
# record: parameter-20181004-122935-26076479 ..inserted
# record: parameter-20181004-122935-64219599 ..inserted
# record: parameter-20181004-122935-80134714 ..inserted
# record: parameter-20181004-122935-21763464 ..inserted
# record: parameter-20181004-122935-05871892 ..inserted
# record: parameter-20181004-122935-37181062 ..inserted
# record: parameter-20181004-122935-92042307 ..inserted
# record: parameter-20181004-122935-70283996 ..inserted
# record: parameter-20181004-122935-67676176 ..inserted
# record: parameter-20181004-122935-28834871 ..inserted
# record: parameter-20181004-122935-32033272 ..inserted
# record: parameter-20181004-122935-56508770 ..inserted
# record: parameter-20181004-122935-91915159 ..inserted
# record: parameter-20181004-122935-66515493 ..inserted
# record: parameter-20181004-122935-72342580 ..inserted
# record: parameter-20181004-122935-10153802 ..inserted
# record: parameter-20181004-122935-42458981 ..inserted
# record: parameter-20181004-122935-75959693 ..inserted
# record: parameter-20181004-122935-33446747 ..inserted
# record: parameter-20181004-122935-00498992 ..inserted
# record: parameter-20181004-122935-72475367 ..inserted
# record: parameter-20181004-122935-62083065 ..inserted
# record: parameter-20181004-122935-90016206 ..inserted
# record: parameter-20181004-122935-87181513 ..inserted
# record: parameter-20181004-122935-84333571 ..inserted
# record: parameter-20181004-122935-74731266 ..inserted
# record: parameter-20181004-122935-62586835 ..inserted
# record: parameter-20181004-122935-51540961 ..inserted
# record: parameter-20181004-122935-65204955 ..inserted
# record: parameter-20181004-122935-25451210 ..inserted
# record: parameter-20181004-122935-11716178 ..inserted
# record: parameter-20181004-122935-67302746 ..inserted
# record: parameter-20181004-122935-07201393 ..inserted
# record: parameter-20181004-122935-41522084 ..inserted
# record: parameter-20181004-122935-34469295 ..inserted
# record: parameter-20181004-122935-85864673 ..inserted
# record: parameter-20181004-122935-83513180 ..inserted
# record: parameter-20181004-122935-37368018 ..inserted
# record: parameter-20181004-122935-91415684 ..inserted
# record: parameter-20181004-122935-13475867 ..inserted
# record: parameter-20181004-122935-54766395 ..inserted
# record: parameter-20181004-122935-71571901 ..inserted
# record: parameter-20181004-122935-11645449 ..inserted
# record: parameter-20181004-122935-19890673 ..inserted
# record: parameter-20181004-122935-89736868 ..inserted
# record: parameter-20181004-122935-58770330 ..inserted
# record: parameter-20181004-122935-31368807 ..inserted
# record: parameter-20181004-122935-95688418 ..inserted
# record: parameter-20181004-122935-25171143 ..inserted
# record: parameter-20181004-122935-43384026 ..inserted
# record: parameter-20181004-122935-65118511 ..inserted
# record: parameter-20181004-122935-23713704 ..inserted
# record: parameter-20181004-122935-77772576 ..inserted
# record: parameter-20181004-122935-59447283 ..inserted
# record: parameter-20181004-122935-69239330 ..inserted
# record: parameter-20181004-122935-31087646 ..inserted
# record: parameter-20181004-122935-69224202 ..inserted
# record: parameter-20181004-122935-18062067 ..inserted
# record: parameter-20181004-122935-73771663 ..inserted
# record: parameter-20181004-122935-09529671 ..inserted
# record: parameter-20181004-122935-77563028 ..inserted
# record: parameter-20181004-122935-06042053 ..inserted
# record: parameter-20181004-122935-63275816 ..inserted
# record: parameter-20181004-122935-05709938 ..inserted
# record: parameter-20181004-122935-14744116 ..inserted
# record: parameter-20181004-122935-92664998 ..inserted
# record: parameter-20181004-122935-21845917 ..inserted
# record: parameter-20181004-122935-27072700 ..inserted
# record: parameter-20181004-122935-47871199 ..inserted
# record: parameter-20181004-122935-28698976 ..inserted
# record: parameter-20181004-122935-40365279 ..inserted
# record: parameter-20181004-122935-63903423 ..inserted
# record: parameter-20181004-122935-22015140 ..inserted
# record: parameter-20181004-122935-87706415 ..inserted
# record: parameter-20181004-122935-88312078 ..inserted
# record: parameter-20181004-122935-89094447 ..inserted
# record: parameter-20181004-122935-05054374 ..inserted
# record: parameter-20181004-122935-54951017 ..inserted
# record: parameter-20181004-122935-11223529 ..inserted
# record: parameter-20181004-122935-54498586 ..inserted
# record: parameter-20181004-122935-24939892 ..inserted
# record: parameter-20181004-122935-62078752 ..inserted
# record: parameter-20181004-122935-45698683 ..inserted
# record: parameter-20181004-122935-42456973 ..inserted
# record: parameter-20181004-122935-97353814 ..inserted
# record: parameter-20181004-122935-54111496 ..inserted
# record: parameter-20181004-122935-87958421 ..inserted
# record: parameter-20181004-122935-32214159 ..inserted
# record: parameter-20181004-122935-92643441 ..inserted
# record: parameter-20181004-122935-80504471 ..inserted
# record: parameter-20181004-122935-32596350 ..inserted
# record: parameter-20181004-122935-85731504 ..inserted
# record: parameter-20181004-122935-49413903 ..inserted
# record: parameter-20181004-122935-87958123 ..inserted
# record: parameter-20181004-122935-74759378 ..inserted
# record: parameter-20181004-122935-89296580 ..inserted
# record: parameter-20181004-122935-17555304 ..inserted
# record: parameter-20181004-122935-54732142 ..inserted
# record: parameter-20181004-122935-74715891 ..inserted
# record: parameter-20181004-122935-16585335 ..inserted
# record: parameter-20181004-122935-63960885 ..inserted
# record: parameter-20181004-122935-13044327 ..inserted
# record: parameter-20181004-122935-51705965 ..inserted
# record: parameter-20181004-122935-74123768 ..inserted
# record: parameter-20181004-122935-37172834 ..inserted
# record: parameter-20181004-122935-89285034 ..inserted
# record: parameter-20181004-122935-85498577 ..inserted
# record: parameter-20181004-122935-59948334 ..inserted
# record: parameter-20181004-122935-11490840 ..inserted
# record: parameter-20181004-122935-24848034 ..inserted
# record: parameter-20181004-122935-35297994 ..inserted
# record: parameter-20181004-122935-69047129 ..inserted
# record: parameter-20181004-122935-99169738 ..inserted
# record: parameter-20181004-122935-97783579 ..inserted
# record: parameter-20181004-122935-68754018 ..inserted
# record: parameter-20181004-122935-22833183 ..inserted
# record: parameter-20181004-122935-90815792 ..inserted
# record: parameter-20181004-122935-50104545 ..inserted
# record: parameter-20181004-122935-47100037 ..inserted
# record: parameter-20181004-122935-54736534 ..inserted
# record: parameter-20181004-122935-57247040 ..inserted
# record: parameter-20181004-122935-84667360 ..inserted
# record: parameter-20181004-122935-38631600 ..inserted
# record: parameter-20181004-122935-35646007 ..inserted
# record: parameter-20181004-122935-46543360 ..inserted
# record: parameter-20181004-122935-14305907 ..inserted
# record: parameter-20181004-122935-25311693 ..inserted
# record: parameter-20181004-122935-91833536 ..inserted
# record: parameter-20181004-122935-98906885 ..inserted
# record: parameter-20181004-122935-46504449 ..inserted
# record: parameter-20181004-122935-14055047 ..inserted
# record: parameter-20181004-122935-77961330 ..inserted
# record: parameter-20181004-122935-59775027 ..inserted
# record: parameter-20181004-122935-89681406 ..inserted
# record: parameter-20181004-122935-09044209 ..inserted
# record: parameter-20181004-122935-32150999 ..inserted
# record: parameter-20181004-122935-41146234 ..inserted
# record: parameter-20181004-122935-89957562 ..inserted
# record: parameter-20181004-122935-50360685 ..inserted
# record: parameter-20181004-122935-18122599 ..inserted
# record: parameter-20181004-122935-63554598 ..inserted
# record: parameter-20181004-122935-37406091 ..inserted
# record: parameter-20181004-122935-51486128 ..inserted
# record: parameter-20181004-122935-71881637 ..inserted

# %% [markdown]
# # Read Some Data

# %% [markdown]
# ## Create Default Index
#
#  * Required for querying. If you don't do this you get an error when you run queries
#  * Required when adding additional data ??  --> presumed not required !!!  (for NT1.r4 not done)
#  * This should only be run once. Note yet sure how to ensure that happend
#  * For now, run it once and then comment out the *cb.n1ql_query* statement

# %%
from couchbase.bucket import Bucket

# create a primary index on geotechnical bucket in couchbase
cb = Bucket('couchbase://localhost/geotechnical')
##cb.n1ql_query('CREATE PRIMARY INDEX ON geotechnical').execute()  # TODO this should only be run one time!
# running above query gave HTTPError: ... http_status=500. Primry Index was however created (couchbase browser).

# %%
import json

# check new data stored
from DataOrganizer import CouchbaseSelector

# -- Open the database

db = CouchbaseSelector('localhost','geotechnical')

##fields = ['parameter', 'type', 'value', 'value_unit']
##where = {'project_code':'NT1', 'type': 'parameter', 'parameter': 'E','data_source': 'Laboratory'}
##db.getParameter(parameter_name, fields, where)

recs = []
for rec in db.select(None, None):
# comment out following line for checking data before uploading
# uncomment for uploading
##for rec in db.select(fields, where):
    print json.dumps(rec, indent=2)
    recs.append(rec)
    
print json.dumps(recs[0],indent=2)
print "\nTotal records: "+str(len(recs))
# Out:
# {
#   "geotechnical": {
#     "borehole_code": "NE1-05",
#     "collar_elevation_masl": "",
#     "y_project_coordinate": "1721741.8",
#     "x_project_coordinate": "712184.8",
#     "type": "borehole",
#     "id": "borehole-20170622-174516-05582985"
#   }
# }
# {
#   "geotechnical": {
#     "borehole_code": "NE1-12",
#     "collar_elevation_masl": "",
#     "y_project_coordinate": "1719777.5",
#     "x_project_coordinate": "717089.3",
#     "type": "borehole",
#     "id": "borehole-20170622-174516-11300620"
#   }
# }
# {
#   "geotechnical": {
#     "borehole_code": "NE1-08",
#     "collar_elevation_masl": "",
#     "y_project_coordinate": "1708099.92",
#     "x_project_coordinate": "716316.28",
#     "type": "borehole",
#     "id": "borehole-20170622-174516-23912291"
#   }
# }
# {
#   "geotechnical": {
#     "borehole_code": "NE1-07",
#     "collar_elevation_masl": "",
#     "y_project_coordinate": "1722689",
#     "x_project_coordinate": "711228.7",
#     "type": "borehole",
#     "id": "borehole-20170622-174516-27653986"
#   }
# }
# {
#   "geotechnical": {
#     "borehole_code": "NE1-10a",
#     "collar_elevation_masl": "",
#     "y_project_coordinate": "1708049.1",
#     "x_project_coordinate": "716348.7",
#     "type": "borehole",
#     "id": "borehole-20170622-174516-32247481"
#   }
# }
# {
#   "geotechnical": {
#     "borehole_code": "NE1-02",
#     "collar_elevation_masl": "",
#     "y_project_coordinate": "1720937.67",
#     "x_project_coordinate": "717213.76",
#     "type": "borehole",
#     "id": "borehole-20170622-174516-36599884"
#   }
# }
# {
#   "geotechnical": {
#     "borehole_code": "NE1-06",
#     "collar_elevation_masl": "",
#     "y_project_coordinate": "",
#     "x_project_coordinate": "",
#     "type": "borehole",
#     "id": "borehole-20170622-174516-37573956"
#   }
# }
# {
#   "geotechnical": {
#     "borehole_code": "NE1-01",
#     "collar_elevation_masl": "",
#     "y_project_coordinate": "1720999.33",
#     "x_project_coordinate": "717190.06",
#     "type": "borehole",
#     "id": "borehole-20170622-174516-39266317"
#   }
# }
# {
#   "geotechnical": {
#     "borehole_code": "NE1-14",
#     "collar_elevation_masl": "",
#     "y_project_coordinate": "1719738.4",
#     "x_project_coordinate": "717507.3",
#     "type": "borehole",
#     "id": "borehole-20170622-174516-40630348"
#   }
# }
# {
#   "geotechnical": {
#     "borehole_code": "NE1-13",
#     "collar_elevation_masl": "",
#     "y_project_coordinate": "1719550.5",
#     "x_project_coordinate": "716495.7",
#     "type": "borehole",
#     "id": "borehole-20170622-174516-48544201"
#   }
# }
# {
#   "geotechnical": {
#     "borehole_code": "NE1-15",
#     "collar_elevation_masl": "",
#     "y_project_coordinate": "1720916.13",
#     "x_project_coordinate": "717333.47",
#     "type": "borehole",
#     "id": "borehole-20170622-174516-48740477"
#   }
# }
# {
#   "geotechnical": {
#     "borehole_code": "NE1-11",
#     "collar_elevation_masl": "",
#     "y_project_coordinate": "1720838.8",
#     "x_project_coordinate": "717289.4",
#     "type": "borehole",
#     "id": "borehole-20170622-174516-60302042"
#   }
# }
# {
#   "geotechnical": {
#     "borehole_code": "NE1-03",
#     "collar_elevation_masl": "",
#     "y_project_coordinate": "1720882.06",
#     "x_project_coordinate": "717094.05",
#     "type": "borehole",
#     "id": "borehole-20170622-174516-66318427"
#   }
# }
# {
#   "geotechnical": {
#     "borehole_code": "NE1-04",
#     "collar_elevation_masl": "",
#     "y_project_coordinate": "1720943.4",
#     "x_project_coordinate": "713446.7",
#     "type": "borehole",
#     "id": "borehole-20170622-174516-66574135"
#   }
# }
# {
#   "geotechnical": {
#     "borehole_code": "NE1-09",
#     "collar_elevation_masl": "",
#     "y_project_coordinate": "1708082.75",
#     "x_project_coordinate": "716250.92",
#     "type": "borehole",
#     "id": "borehole-20170622-174516-85469632"
#   }
# }
# {
#   "geotechnical": {
#     "borehole_code": "NE1-10b",
#     "collar_elevation_masl": "",
#     "y_project_coordinate": "1708061.97",
#     "x_project_coordinate": "716360.1",
#     "type": "borehole",
#     "id": "borehole-20170622-174516-94840249"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "",
#     "test_standard": "ASTM 2166",
#     "laboratory": "LTEC",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE09",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "29",
#     "test_type": "Uniaxial compression",
#     "sample_description": "dry",
#     "id": "parameter-20170622-174516-01332636",
#     "type": "parameter",
#     "lithology": "Sericite",
#     "sample_depth_top_m": "19.15-19.25",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-09",
#     "value": "115.72",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "",
#     "test_standard": "",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "MPa",
#         "description": "s3",
#         "value": "1"
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE01-1",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "4",
#     "test_type": "Triaxial compression",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-01582750",
#     "type": "parameter",
#     "lithology": "Diorite",
#     "sample_depth_top_m": "13.45-13.55",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-01",
#     "value": "93.13",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "",
#     "test_standard": "ASTM 2166",
#     "laboratory": "LTEC",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE08",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "31",
#     "test_type": "Uniaxial compression",
#     "sample_description": "dry",
#     "id": "parameter-20170622-174516-01792118",
#     "type": "parameter",
#     "lithology": "Sericite",
#     "sample_depth_top_m": "16.3-16.45 ",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-08",
#     "value": "28.58",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "Es",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE07",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "17",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-03247360",
#     "type": "parameter",
#     "lithology": "Sandstone",
#     "sample_depth_top_m": "32.60-33.00",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-07",
#     "value": "13300",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE03",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "14",
#     "test_type": "Uniaxial compression",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-04690191",
#     "type": "parameter",
#     "lithology": "Pegmatite",
#     "sample_depth_top_m": "19.50-19.60",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-03",
#     "value": "122.42",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE12",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "21",
#     "test_type": "Uniaxial compression",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-05413451",
#     "type": "parameter",
#     "lithology": "Granodiorite",
#     "sample_depth_top_m": "34.05-34.20",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-12",
#     "value": "204.34",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "E50",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE07",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "19",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-06506482",
#     "type": "parameter",
#     "lithology": "Sandstone",
#     "sample_depth_top_m": "44.80-45.00",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-07",
#     "value": "44310",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE12",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "23",
#     "test_type": "Uniaxial compression",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-08514231",
#     "type": "parameter",
#     "lithology": "Diorite",
#     "sample_depth_top_m": "99.80-99.90",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-12",
#     "value": "183.13",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "E50",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE02",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "12",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-10001617",
#     "type": "parameter",
#     "lithology": "Pegmatite",
#     "sample_depth_top_m": "25.15-25.25",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-02",
#     "value": "52930",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "",
#     "test_standard": "ASTM 2166",
#     "laboratory": "LTEC",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE04",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "27",
#     "test_type": "Uniaxial compression",
#     "sample_description": "dry",
#     "id": "parameter-20170622-174516-10977084",
#     "type": "parameter",
#     "lithology": "Granodiorite",
#     "sample_depth_top_m": "24.1-24.25",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-04",
#     "value": "9.71",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "",
#     "test_standard": "",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "MPa",
#         "description": "s3",
#         "value": "1"
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE07-1",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "1",
#     "test_type": "Triaxial compression",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-11063381",
#     "type": "parameter",
#     "lithology": "Sandstone",
#     "sample_depth_top_m": "26.75-27.80",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-07",
#     "value": "140.66",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "Es",
#     "test_standard": "ASTM 2166",
#     "laboratory": "LTEC",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE04",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "26",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "dry",
#     "id": "parameter-20170622-174516-11720192",
#     "type": "parameter",
#     "lithology": "Granodiorite",
#     "sample_depth_top_m": "100.45-100.55",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-04",
#     "value": "5769.2",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "Et",
#     "test_standard": "ASTM 2166",
#     "laboratory": "LTEC",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE04",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "26",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "dry",
#     "id": "parameter-20170622-174516-12987005",
#     "type": "parameter",
#     "lithology": "Granodiorite",
#     "sample_depth_top_m": "100.45-100.55",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-04",
#     "value": "8475",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "Es",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE02",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "12",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-13476027",
#     "type": "parameter",
#     "lithology": "Pegmatite",
#     "sample_depth_top_m": "25.15-25.25",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-02",
#     "value": "29700",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "Es",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE07",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "15",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-13644660",
#     "type": "parameter",
#     "lithology": "Sandstone",
#     "sample_depth_top_m": "28.00-28.25",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-07",
#     "value": "14600",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "Es",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE03",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "14",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-14605015",
#     "type": "parameter",
#     "lithology": "Pegmatite",
#     "sample_depth_top_m": "19.50-19.60",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-03",
#     "value": "5650",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE07",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "17",
#     "test_type": "Uniaxial compression",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-19326049",
#     "type": "parameter",
#     "lithology": "Sandstone",
#     "sample_depth_top_m": "32.60-33.00",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-07",
#     "value": "134.33",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "E50",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE02",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "11",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-19616714",
#     "type": "parameter",
#     "lithology": "Diorite",
#     "sample_depth_top_m": "19.80-20.00",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-02",
#     "value": "24630",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "Es",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE07",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "18",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-20164395",
#     "type": "parameter",
#     "lithology": "Sandstone",
#     "sample_depth_top_m": "34.05-34.20",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-07",
#     "value": "30500",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "Es",
#     "test_standard": "ASTM 2166",
#     "laboratory": "LTEC",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE08",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "31",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "dry",
#     "id": "parameter-20170622-174516-21963802",
#     "type": "parameter",
#     "lithology": "Sericite",
#     "sample_depth_top_m": "16.3-16.45 ",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-08",
#     "value": "3891.9",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "E50",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE07",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "15",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-23959907",
#     "type": "parameter",
#     "lithology": "Sandstone",
#     "sample_depth_top_m": "28.00-28.25",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-07",
#     "value": "21290",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "Es",
#     "test_standard": "ASTM 2166",
#     "laboratory": "LTEC",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE08",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "32",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "dry",
#     "id": "parameter-20170622-174516-24266828",
#     "type": "parameter",
#     "lithology": "Sericite",
#     "sample_depth_top_m": "24.25-25.37",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-08",
#     "value": "6375",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE07",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "18",
#     "test_type": "Uniaxial compression",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-26399717",
#     "type": "parameter",
#     "lithology": "Sandstone",
#     "sample_depth_top_m": "34.05-34.20",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-07",
#     "value": "153.02",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "Es",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE01",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "10",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-26523617",
#     "type": "parameter",
#     "lithology": "Diorite",
#     "sample_depth_top_m": "22.80-23.10",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-01",
#     "value": "12800",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "",
#     "test_standard": "",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "MPa",
#         "description": "s3",
#         "value": "5"
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE07-3",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "3",
#     "test_type": "Triaxial compression",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-27424226",
#     "type": "parameter",
#     "lithology": "Sandstone",
#     "sample_depth_top_m": "31.00-31.15",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-07",
#     "value": "215.07",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "",
#     "test_standard": "",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "MPa",
#         "description": "s3",
#         "value": "3"
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE02-2",
#     "test_comment": "Marked as wrong, to be repeated",
#     "project_code": "NEM",
#     "laboratory_test_code": "8",
#     "test_type": "Triaxial compression",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-28164635",
#     "type": "parameter",
#     "lithology": "Diorite",
#     "sample_depth_top_m": "23.00-23.70",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-02",
#     "value": "172.15",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "E50",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE02",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "13",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-28570457",
#     "type": "parameter",
#     "lithology": "Diorite",
#     "sample_depth_top_m": "28.80-28.90",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-02",
#     "value": "21560",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "Et",
#     "test_standard": "ASTM 2166",
#     "laboratory": "LTEC",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE09",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "29",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "dry",
#     "id": "parameter-20170622-174516-30875116",
#     "type": "parameter",
#     "lithology": "Sericite",
#     "sample_depth_top_m": "19.15-19.25",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-09",
#     "value": "14813.1",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE12",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "20",
#     "test_type": "Uniaxial compression",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-32939424",
#     "type": "parameter",
#     "lithology": "Granodiorite",
#     "sample_depth_top_m": "46.75-46.85",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-12",
#     "value": "268.27",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "",
#     "test_standard": "ASTM 2166",
#     "laboratory": "LTEC",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE08",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "32",
#     "test_type": "Uniaxial compression",
#     "sample_description": "dry",
#     "id": "parameter-20170622-174516-33514021",
#     "type": "parameter",
#     "lithology": "Sericite",
#     "sample_depth_top_m": "24.25-25.37",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-08",
#     "value": "41.28",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "Et",
#     "test_standard": "ASTM 2166",
#     "laboratory": "LTEC",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE09",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "30",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "dry",
#     "id": "parameter-20170622-174516-34260199",
#     "type": "parameter",
#     "lithology": "Sericite",
#     "sample_depth_top_m": "23.45-23.55",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-09",
#     "value": "11893.5",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "",
#     "test_standard": "",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "MPa",
#         "description": "s3",
#         "value": "3"
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE07-2",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "2",
#     "test_type": "Triaxial compression",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-34915031",
#     "type": "parameter",
#     "lithology": "Sandstone",
#     "sample_depth_top_m": "27.60-27.80",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-07",
#     "value": "151.22",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "E50",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE12",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "20",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-35375071",
#     "type": "parameter",
#     "lithology": "Granodiorite",
#     "sample_depth_top_m": "46.75-46.85",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-12",
#     "value": "71420",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE07",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "16",
#     "test_type": "Uniaxial compression",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-36513529",
#     "type": "parameter",
#     "lithology": "Sandstone",
#     "sample_depth_top_m": "32.60-33.00",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-07",
#     "value": "158.28",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE02",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "13",
#     "test_type": "Uniaxial compression",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-36933370",
#     "type": "parameter",
#     "lithology": "Diorite",
#     "sample_depth_top_m": "28.80-28.90",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-02",
#     "value": "167.37",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "Et",
#     "test_standard": "ASTM 2166",
#     "laboratory": "LTEC",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE08",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "32",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "dry",
#     "id": "parameter-20170622-174516-37971614",
#     "type": "parameter",
#     "lithology": "Sericite",
#     "sample_depth_top_m": "24.25-25.37",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-08",
#     "value": "9053.3",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE07",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "15",
#     "test_type": "Uniaxial compression",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-39429883",
#     "type": "parameter",
#     "lithology": "Sandstone",
#     "sample_depth_top_m": "28.00-28.25",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-07",
#     "value": "104.25",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "Es",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE07",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "19",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-41139440",
#     "type": "parameter",
#     "lithology": "Sandstone",
#     "sample_depth_top_m": "44.80-45.00",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-07",
#     "value": "22100",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "Es",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE12",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "24",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-41645070",
#     "type": "parameter",
#     "lithology": "Granodiorite",
#     "sample_depth_top_m": "33.40-33.50",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-12",
#     "value": "21500",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "Et",
#     "test_standard": "ASTM 2166",
#     "laboratory": "LTEC",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE04",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "27",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "dry",
#     "id": "parameter-20170622-174516-42645633",
#     "type": "parameter",
#     "lithology": "Granodiorite",
#     "sample_depth_top_m": "24.1-24.25",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-04",
#     "value": "4799.2",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "Es",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE02",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "11",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-44189476",
#     "type": "parameter",
#     "lithology": "Diorite",
#     "sample_depth_top_m": "19.80-20.00",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-02",
#     "value": "18100",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "E50",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE12",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "22",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-46972923",
#     "type": "parameter",
#     "lithology": "Granodiorite",
#     "sample_depth_top_m": "87.15-87.25",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-12",
#     "value": "20940",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "E50",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE07",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "16",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-47263802",
#     "type": "parameter",
#     "lithology": "Sandstone",
#     "sample_depth_top_m": "32.60-33.00",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-07",
#     "value": "20800",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE12",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "22",
#     "test_type": "Uniaxial compression",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-49356757",
#     "type": "parameter",
#     "lithology": "Granodiorite",
#     "sample_depth_top_m": "87.15-87.25",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-12",
#     "value": "117.59",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE02",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "11",
#     "test_type": "Uniaxial compression",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-51489069",
#     "type": "parameter",
#     "lithology": "Diorite",
#     "sample_depth_top_m": "19.80-20.00",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-02",
#     "value": "153.5",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE07",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "19",
#     "test_type": "Uniaxial compression",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-52980020",
#     "type": "parameter",
#     "lithology": "Sandstone",
#     "sample_depth_top_m": "44.80-45.00",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-07",
#     "value": "193.46",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "Es",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE07",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "16",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-53140229",
#     "type": "parameter",
#     "lithology": "Sandstone",
#     "sample_depth_top_m": "32.60-33.00",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-07",
#     "value": "16800",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "Es",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE15",
# ...
#     "sample_orientation": "10",
#     "project_code": "NT1.r6",
#     "laboratory_test_code": "",
#     "test_type": "Dilatometer",
#     "sample_description": "Basic Design",
#     "id": "parameter-20181003-092534-96958709",
#     "type": "parameter",
#     "revision": "r6",
#     "lithology": "Conglomerate",
#     "sample_depth_top_m": "62.00",
#     "input_id": "288",
#     "value_likelihood": "",
#     "parameter": "E",
#     "data_source": "Field",
#     "borehole_code": "NT1-6",
#     "value": "1800.00",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "sample_state": "",
#     "measurement_convention": "Peak strength",
#     "test_standard": "ASTM D5607-95",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "MPa",
#         "description": "s3",
#         "value": "0.50"
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "11",
#     "test_comment": "",
#     "sample_orientation": "80",
#     "project_code": "NT1.r6",
#     "laboratory_test_code": "",
#     "test_type": "Direct shear",
#     "sample_description": "Construction Design",
#     "id": "parameter-20181003-092534-97053238",
#     "type": "parameter",
#     "revision": "r6",
#     "lithology": "Siltstone",
#     "sample_depth_top_m": "20.30",
#     "input_id": "80",
#     "value_likelihood": "Data point",
#     "parameter": "tau",
#     "data_source": "Laboratory",
#     "borehole_code": "NT1-17",
#     "value": "0.57",
#     "test_date": "12.07.2017",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "sample_state": "",
#     "measurement_convention": "",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "21",
#     "test_comment": "",
#     "sample_orientation": "80",
#     "project_code": "NT1.r6",
#     "laboratory_test_code": "49",
#     "test_type": "Uniaxial compression",
#     "sample_description": "Construction Design",
#     "id": "parameter-20181003-092534-97157479",
#     "type": "parameter",
#     "revision": "r6",
#     "lithology": "Siltstone",
#     "sample_depth_top_m": "22.40",
#     "input_id": "214",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NT1-DL-01",
#     "value": "15.30",
#     "test_date": "13.05.2017",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "sample_state": "",
#     "measurement_convention": "E50",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "12",
#     "test_comment": "",
#     "sample_orientation": "80",
#     "project_code": "NT1.r6",
#     "laboratory_test_code": "60",
#     "test_type": "E measured during uniaxial compression",
#     "sample_description": "Basic Design",
#     "id": "parameter-20181003-092534-98220546",
#     "type": "parameter",
#     "revision": "r6",
#     "lithology": "Siltstone",
#     "sample_depth_top_m": "64.70",
#     "input_id": "182",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NT1-5",
#     "value": "1902.00",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "",
#     "sample_state": "",
#     "measurement_convention": "",
#     "test_standard": "",
#     "laboratory": "",
#     "test_parameters": [
#       {
#         "units": "MPa",
#         "description": "s_comp",
#         "value": "3.20"
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "11",
#     "test_comment": "",
#     "sample_orientation": "",
#     "project_code": "NT1.r6",
#     "laboratory_test_code": "",
#     "test_type": "Plate Bearing",
#     "sample_description": "Basic Design",
#     "id": "parameter-20181003-092534-98231095",
#     "type": "parameter",
#     "revision": "r6",
#     "lithology": "Siltstone",
#     "sample_depth_top_m": "14.00",
#     "input_id": "262",
#     "value_likelihood": "",
#     "parameter": "E",
#     "data_source": "Field",
#     "borehole_code": "NT1-LB-ExpAdit",
#     "value": "2880.00",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "sample_state": "",
#     "measurement_convention": "Mobilized residual friction angle",
#     "test_standard": "CEN ISO 17892-9",
#     "laboratory": "ETH Zurich",
#     "test_parameters": [
#       {
#         "units": "MPa",
#         "description": "s3",
#         "value": "0.10"
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "1",
#     "test_comment": "",
#     "sample_orientation": "",
#     "project_code": "NT1.r6",
#     "laboratory_test_code": "",
#     "test_type": "Triaxial compression",
#     "sample_description": "Construction Design",
#     "id": "parameter-20181003-092534-98432912",
#     "type": "parameter",
#     "revision": "r6",
#     "lithology": "Fault gauge SZ1",
#     "sample_depth_top_m": "",
#     "input_id": "369",
#     "value_likelihood": "Data point",
#     "parameter": "s_c",
#     "data_source": "Laboratory",
#     "borehole_code": "Adit_2",
#     "value": "25.10",
#     "test_date": "",
#     "value_unit": "Deg"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "sample_state": "",
#     "measurement_convention": "Peak strength",
#     "test_standard": "ASTM 5607",
#     "laboratory": "Asec Consultants Ltd.",
#     "test_parameters": [
#       {
#         "units": "MPa",
#         "description": "s3",
#         "value": "2.10"
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "6",
#     "test_comment": "",
#     "sample_orientation": "",
#     "project_code": "NT1.r6",
#     "laboratory_test_code": "",
#     "test_type": "Direct shear",
#     "sample_description": "Basic Design",
#     "id": "parameter-20181003-092534-98486091",
#     "type": "parameter",
#     "revision": "r6",
#     "lithology": "Siltstone",
#     "sample_depth_top_m": "103.30",
#     "input_id": "355",
#     "value_likelihood": "Data point",
#     "parameter": "tau",
#     "data_source": "Laboratory",
#     "borehole_code": "NT1-06",
#     "value": "3.19",
#     "test_date": "12.05.2015",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "sample_state": "",
#     "measurement_convention": "Peak strength",
#     "test_standard": "ASTM 5607",
#     "laboratory": "Asec Consultants Ltd.",
#     "test_parameters": [
#       {
#         "units": "MPa",
#         "description": "s3",
#         "value": "2.00"
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "1",
#     "test_comment": "",
#     "sample_orientation": "",
#     "project_code": "NT1.r6",
#     "laboratory_test_code": "",
#     "test_type": "Direct shear",
#     "sample_description": "Basic Design",
#     "id": "parameter-20181003-092534-98545132",
#     "type": "parameter",
#     "revision": "r6",
#     "lithology": "Grey Sandstone",
#     "sample_depth_top_m": "36.10",
#     "input_id": "319",
#     "value_likelihood": "Data point",
#     "parameter": "tau",
#     "data_source": "Laboratory",
#     "borehole_code": "NT1-01",
#     "value": "11.49",
#     "test_date": "01.04.2015",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "",
#     "sample_state": "Soaked",
#     "measurement_convention": "E50",
#     "test_standard": "",
#     "laboratory": "",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "11",
#     "test_comment": "",
#     "sample_orientation": "",
#     "project_code": "NT1.r6",
#     "laboratory_test_code": "",
#     "test_type": "E measured during uniaxial compression",
#     "sample_description": "Construction Design",
#     "id": "parameter-20181003-092534-98577883",
#     "type": "parameter",
#     "revision": "r6",
#     "lithology": "Grey Sandstone",
#     "sample_depth_top_m": "60.80",
#     "input_id": "163",
#     "value_likelihood": "",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NT1-24",
#     "value": "6080.00",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "",
#     "sample_state": "Soaked",
#     "measurement_convention": "",
#     "test_standard": "",
#     "laboratory": "",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "12",
#     "test_comment": "",
#     "sample_orientation": "",
#     "project_code": "NT1.r6",
#     "laboratory_test_code": "",
#     "test_type": "Uniaxial compression",
#     "sample_description": "Construction Design",
#     "id": "parameter-20181003-092534-98935853",
#     "type": "parameter",
#     "revision": "r6",
#     "lithology": "Grey Sandstone",
#     "sample_depth_top_m": "52.95",
#     "input_id": "165",
#     "value_likelihood": "",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NT1-22",
#     "value": "41.20",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "",
#     "sample_state": "",
#     "measurement_convention": "",
#     "test_standard": "",
#     "laboratory": "",
#     "test_parameters": [
#       {
#         "units": "MPa",
#         "description": "s_comp",
#         "value": "4.00"
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "31",
#     "test_comment": "",
#     "sample_orientation": "",
#     "project_code": "NT1.r6",
#     "laboratory_test_code": "",
#     "test_type": "Plate Bearing",
#     "sample_description": "Basic Design",
#     "id": "parameter-20181003-092534-99099017",
#     "type": "parameter",
#     "revision": "r6",
#     "lithology": "Grey Sandstone",
#     "sample_depth_top_m": "19.00",
#     "input_id": "272",
#     "value_likelihood": "",
#     "parameter": "E",
#     "data_source": "Field",
#     "borehole_code": "NT1-RB-ExpAdit",
#     "value": "4470.00",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "sample_state": "",
#     "measurement_convention": "",
#     "test_standard": "ASTM D7012 B",
#     "laboratory": "",
#     "test_parameters": [
#       {
#         "units": "MPa",
#         "description": "s3",
#         "value": "5.00"
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "16",
#     "test_comment": "",
#     "sample_orientation": "10",
#     "project_code": "NT1.r6",
#     "laboratory_test_code": "",
#     "test_type": "Triaxial compression",
#     "sample_description": "Basic Design",
#     "id": "parameter-20181003-092534-99215537",
#     "type": "parameter",
#     "revision": "r6",
#     "lithology": "Grey Sandstone",
#     "sample_depth_top_m": "125.55",
#     "input_id": "310",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NT1-6",
#     "value": "95.55",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "",
#     "sample_state": "Soaked",
#     "measurement_convention": "",
#     "test_standard": "",
#     "laboratory": "",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "11",
#     "test_comment": "",
#     "sample_orientation": "",
#     "project_code": "NT1.r6",
#     "laboratory_test_code": "",
#     "test_type": "Uniaxial compression",
#     "sample_description": "Construction Design",
#     "id": "parameter-20181003-092534-99243869",
#     "type": "parameter",
#     "revision": "r6",
#     "lithology": "Grey Sandstone",
#     "sample_depth_top_m": "52.55",
#     "input_id": "164",
#     "value_likelihood": "",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NT1-22",
#     "value": "28.65",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "",
#     "sample_state": "",
#     "measurement_convention": "",
#     "test_standard": "",
#     "laboratory": "",
#     "test_parameters": [
#       {
#         "units": "MPa",
#         "description": "s_comp",
#         "value": "3.20"
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "11",
#     "test_comment": "",
#     "sample_orientation": "",
#     "project_code": "NT1.r6",
#     "laboratory_test_code": "",
#     "test_type": "Plate Bearing",
#     "sample_description": "Basic Design",
#     "id": "parameter-20181003-092534-99674942",
#     "type": "parameter",
#     "revision": "r6",
#     "lithology": "Grey Sandstone",
#     "sample_depth_top_m": "15.00",
#     "input_id": "266",
#     "value_likelihood": "",
#     "parameter": "E",
#     "data_source": "Field",
#     "borehole_code": "NT1-RB-ExpAdit",
#     "value": "6040.00",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "sample_state": "",
#     "measurement_convention": "Peak strength",
#     "test_standard": "ASTM D3080",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "MPa",
#         "description": "s3",
#         "value": "0.40"
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "22",
#     "test_comment": "",
#     "sample_orientation": "",
#     "project_code": "NT1.r6",
#     "laboratory_test_code": "94",
#     "test_type": "Direct shear",
#     "sample_description": "Construction Design",
#     "id": "parameter-20181003-092534-99886482",
#     "type": "parameter",
#     "revision": "r6",
#     "lithology": "Fault Gauge SZ1",
#     "sample_depth_top_m": "57.80",
#     "input_id": "147",
#     "value_likelihood": "Data point",
#     "parameter": "tau",
#     "data_source": "Laboratory",
#     "borehole_code": "NT1-21",
#     "value": "0.29",
#     "test_date": "19.05.2017",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "project_code": "TAG",
#     "project_coordinate_system": "UTM",
#     "type": "project",
#     "id": "project-20170622-174516-10551702",
#     "name": "Tagoloan"
#   }
# }
# {
#   "geotechnical": {
#     "project_code": "NEM",
#     "project_coordinate_system": "UTM",
#     "type": "project",
#     "id": "project-20170622-174516-52956332",
#     "name": "Nam E-Moun"
#   }
# }
# {
#   "geotechnical": {
#     "project_code": "BUB",
#     "project_coordinate_system": "UTM",
#     "type": "project",
#     "id": "project-20170622-174516-72672078",
#     "name": "Bubunawan"
#   }
# }
# {
#   "geotechnical": {
#     "project_code": "NT1",
#     "project_coordinate_system": "UTM",
#     "type": "project",
#     "id": "project-20170622-174516-76927550",
#     "name": "Nam Theun 1"
#   }
# }
# {
#   "geotechnical": {
#     "borehole_code": "NE1-05",
#     "collar_elevation_masl": "",
#     "y_project_coordinate": "1721741.8",
#     "x_project_coordinate": "712184.8",
#     "type": "borehole",
#     "id": "borehole-20170622-174516-05582985"
#   }
# }
#
# Total records: 1563
