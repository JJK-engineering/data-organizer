# %%
# 2020.02.18 to 2020.02.27
#   v.01  2020.02.21
#   v.02  2020.02.26
# data analysis for ground anchors
# for ASTRA Thun

# %% [markdown]
# # description of anchor data analysis task
#
# 1) locate the authoritative data -> spreadsheets <br />
# 2) define the header for anchor measurement records (field names) <br />
# 3) link the spreadsheet data into the csv sheet format (following header) <br />
# 4) acquire the spreadsheet CSV data with Pandas (with basic data checking) <br />
# 5) set up agreed data analysis procedures -> will be limited in this phase <br />
# 6) set up interactive plotting for exploring anchor data (as protype) <br />
# 7) produce agreed plots for initial presentation purposes <br />
#
# Based on initial data review, new spreadsheets with corrected and more complete data were provided. Task 3) was therefore repeated.

# %% [markdown]
# # to do
# * rename 'anchor_load_char' to 'anchor_failure_load_char'
# * accept anchor_id as str or number in csv and convert pandas column format to str
#   (see fix below for plots of load history of individual anchors)

# %% [markdown]
# # setup

# %%
# setup for python ecosystem
import json
from math import *
import glob
import pandas as pd
import numpy as np
from IPython.core.display import HTML, display
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from scipy.stats import norm
from scipy.stats import lognorm
from scipy import stats

# %%
# setup for pandas
pd.set_option('display.max_rows', 5000)
pd.set_option('display.max_columns',100)

# %%
# setup for pixiedust data exploration
import pixiedust
from pixiedust.display import *
# installed:
# sudo pip install --user --upgrade pixiedust 
# sudo pip install seaborn
# sudo pip install bokeh

# "Bad 'legend' parameter value: None" when plotting bokeh with pixiedust
# https://github.com/org-arl/arlpy/issues/31 
# appears to be bug with bokeh, fix is to degrade the version of Bokeh 1.3
# sudo pip install bokeh==1.3.0
# Out:
# Pixiedust database opened successfully
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-watson-data-lab/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-watson-data-lab/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 1.1.18</span>
#         </div>

# %%
# define common functions

# function for calculating allowable anchor force
# based on SIA 260 (2013) 
# as documented in https://docs.google.com/spreadsheets/d/17GsuXH_9kubzu-f16cIugCzPtyKBbbA4Jdm00d-uyHU/edit#gid=469557799
#   steel_xsect_area = total steel cross-section, e.g. of steel tendon strands (mm)
#   steel_tensile_strength_char = characteristic tensile strength of anchor steel (N/mm2 = MPa)
#   anchor_load_char = anchor load when characteristic tensile strength of anchor steel is reached (kN)
def anchor_load_char_calc_sia260(steel_xsect_area, steel_tensile_strength_char):
    anchor_load_char = steel_xsect_area * steel_tensile_strength_char /1000.0
    return(anchor_load_char)

# function for determining capacity utilization of an anchor
# based on ASTRA "Risikoanalyse"  
# as documented in https://docs.google.com/spreadsheets/d/17GsuXH_9kubzu-f16cIugCzPtyKBbbA4Jdm00d-uyHU/edit#gid=4695577997
#   measured_anchor_load = measured anchor load during monitoring (kN)
#   measurement_tol = measurement tolerance (%)
#   anchor_capacity_utiliz = pro cent capacity utilization of an anchor (fraction between 0 and 1)
def anchor_capacity_utiliz_calc_astra(measured_anchor_load, measurement_tol, anchor_load_char):
    anchor_capacity_utiliz = measured_anchor_load * (1-measurement_tol/100) / anchor_load_char
    return(anchor_capacity_utiliz) 

# function for calculating change in anchor load to installed anchor load 
# based on ASTRA "Risikoanalyse"  
#   installed_anchor_load = anchor load at time of anchor installation (kN)
#   anchor_load_change = measured anchor load minus installed anchor load (kN, positive value means increase load)
def anchor_load_change_calc_astra(measured_anchor_load, installed_anchor_load):
    anchor_load_change = measured_anchor_load - installed_anchor_load
    return(anchor_load_change)

# %% [markdown]
# # remarks on input data
#
# * data sources
#   * https://drive.google.com/drive/folders/1hg8eD9MrwUcdzMDHcKWOA0V6jrQybA9j
#   * spreadshhets for five example structures
#     * SM 4
#     * SM 1 + B18
#     * Felssicherung Chüebalm
#     * Brücke Tuffgraben
#     * SM 5
#
#
# * the data in the sources cited above were taken by Tosacano AF
#   from various reports and drawings made available from ASTRA; <br />
#   in this data analysis only data from the above five data sources are consdered
#
#
# * data in data sources is partly conflicted in other documents
#     * SM 4 in spreadsheet 'Untersuchung_Ankerkräfte_Risk  SM4' <br />
#       https://docs.google.com/spreadsheets/d/17GsuXH_9kubzu-f16cIugCzPtyKBbbA4Jdm00d-uyHU/edit#gid=1364999228 <br />
#       --> differences in steel area and steel strength
#
#
# * each measurment is a data record, i.e. a spreadshet row in the CSV sheet; <br />
#   having records for all measurements (years) in the same row is not good data practice and is not the data structure expected by dataframes (pandas) <br />
#   [I suppose yearly data could be though of as a time series, but this seems like a convoluted way to work.]
#
#
# * data from the spreadsheets was prepared by linking the original data in each spreadsheet to a CSV worksheet in the same worksheet, <br /> using common headers agreed specifically for this work, and then exporting the CSV worksheet
#
#
# * structure_id and anchor_id
#   * decimals (and spaces) in IDs are bad data practice
#
#
# * the data from the intial anchor measurements (labelled P0 in the source spreadsheets) is enetered both as   installed_anchor_load and measured_anchor_load data; <br />
#  this foresees that the two data sets may difer, e.g. installed_anchor_load may correspond to the intial prescribed load ("Festsetzkraft") and the measured_anchor_load may correspond to the actual installed anchor load (which may differ from the prescribe load if within a specified tolerance)
#
#
# * the data entry sheet, the CSV sheet and the data column headers require additional review and refinement <br />
#   before the collection and preparation of additional anchor data (see also remarks to data table design below)

# %% [markdown]
# # remarks to flat table from CSV sheet in spreadsheet:
#
# * the CSV sheet for anchor data is configured as a single flat table <br />
#   using a common header line with header titles for each data column
# * the data structure suggests that two separate tables (anchor data table, measurment data table) should be used, <br />
#   which would e.g. avoid the repetition of anchor data for each measurment record
# * the anchor data table and measurment data table would then be joined in pandas into a single table
# * a single flat table is used in this preliminary proof-of-concept work to simplify data preparation
# * an appropriate data table design, e.g. using separate anchor data tables and measurment data tables <br />
#   should be completed before additional input data is prepared
# * a separate data entry sheet in the spreadsheet should be designed together with the data table design; <br />
#   the purpose of the data entry sheet is to make data entry as easy and error free as possible, <br />
#   with the CSV sheet being configured separately and structured for data analysis
#
#
# * the first header line is intended for accessing data from python code and is in English using snake_case
# * a second header line is in German text and is intended to be used for figure and table titles
# * additional header lines could be added for other languages
#
#
# * additional data tables to consider are
#   * structures table <br />
#     using an appropriate structures id as a database key
#   * anchor type table (?) <br />
#     considering however that this will complicate data entry and whether anchor detail data is required

# %% [markdown]
# # data input

# %%
# read in csv files containign anchor data
anchors_df = pd.concat([pd.read_csv(f, header=[0,1], encoding='utf-8') for f in glob.glob('data/ASTRA/IN/*.csv')], 
                       ignore_index = True)

# remove second header line (for this work)
anchors_df.columns = anchors_df.columns.droplevel(-1)

#glob.glob('data/ASTRA/*.csv')  #testing
anchors_df.dtypes  #testing
# Out:
# inventory_id                            object
# structure_name                          object
# data_source                             object
# structure_type                          object
# anchor_id                               object
# anchor_type                             object
# steel_tensile_strength_char              int64
# steel_xsect_area                         int64
# anchor_load_char_calculation_method    float64
# anchor_load_char                       float64
# warning_value_calculation_method       float64
# alarm_value_calculation_method         float64
# warning_value                          float64
# alarm_value                            float64
# installation_date                        int64
# installed_anchor_load                  float64
# measurement_date                         int64
# measured_anchor_load                   float64
# stress_unit                             object
# force_unit                              object
# area_unit                               object
# dtype: object

# %%
# configure date columns
#   dates in original data and csv data are year only
#   year date yyyy will be presumed as yyyy/01/01

# %% [markdown]
# # data analysis

# %%
# calculated fields
anchors_df["anchor_load_char"] = anchor_load_char_calc_sia260(anchors_df.steel_xsect_area, 
                                                anchors_df.steel_tensile_strength_char)

measurement_tol = 2.5  # %
anchors_df["anchor_capacity_utiliz"] = anchor_capacity_utiliz_calc_astra(anchors_df.measured_anchor_load, 
                                                measurement_tol, anchors_df.anchor_load_char)

anchors_df["anchor_load_change"] = anchor_load_change_calc_astra(anchors_df.measured_anchor_load, 
                                                anchors_df.installed_anchor_load)

# new fields for plotting
anchors_df["P"] = anchors_df.measured_anchor_load
anchors_df["P30"] = 0.3 * anchors_df.anchor_load_char
anchors_df["P70"] = 0.7 * anchors_df.anchor_load_char
anchors_df["anchor_structure"] = anchors_df.anchor_id +"_" +anchors_df.inventory_id  #anchor_id should be str for pixiedust
# anchor_id presently doubled-quoted in spreadsheet if number; better accept str or number and convert pandas column format to str

# %% [markdown]
# # testing

# %%
# data validity checking
#   test suite for testing data validity checking 
#   (e.g. string instead of float value, blank lines in csv data, garbled header title, ID fields NaN)

# how to introduce plausibility checking for measurement data?
#   simply omitting out-of-range values is not good, as anchors can conceivably fail e.g. leading to low measured values
#   maybe warning message and a function to manually delete a value, adding a comment to a new comment field?

# how to introduce plausibility checking for calculated data?
#   e.g if suspect capacity utilization in initial measurement

# %%
# function testing

steel_xsect_area = 1116  # mm2
steel_tensile_strength_char = 1770  # MPa
anchor_load_char = anchor_load_char_calc_sia260(steel_xsect_area, steel_tensile_strength_char)
print(anchor_load_char)

measured_anchor_load = 1100.0  #kN
measurement_tol = 2.5  # %
anchor_capacity_utiliz = anchor_capacity_utiliz_calc_astra(measured_anchor_load, measurement_tol, anchor_load_char)
print(anchor_capacity_utiliz)

installed_anchor_load = 1000.0
anchor_load_change = anchor_load_change_calc_astra(measured_anchor_load, installed_anchor_load)
print(anchor_load_change)
# Out:
# 1975.32
# 0.542950003037
# 100.0

# %%
# data for end-to-end testing
#anchors_df[anchors_df.anchor_id.isin(['9a','9b'])]  #problems with pixiedust
#anchors_df[anchors_df.structure_id.isin(['SM4'])]  #problems with pixiedust

anchors_SM4 = anchors_df[anchors_df.data_source.isin(['SM4'])]
anchors_SM5 = anchors_df[anchors_df.data_source.isin(['SM5'])]
anchors_SM1 = anchors_df[anchors_df.data_source.isin(['SM1'])]
anchors_chuebalm = anchors_df[anchors_df.data_source.isin(['Felssicherung Chuebalm'])]
anchors_tuffgraben = anchors_df[anchors_df.data_source.isin(['Bruecke Tuffgraben'])]

# %%
# end-to-end testing
#anchors_tuffgraben[anchors_df['measurement_date']==2019].describe()
anchors_tuffgraben.describe()

#anchors_SM4[anchors_df['measurement_date']==2019].sum()
# Out:
#        steel_tensile_strength_char  steel_xsect_area  \
# count                          9.0               9.0
# mean                        1770.0            1023.0
# std                            0.0               0.0
# min                         1770.0            1023.0
# 25%                         1770.0            1023.0
# 50%                         1770.0            1023.0
# 75%                         1770.0            1023.0
# max                         1770.0            1023.0
#
#        anchor_load_char_calculation_method  anchor_load_char  \
# count                                  0.0              9.00
# mean                                   NaN           1810.71
# std                                    NaN              0.00
# min                                    NaN           1810.71
# 25%                                    NaN           1810.71
# 50%                                    NaN           1810.71
# 75%                                    NaN           1810.71
# max                                    NaN           1810.71
#
#        warning_value_calculation_method  alarm_value_calculation_method  \
# count                               0.0                             0.0
# mean                                NaN                             NaN
# std                                 NaN                             NaN
# min                                 NaN                             NaN
# 25%                                 NaN                             NaN
# 50%                                 NaN                             NaN
# 75%                                 NaN                             NaN
# max                                 NaN                             NaN
#
#        warning_value  alarm_value  installation_date  installed_anchor_load  \
# count            0.0          0.0                9.0                    9.0
# mean             NaN          NaN             1980.0                  900.0
# std              NaN          NaN                0.0                    0.0
# min              NaN          NaN             1980.0                  900.0
# 25%              NaN          NaN             1980.0                  900.0
# 50%              NaN          NaN             1980.0                  900.0
# 75%              NaN          NaN             1980.0                  900.0
# max              NaN          NaN             1980.0                  900.0
#
#        measurement_date  measured_anchor_load  anchor_capacity_utiliz  \
# count          9.000000              9.000000                9.000000
# mean        2003.000000            960.222222                0.517044
# std           17.684739             47.683272                0.025676
# min         1980.000000            900.000000                0.484617
# 25%         1980.000000            900.000000                0.484617
# 50%         2010.000000            980.000000                0.527694
# 75%         2019.000000           1004.000000                0.540617
# max         2019.000000           1010.000000                0.543847
#
#        anchor_load_change            P      P30       P70
# count            9.000000     9.000000    9.000     9.000
# mean            60.222222   960.222222  543.213  1267.497
# std             47.683272    47.683272    0.000     0.000
# min              0.000000   900.000000  543.213  1267.497
# 25%              0.000000   900.000000  543.213  1267.497
# 50%             80.000000   980.000000  543.213  1267.497
# 75%            104.000000  1004.000000  543.213  1267.497
# max            110.000000  1010.000000  543.213  1267.497

# %%
# check handling of NaN values by pandas plot -> NaN values are omitted in plot -> ok
# plot of anchor loads vs index    
#anchors_SM4.measured_anchor_load
anchors_SM4.measured_anchor_load.plot()

# %% [markdown]
# # dataframe views

# %%
anchors_df
#anchors_df[anchors_df['structure_id']=='SM4']
#anchors_df[anchors_df['anchor_id']=='18b']
# Out:
#         inventory_id           structure_name             data_source  \
# 0    02.08.60.410.50       BRÜCKE SM Wäldli 1                     SM1
# 1    02.08.60.410.50       BRÜCKE SM Wäldli 1                     SM1
# 2    02.08.60.723.02      SM Wäldli 1 BR - SP                     SM1
#
02.08.60.723.09       SM Brand BR - SP 5                     SM5
# 426  02.08.60.723.09       SM Brand BR - SP 5                     SM5
# 427  02.08.60.723.09       SM Brand BR - SP 5                     SM5
# 428  02.08.60.723.09       SM Brand BR - SP 5                     SM5
# 429  02.08.60.723.09       SM Brand BR - SP 5                     SM5
# 430  02.08.60.723.09       SM Brand BR - SP 5                     SM5
# 431  02.08.60.723.09       SM Brand BR - SP 5                     SM5
# 432  02.08.60.723.09       SM Brand BR - SP 5                     SM5
# 433  02.08.60.723.09       SM Brand BR - SP 5                     SM5
# 434  02.08.60.723.09       SM Brand BR - SP 5                     SM5
# 435  02.08.60.723.09       SM Brand BR - SP 5                     SM5
# 436  02.08.60.723.09       SM Brand BR - SP 5                     SM5
# 437  02.08.60.723.09       SM Brand BR - SP 5                     SM5
# 438  02.08.60.723.09       SM Brand BR - SP 5                     SM5
# 439  02.08.60.723.09       SM Brand BR - SP 5                     SM5
# 440  02.08.60.723.09       SM Brand BR - SP 5                     SM5
# 441  02.08.60.723.09       SM Brand BR - SP 5                     SM5
# 442  02.08.60.723.09       SM Brand BR - SP 5                     SM5
# 443  02.08.60.723.09       SM Brand BR - SP 5                     SM5
# 444  02.08.60.723.09       SM Brand BR - SP 5                     SM5
# 445  02.08.60.723.09       SM Brand BR - SP 5                     SM5
# 446  02.08.60.723.09       SM Brand BR - SP 5                     SM5
# 447  02.08.60.723.09       SM Brand BR - SP 5                     SM5
# 448  02.08.60.723.09       SM Brand BR - SP 5                     SM5
# 449  02.08.60.723.09       SM Brand BR - SP 5                     SM5
# 450  02.08.60.723.09       SM Brand BR - SP 5                     SM5
# 451  02.08.60.723.09       SM Brand BR - SP 5                     SM5
# 452  02.08.60.723.09       SM Brand BR - SP 5                     SM5
# 453  02.08.60.723.09       SM Brand BR - SP 5                     SM5
# 454  02.08.60.723.09       SM Brand BR - SP 5                     SM5
# 455  02.08.60.723.09       SM Brand BR - SP 5                     SM5
# 456  02.08.60.723.09       SM Brand BR - SP 5                     SM5
# 457  02.08.60.723.09       SM Brand BR - SP 5                     SM5
# 458  02.08.60.723.09       SM Brand BR - SP 5                     SM5
# 459  02.08.60.723.09       SM Brand BR - SP 5                     SM5
# 460  02.08.60.723.09       SM Brand BR - SP 5                     SM5
# 461  02.08.60.723.09       SM Brand BR - SP 5                     SM5
# 462  02.08.60.723.09       SM Brand BR - SP 5                     SM5
# 463  02.08.60.723.09       SM Brand BR - SP 5                     SM5
# 464  02.08.60.723.09       SM Brand BR - SP 5                     SM5
# 465  02.08.60.723.09       SM Brand BR - SP 5                     SM5
# 466  02.08.60.723.09       SM Brand BR - SP 5                     SM5
# 467  02.08.60.723.09       SM Brand BR - SP 5                     SM5
# 468  02.08.60.723.09       SM Brand BR - SP 5                     SM5
# 469  02.08.60.723.09       SM Brand BR - SP 5                     SM5
# 470  02.08.60.723.09       SM Brand BR - SP 5                     SM5
# 471  02.08.60.723.09       SM Brand BR - SP 5                     SM5
# 472  02.08.60.723.09       SM Brand BR - SP 5                     SM5
# 473  02.08.60.723.09       SM Brand BR - SP 5                     SM5
#
#     structure_type anchor_id           anchor_type  \
# 0       Stützmauer     24.1a  VSL Typ EA35 5-12/12
# 1       Stützmauer     24.1b  VSL Typ EA35 5-12/12
# 2       Stützmauer      20.a  VSL Typ EA35 5-12/12
# 3       Stützmauer      20.b  VSL Typ EA35 5-12/12
# 4       Stützmauer      19.a  VSL Typ EA35 5-12/12
# 5       Stützmauer      19.b  VSL Typ EA35 5-12/12
# 6       Stützmauer      18.a  VSL Typ EA35 5-12/12
# 7       Stützmauer      18.b  VSL Typ EA35 5-12/12
# 8       Stützmauer      17.a  VSL Typ EA35 5-12/12
# 9       Stützmauer      17.b  VSL Typ EA35 5-12/12
# 10      Stützmauer      16.a  VSL Typ EA35 5-12/12
# 11      Stützmauer      16.b  VSL Typ EA35 5-12/12
# 12      Stützmauer      15.a  VSL Typ EA35 5-12/12
# 13      Stützmauer      15.b  VSL Typ EA35 5-12/12
# 14      Stützmauer      14.a  VSL Typ EA35 5-12/12
# 15      Stützmauer      14.b  VSL Typ EA35 5-12/12
# 16      Stützmauer      10.b  VSL Typ EA35 5-12/12
# 17      Stützmauer       9.b  VSL Typ EA35 5-12/12
# 18      Stützmauer      18.2  VSL Typ EA35 5-12/12
# 19      Stützmauer     24.1a  VSL Typ EA35 5-12/12
# 20      Stützmauer     24.1b  VSL Typ EA35 5-12/12
# 21      Stützmauer      20.a  VSL Typ EA35 5-12/12
# 22      Stützmauer      20.b  VSL Typ EA35 5-12/12
# 23      Stützmauer      19.a  VSL Typ EA35 5-12/12
# 24      Stützmauer      19.b  VSL Typ EA35 5-12/12
# 25      Stützmauer      18.a  VSL Typ EA35 5-12/12
# 26      Stützmauer      18.b  VSL Typ EA35 5-12/12
# 27      Stützmauer      17.a  VSL Typ EA35 5-12/12
# 28      Stützmauer      17.b  VSL Typ EA35 5-12/12
# 29      Stützmauer      16.a  VSL Typ EA35 5-12/12
# 30      Stützmauer      16.b  VSL Typ EA35 5-12/12
# 31      Stützmauer      15.a  VSL Typ EA35 5-12/12
# 32      Stützmauer      15.b  VSL Typ EA35 5-12/12
# 33      Stützmauer      14.a  VSL Typ EA35 5-12/12
# 34      Stützmauer      14.b  VSL Typ EA35 5-12/12
# 35      Stützmauer      10.b  VSL Typ EA35 5-12/12
# 36      Stützmauer       9.b  VSL Typ EA35 5-12/12
# 37      Stützmauer      18.2  VSL Typ EA35 5-12/12
# 38      Stützmauer     24.1a  VSL Typ EA35 5-12/12
# 39      Stützmauer     24.1b  VSL Typ EA35 5-12/12
# 40      Stützmauer      20.a  VSL Typ EA35 5-12/12
# 41      Stützmauer      20.b  VSL Typ EA35 5-12/12
# 42      Stützmauer      19.a  VSL Typ EA35 5-12/12
# 43      Stützmauer      19.b  VSL Typ EA35 5-12/12
# 44      Stützmauer      18.a  VSL Typ EA35 5-12/12
# 45      Stützmauer      18.b  VSL Typ EA35 5-12/12
# 46      Stützmauer      17.a  VSL Typ EA35 5-12/12
# 47      Stützmauer      17.b  VSL Typ EA35 5-12/12
# 48      Stützmauer      16.a  VSL Typ EA35 5-12/12
# 49      Stützmauer      16.b  VSL Typ EA35 5-12/12
# 50      Stützmauer      15.a  VSL Typ EA35 5-12/12
# 51      Stützmauer      15.b  VSL Typ EA35 5-12/12
# 52      Stützmauer      14.a  VSL Typ EA35 5-12/12
# 53      Stützmauer      14.b  VSL Typ EA35 5-12/12
# 54      Stützmauer      10.b  VSL Typ EA35 5-12/12
# 55      Stützmauer       9.b  VSL Typ EA35 5-12/12
# 56      Stützmauer      18.2  VSL Typ EA35 5-12/12
# 57      Stützmauer     24.1a  VSL Typ EA35 5-12/12
# 58      Stützmauer     24.1b  VSL Typ EA35 5-12/12
# 59      Stützmauer      20.a  VSL Typ EA35 5-12/12
# 60      Stützmauer      20.b  VSL Typ EA35 5-12/12
# 61      Stützmauer      19.a  VSL Typ EA35 5-12/12
# 62      Stützmauer      19.b  VSL Typ EA35 5-12/12
# 63      Stützmauer      18.a  VSL Typ EA35 5-12/12
# 64      Stützmauer      18.b  VSL Typ EA35 5-12/12
# 65      Stützmauer      17.a  VSL Typ EA35 5-12/12
# 66      Stützmauer      17.b  VSL Typ EA35 5-12/12
# 67      Stützmauer      16.a  VSL Typ EA35 5-12/12
# 68      Stützmauer      16.b  VSL Typ EA35 5-12/12
# 69      Stützmauer      15.a  VSL Typ EA35 5-12/12
# 70      Stützmauer      15.b  VSL Typ EA35 5-12/12
# 71      Stützmauer      14.a  VSL Typ EA35 5-12/12
# 72      Stützmauer      14.b  VSL Typ EA35 5-12/12
# 73      Stützmauer      10.b  VSL Typ EA35 5-12/12
# 74      Stützmauer       9.b  VSL Typ EA35 5-12/12
# 75      Stützmauer      18.2  VSL Typ EA35 5-12/12
# 76      Stützmauer     24.1a  VSL Typ EA35 5-12/12
# 77      Stützmauer     24.1b  VSL Typ EA35 5-12/12
# 78      Stützmauer      20.a  VSL Typ EA35 5-12/12
# 79      Stützmauer      20.b  VSL Typ EA35 5-12/12
# 80      Stützmauer      19.a  VSL Typ EA35 5-12/12
# 81      Stützmauer      19.b  VSL Typ EA35 5-12/12
# 82      Stützmauer      18.a  VSL Typ EA35 5-12/12
# 83      Stützmauer      18.b  VSL Typ EA35 5-12/12
# 84      Stützmauer      17.a  VSL Typ EA35 5-12/12
# 85      Stützmauer      17.b  VSL Typ EA35 5-12/12
# 86      Stützmauer      16.a  VSL Typ EA35 5-12/12
# 87      Stützmauer      16.b  VSL Typ EA35 5-12/12
# 88      Stützmauer      15.a  VSL Typ EA35 5-12/12
# 89      Stützmauer      15.b  VSL Typ EA35 5-12/12
# 90      Stützmauer      14.a  VSL Typ EA35 5-12/12
# 91      Stützmauer      14.b  VSL Typ EA35 5-12/12
# 92      Stützmauer      10.b  VSL Typ EA35 5-12/12
# 93      Stützmauer       9.b  VSL Typ EA35 5-12/12
# 94      Stützmauer      18.2  VSL Typ EA35 5-12/12
# 95      Stützmauer     24.1a  VSL Typ EA35 5-12/12
# 96      Stützmauer     24.1b  VSL Typ EA35 5-12/12
# 97      Stützmauer      20.a  VSL Typ EA35 5-12/12
# 98      Stützmauer      20.b  VSL Typ EA35 5-12/12
# 99      Stützmauer      19.a  VSL Typ EA35 5-12/12
# 100     Stützmauer      19.b  VSL Typ EA35 5-12/12
# 101     Stützmauer      18.a  VSL Typ EA35 5-12/12
# 102     Stützmauer      18.b  VSL Typ EA35 5-12/12
# 103     Stützmauer      17.a  VSL Typ EA35 5-12/12
# 104     Stützmauer      17.b  VSL Typ EA35 5-12/12
# 105     Stützmauer      16.a  VSL Typ EA35 5-12/12
# 106     Stützmauer      16.b  VSL Typ EA35 5-12/12
# 107     Stützmauer      15.a  VSL Typ EA35 5-12/12
# 108     Stützmauer      15.b  VSL Typ EA35 5-12/12
# 109     Stützmauer      14.a  VSL Typ EA35 5-12/12
# 110     Stützmauer      14.b  VSL Typ EA35 5-12/12
# 111     Stützmauer      10.b  VSL Typ EA35 5-12/12
# 112     Stützmauer       9.b  VSL Typ EA35 5-12/12
# 113     Stützmauer      18.2  VSL Typ EA35 5-12/12
# 114         Brücke       "1"       VSL Typ EG 5-12
# 115         Brücke       "2"       VSL Typ EG 5-12
# 116         Brücke       "3"       VSL Typ EG 5-12
# 117         Brücke       "1"       VSL Typ EG 5-12
# 118         Brücke       "2"       VSL Typ EG 5-12
# 119         Brücke       "3"       VSL Typ EG 5-12
# 120         Brücke       "1"       VSL Typ EG 5-12
# 121         Brücke       "2"       VSL Typ EG 5-12
# 122         Brücke       "3"       VSL Typ EG 5-12
# 123   Tunnelportal     "101"       VSL Typ EG 5-12
# 124   Tunnelportal     "102"       VSL Typ EG 5-12
# 125   Tunnelportal     "103"       VSL Typ EG 5-12
# 126   Tunnelportal     "104"       VSL Typ EG 5-12
# 127   Tunnelportal     "105"       VSL Typ EG 5-12
# 128   Tunnelportal     "106"       VSL Typ EG 5-12
# 129   Tunnelportal     "107"       VSL Typ EG 5-12
# 130   Tunnelportal     "101"       VSL Typ EG 5-12
# 131   Tunnelportal     "102"       VSL Typ EG 5-12
# 132   Tunnelportal     "103"       VSL Typ EG 5-12
# 133   Tunnelportal     "104"       VSL Typ EG 5-12
# 134   Tunnelportal     "105"       VSL Typ EG 5-12
# 135   Tunnelportal     "106"       VSL Typ EG 5-12
# 136   Tunnelportal     "107"       VSL Typ EG 5-12
# 137   Tunnelportal     "101"       VSL Typ EG 5-12
# 138   Tunnelportal     "102"       VSL Typ EG 5-12
# 139   Tunnelportal     "103"       VSL Typ EG 5-12
# 140   Tunnelportal     "104"       VSL Typ EG 5-12
# 141   Tunnelportal     "105"       VSL Typ EG 5-12
# 142   Tunnelportal     "106"       VSL Typ EG 5-12
# 143   Tunnelportal     "107"       VSL Typ EG 5-12
# 144     Stützmauer       30a           VSL EA 5-12
# 145     Stützmauer       30b           VSL EA 5-12
# 146     Stützmauer       29a           VSL EA 5-12
# 147     Stützmauer       29b           VSL EA 5-12
# 148     Stützmauer       29c           VSL EA 5-12
# 149     Stützmauer       29d           VSL EA 5-12
# 150     Stützmauer        28           VSL EA 5-12
# 151     Stützmauer        25           VSL EA 5-12
# 152     Stützmauer       24a           VSL EA 5-12
# 153     Stützmauer        24           VSL EA 5-12
# 154     Stützmauer        23           VSL EA 5-12
# 155     Stützmauer       23a           VSL EA 5-12
# 156     Stützmauer      22.1           VSL EA 5-12
# 157     Stützmauer      19.1           VSL EA 5-12
# 158     Stützmauer       18a           VSL EA 5-12
# 159     Stützmauer       18b           VSL EA 5-12
# 160     Stützmauer       18c           VSL EA 5-12
# 161     Stützmauer       18d           VSL EA 5-12
# 162     Stützmauer        17           VSL EA 5-12
# 163     Stützmauer        14           VSL EA 5-12
# 164     Stützmauer       13a           VSL EA 5-12
# 165     Stützmauer       13b           VSL EA 5-12
# 166     Stützmauer       13c           VSL EA 5-12
# 167     Stützmauer       13d           VSL EA 5-12
# 168     Stützmauer        12           VSL EA 5-12
# 169     Stützmauer        10           VSL EA 5-12
# 170     Stützmauer        9a           VSL EA 5-12
# 171     Stützmauer        9b           VSL EA 5-12
# 172     Stützmauer       30a           VSL EA 5-12
# 173     Stützmauer       30b           VSL EA 5-12
# 174     Stützmauer       29a           VSL EA 5-12
# 175     Stützmauer       29b           VSL EA 5-12
# 176     Stützmauer       29c           VSL EA 5-12
# 177     Stützmauer       29d           VSL EA 5-12
# 178     Stützmauer        28           VSL EA 5-12
# 179     Stützmauer        25           VSL EA 5-12
# 180     Stützmauer       24a           VSL EA 5-12
# 181     Stützmauer        24           VSL EA 5-12
# 182     Stützmauer        23           VSL EA 5-12
# 183     Stützmauer       23a           VSL EA 5-12
# 184     Stützmauer      22.1           VSL EA 5-12
# 185     Stützmauer      19.1           VSL EA 5-12
# 186     Stützmauer       18a           VSL EA 5-12
# 187     Stützmauer       18b           VSL EA 5-12
# 188     Stützmauer       18c           VSL EA 5-12
# 189     Stützmauer       18d           VSL EA 5-12
# 190     Stützmauer        17           VSL EA 5-12
# 191     Stützmauer        14           VSL EA 5-12
# 192     Stützmauer       13a           VSL EA 5-12
# 193     Stützmauer       13b           VSL EA 5-12
# 194     Stützmauer       13c           VSL EA 5-12
# 195     Stützmauer       13d           VSL EA 5-12
# 196     Stützmauer        12           VSL EA 5-12
# 197     Stützmauer        10           VSL EA 5-12
# 198     Stützmauer        9a           VSL EA 5-12
# 199     Stützmauer        9b           VSL EA 5-12
# 200     Stützmauer       30a           VSL EA 5-12
# 201     Stützmauer       30b           VSL EA 5-12
# 202     Stützmauer       29a           VSL EA 5-12
# 203     Stützmauer       29b           VSL EA 5-12
# 204     Stützmauer       29c           VSL EA 5-12
# 205     Stützmauer       29d           VSL EA 5-12
# 206     Stützmauer        28           VSL EA 5-12
# 207     Stützmauer        25           VSL EA 5-12
# 208     Stützmauer       24a           VSL EA 5-12
# 209     Stützmauer        24           VSL EA 5-12
# 210     Stützmauer        23           VSL EA 5-12
# 211     Stützmauer       23a           VSL EA 5-12
# 212     Stützmauer      22.1           VSL EA 5-12
# 213     Stützmauer      19.1           VSL EA 5-12
# 214     Stützmauer       18a           VSL EA 5-12
# 215     Stützmauer       18b           VSL EA 5-12
# 216     Stützmauer       18c           VSL EA 5-12
# 217     Stützmauer       18d           VSL EA 5-12
# 218     Stützmauer        17           VSL EA 5-12
# 219     Stützmauer        14           VSL EA 5-12
# 220     Stützmauer       13a           VSL EA 5-12
# 221     Stützmauer       13b           VSL EA 5-12
# 222     Stützmauer       13c           VSL EA 5-12
# 223     Stützmauer       13d           VSL EA 5-12
# 224     Stützmauer        12           VSL EA 5-12
# 225     Stützmauer        10           VSL EA 5-12
# 226     Stützmauer        9a           VSL EA 5-12
# 227     Stützmauer        9b           VSL EA 5-12
# 228     Stützmauer       30a           VSL EA 5-12
# 229     Stützmauer       30b           VSL EA 5-12
# 230     Stützmauer       29a           VSL EA 5-12
# 231     Stützmauer       29b           VSL EA 5-12
# 232     Stützmauer       29c           VSL EA 5-12
# 233     Stützmauer       29d           VSL EA 5-12
# 234     Stützmauer        28           VSL EA 5-12
# 235     Stützmauer        25           VSL EA 5-12
# 236     Stützmauer       24a           VSL EA 5-12
# 237     Stützmauer        24           VSL EA 5-12
# 238     Stützmauer        23           VSL EA 5-12
# 239     Stützmauer       23a           VSL EA 5-12
# 240     Stützmauer      22.1           VSL EA 5-12
# 241     Stützmauer      19.1           VSL EA 5-12
# 242     Stützmauer       18a           VSL EA 5-12
# 243     Stützmauer       18b           VSL EA 5-12
# 244     Stützmauer       18c           VSL EA 5-12
# ...
# 446                0.378082                55.0   755.0  584.100  1362.900
# 447                0.515794                30.0  1030.0  584.100  1362.900
# 448                0.535824                70.0  1070.0  584.100  1362.900
# 449                0.507698               106.0  1106.0  637.200  1486.800
# 450                0.343529              -314.0   686.0  584.100  1362.900
# 451                0.524807                48.0  1048.0  584.100  1362.900
# 452                0.515794                30.0  1030.0  584.100  1362.900
# 453                0.521302                41.0  1041.0  584.100  1362.900
# 454                0.506780                12.0  1012.0  584.100  1362.900
# 455                0.540832                80.0  1080.0  584.100  1362.900
# 456                0.274923                49.0   549.0  584.100  1362.900
# 457                0.521803                42.0  1042.0  584.100  1362.900
# 458                0.262404                24.0   524.0  584.100  1362.900
# 459                0.533821                66.0  1066.0  584.100  1362.900
# 460                0.548344                95.0  1095.0  584.100  1362.900
# 461                0.513790                26.0  1026.0  584.100  1362.900
# 462                0.534322               164.0  1164.0  637.200  1486.800
# 463                0.535824                70.0  1070.0  584.100  1362.900
# 464                0.540832                80.0  1080.0  584.100  1362.900
Axis"},{"attributes":{"callback":null,"start":0},"id":"1043","type":"DataRange1d"},{"attributes":{},"id":"1050","type":"BasicTicker"},{"attributes":{"ticker":{"id":"1050","type":"BasicTicker"}},"id":"1053","type":"Grid"},{"attributes":{"axis_label":"Frequency","formatter":{"id":"1094","type":"BasicTickFormatter"},"ticker":{"id":"1055","type":"BasicTicker"}},"id":"1054","type":"LinearAxis"},{"attributes":{},"id":"1055","type":"BasicTicker"},{"attributes":{"dimension":1,"ticker":{"id":"1055","type":"BasicTicker"}},"id":"1058","type":"Grid"},{"attributes":{"callback":null,"tooltips":[["Frequency","@top{0.00}"],["Interval","@left - @right"]]},"id":"1077","type":"HoverTool"},{"attributes":{"bottom":{"value":0},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"top":{"field":"top"}},"id":"1074","type":"Quad"},{"attributes":{"data_source":{"id":"1072","type":"ColumnDataSource"},"glyph":{"id":"1073","type":"Quad"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"1074","type":"Quad"},"selection_glyph":null,"view":{"id":"1076","type":"CDSView"}},"id":"1075","type":"GlyphRenderer"},{"attributes":{"callback":null,"data":{"left":{"__ndarray__":"AAAAAABAf0CamZmZmWmAQDMzMzMzM4FAzczMzMz8gUBmZmZmZsaCQAAAAAAAkINAmpmZmZlZhEAzMzMzMyOFQM3MzMzM7IVAZmZmZma2hkAAAAAAAICHQJqZmZmZSYhAMzMzMzMTiUDMzMzMzNyJQGZmZmZmpopAAAAAAABwi0CamZmZmTmMQDMzMzMzA41AzMzMzMzMjUBmZmZmZpaOQA==","dtype":"float64","shape":[20]},"right":{"__ndarray__":"mpmZmZlpgEAzMzMzMzOBQM3MzMzM/IFAZmZmZmbGgkAAAAAAAJCDQJqZmZmZWYRAMzMzMzMjhUDNzMzMzOyFQGZmZmZmtoZAAAAAAACAh0CamZmZmUmIQDMzMzMzE4lAzMzMzMzciUBmZmZmZqaKQAAAAAAAcItAmpmZmZk5jEAzMzMzMwONQMzMzMzMzI1AZmZmZmaWjkAAAAAAAGCPQA==","dtype":"float64","shape":[20]},"top":{"__ndarray__":"Rx9+t+h8Uj8AAAAAAAAAAAAAAAAAAAAAnoknhy7QPj8AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAv423Ohcx0PwAAAAAAAAAARx9+t+h8Uj8AAAAAAAAAAJ6JJ4cu0E4/AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA6i49E127Sz9fH3636HxCPwAAAAAAAAAAAAAAAAAAAAB8mGtBRzyePw==","dtype":"float64","shape":[20]}},"selected":{"id":"1095","type":"Selection"},"selection_policy":{"id":"1096","type":"UnionRenderers"}},"id":"1072","type":"ColumnDataSource"},{"attributes":{"bottom":{"value":0},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_color":{"value":"#cccccc"},"right":{"field":"right"},"top":{"field":"top"}},"id":"1073","type":"Quad"},{"attributes":{"callback":null,"tooltips":[["Frequency","@top{0.00}"],["Interval","@left - @right"]]},"id":"1038","type":"HoverTool"},{"attributes":{"dimension":1,"ticker":{"id":"1016","type":"BasicTicker"}},"id":"1019","type":"Grid"},{"attributes":{"ticker":{"id":"1011","type":"BasicTicker"}},"id":"1014","type":"Grid"},{"attributes":{"axis_label":"Frequency","formatter":{"id":"1084","type":"BasicTickFormatter"},"ticker":{"id":"1016","type":"BasicTicker"}},"id":"1015","type":"LinearAxis"},{"attributes":{},"id":"1016","type":"BasicTicker"},{"attributes":{"data_source":{"id":"1033","type":"ColumnDataSource"},"glyph":{"id":"1034","type":"Quad"},"hover_glyph":null,"muted_glyph":null,"n ...

# %%
# basic data check of all anchor measurements over time
display(anchors_df)
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#
#         </div>
#     <div id="chartFigureb3165fd3" class="pd_save is-viewer-good" style="overflow-x:auto">
#
#
#                             <center><img style="max-width:initial !important" src="data:image/png;base64,..." class="pd_save"></center>
#
#
#
#         </div>

# %% [markdown]
# ### data trends

# %%
# scatterplot of anchor capacity utilization vs anchor load change
display(anchors_df)

# careful: anchor_id's are not unique !!
# anchor 18c at SMC4 has low capacity utilization, is data for calc_anchor_load correct ??
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>

# %%
# average of all anchors at each strcuture
display(anchors_df)

#display(anchors_df[anchors_df.structure_id.isin(['Bruecke Tuffgraben'])])
#display(anchors_SM4)

# are NaN values taken as zero??
# e.g. SM1 is not displayed correctly with 'display(anchors_df)', compare with 'display(anchors_SM1)'
#   -> looks more like a bug with pixiedust
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>

# %% [markdown]
# ### data for indiviudal anchors

# %%
# anchor load over time for individual anchors
display(anchors_df[anchors_df['anchor_id']=='18b'])

# careful: anchor_id's are not unique !!
#          and 18.b and 18b give same result !!  -> seems to be strange pixiedust render updating behvaior
#            -> decimals (and spaces) in IDs are bad practice !!
# NaN values are omitted (expected behavior), but why different further below in subplots ??
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#             18b
#         </div>
#     <div id="chartFigure41ba113a" class="pd_save is-viewer-good" style="overflow-x:auto">
#
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-41ba113a")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"87ee9b03-ed60-499a-9233-d6b1d98816e5":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"2415","type":"BoxAnnotation"},{"attributes":{"ticker":{"id":"2379","type":"BasicTicker"}},"id":"2382","type":"Grid"},{"attributes":{},"id":"2392","type":"ResetTool"},{"attributes":{},"id":"2414","type":"UnionRenderers"},{"attributes":{"axis_label":"measured_anchor_load","formatter":{"id":"2412","type":"BasicTickFormatter"},"ticker":{"id":"2384","type":"BasicTicker"}},"id":"2383","type":"LinearAxis"},{"attributes":{"callback":null,"tooltips":[["measurement_date","@x"],["measured_anchor_load","@y{0.00}"],["x","$x"],["y","$y"]]},"id":"2406","type":"HoverTool"},{"attributes":{"data_source":{"id":"2401","type":"ColumnDataSource"},"glyph":{"id":"2402","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"2403","type":"Line"},"selection_glyph":null,"view":{"id":"2405","type":"CDSView"}},"id":"2404","type":"GlyphRenderer"},{"attributes":{"source":{"id":"2401","type":"ColumnDataSource"}},"id":"2405","type":"CDSView"},{"attributes":{"line_color":"#1f77b4","line_width":2,"x":{"field":"x"},"y":{"field":"y"}},"id":"2402","type":"Line"},{"attributes":{"line_alpha":0.1,"line_color":"#1f77b4","line_width":2,"x":{"field":"x"},"y":{"field":"y"}},"id":"2403","type":"Line"},{"attributes":{"dimension":1,"ticker":{"id":"2384","type":"BasicTicker"}},"id":"2387","type":"Grid"},{"attributes":{"below":[{"id":"2378","type":"LinearAxis"}],"center":[{"id":"2382","type":"Grid"},{"id":"2387","type":"Grid"}],"left":[{"id":"2383","type":"LinearAxis"}],"plot_height":373,"plot_width":500,"renderers":[{"id":"2404","type":"GlyphRenderer"}],"title":null,"toolbar":{"id":"2394","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"2370","type":"DataRange1d"},"x_scale":{"id":"2374","type":"LinearScale"},"y_range":{"id":"2372","type":"DataRange1d"},"y_scale":{"id":"2376","type":"LinearScale"}},"id":"2368","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"2389","type":"WheelZoomTool"},{"attributes":{},"id":"2388","type":"PanTool"},{"attributes":{},"id":"2379","type":"BasicTicker"},{"attributes":{},"id":"2384","type":"BasicTicker"},{"attributes":{"children":[[{"id":"2368","subtype":"Figure","type":"Plot"},0,0]]},"id":"2417","type":"GridBox"},{"attributes":{"children":[{"id":"2419","type":"ToolbarBox"},{"id":"2417","type":"GridBox"}]},"id":"2420","type":"Column"},{"attributes":{"callback":null,"data":{"x":[1984.0,1996.0,2004.0,2010.0,2019.0],"y":[1000.0,1021.0,993.0,1016.0,1015.0]},"selected":{"id":"2413","type":"Selection"},"selection_policy":{"id":"2414","type":"UnionRenderers"}},"id":"2401","type":"ColumnDataSource"},{"attributes":{},"id":"2374","type":"LinearScale"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_multi":null,"active_scroll":"auto","active_tap":"auto","tools":[{"id":"2388","type":"PanTool"},{"id":"2389","type":"WheelZoomTool"},{"id":"2390","type":"BoxZoomTool"},{"id":"2391","type":"SaveTool"},{"id":"2392","type":"ResetTool"},{"id":"2393","type":"HelpTool"},{"id":"2406","type":"HoverTool"}]},"id":"2394","type":"Toolbar"},{"attributes":{},"id":"2410","type":"BasicTickFormatter"},{"attributes":{},"id":"2413","type":"Selection"},{"attributes":{},"id":"2412","type":"BasicTickFormatter"},{"attributes":{"axis_label":"measurement_date","formatter":{"id":"2410","type":"BasicTickFormatter"},"ticker":{"id":"2379","type":"BasicTicker"}},"id":"2378","type":"LinearAxis"},{"attributes":{},"id":"2393","type":"HelpTool"},{"attributes":{"overlay":{"id":"2415","type":"BoxAnnotation"}},"id":"2390","type":"BoxZoomTool"},{"attributes":{},"id":"2391","type":"SaveTool"},{"attributes":{"toolbar":{"id":"2418","type":"Proxy ...
#           var render_items = [{"docid":"87ee9b03-ed60-499a-9233-d6b1d98816e5","roots":{"2420":"d5c99829-107b-4b66-b757-e9e822af5b00"}}];
#           root.Bokeh.embed.embed_items(docs_json, render_items);
#
#           }
#           if (root.Bokeh !== undefined) {
#             embed_document(root);
#           } else {
#             var attempts = 0;
#             var timer = setInterval(function(root) {
#               if (root.Bokeh !== undefined) {
#                 embed_document(root);
#                 clearInterval(timer);
#               }
#               attempts++;
#               if (attempts > 100) {
#                 console.log("Bokeh: ERROR: Unable to run BokehJS code because BokehJS library is missing");
#                 clearInterval(timer);
#               }
#             }, 10, root)
#           }
#         })(window);
#       });
#     };
#     if (document.readyState != "loading") fn();
#     else document.addEventListener("DOMContentLoaded", fn);
#   })();
# <\/script>`
#                                 var chartscript = el.childNodes[1]
#                                 var s = document.createElement("script")
#                                 s.innerHTML = chartscript.innerHTML
#                                 d.parentNode.insertBefore(s, d)
#                             }
#                         }
#                     }
#                     if (!window.Bokeh && !window.autoload){
#                         window.autoload=true;
#
# (function(root) {
#   function now() {
#     return new Date();
#   }
#
#   var force = 1;
#
#   if (typeof root._bokeh_onload_callbacks === "undefined" || force === true) {
#     root._bokeh_onload_callbacks = [];
#     root._bokeh_is_loading = undefined;
#   }
#
#
#
#
#   if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#     root._bokeh_timeout = Date.now() + 5000;
#     root._bokeh_failed_load = false;
#   }
#
#   var NB_LOAD_WARNING = {'data': {'text/html':
#      "<div style='background-color: #fdd'>\n"+
#      "<p>\n"+
#      "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#      "may be due to a slow or bad network connection. Possible fixes:\n"+
#      "</p>\n"+
#      "<ul>\n"+
#      "<li>re-rerun `output_notebook()` to

# %%
anchors_df[anchors_df['anchor_id']=='18b'].plot(x='measurement_date', 
                                                y=['measured_anchor_load','installed_anchor_load'], 
                                                style=['-',':'])
# Out:
# /usr/local/lib/python2.7/dist-packages/pandas/plotting/_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %%
anchors_df["inventory_id"].unique()
#len(anchors_df["anchor_id"].unique())
# Out:
# array([u'02.08.60.410.50', u'02.08.60.723.02', u'02.08.60.410.51',
#        u'02.08.60.410.63', u'02.08.60.714.12', u'02.08.60.723.08',
#        u'02.08.60.410.55', u'02.08.60.723.07', u'02.08.60.410.54',
#        u'02.08.60.723.06', u'02.08.60.410.53', u'02.08.60.723.05',
#        u'02.08.60.410.52', u'02.08.60.723.04', u'02.08.60.723.09'],
#       dtype=object)

# %%
# temp fix for dealing with limitation that Bokeh can only download 10 plots
#anchors_SM5["anchor_id"].unique()
anchors_SM1["anchor_id"].unique()
# Out:
# array([u'24.1a', u'24.1b', u'20.a', u'20.b', u'19.a', u'19.b', u'18.a',
#        u'18.b', u'17.a', u'17.b', u'16.a', u'16.b', u'15.a', u'15.b',
#        u'14.a', u'14.b', u'10.b', u'9.b', u'18.2'], dtype=object)

# %%
anchors_SM5_1 = anchors_SM5[anchors_SM5.anchor_id.isin([u'1A.u',u'1A.o',u'1B.u', u'1B.o', u'2A.u', u'2A.o', u'2B.u',u'2B.o', u'3A.u', u'3A.o'])]
anchors_SM5_2 = anchors_SM5[anchors_SM5.anchor_id.isin([u'3B.u', u'3B.o', u'4A', u'4B', u'5A',u'5B', u'6A', u'6B', u'7A.u', u'7A.o'])]
anchors_SM5_3 = anchors_SM5[anchors_SM5.anchor_id.isin([u'7B.u', u'7B.o', u'8A.u',u'8A.o', u'8B.u', u'8B.o', u'8C'])]

anchors_SM1_1 = anchors_SM1[anchors_SM1.anchor_id.isin([u'24.1a', u'24.1b', u'20.a', u'20.b', u'19.a', u'19.b', u'18.a', u'18.b', u'17.a', u'17.b'])]
anchors_SM1_2 = anchors_SM1[anchors_SM1.anchor_id.isin([u'16.a', u'16.b', u'15.a', u'15.b', u'14.a', u'14.b', u'10.b', u'9.b', u'18.2'])]

# %%
# fix string values in anchor_id (anchor_id's with quotes are not processed by Pixidust)
anchors_chuebalm_ = anchors_chuebalm.astype({"anchor_id": str})
anchors_chuebalm_["anchor_id"] = anchors_chuebalm_["anchor_id"].str.replace('"', '')
anchors_tuffgraben_ = anchors_tuffgraben.astype({"anchor_id": str})
anchors_tuffgraben_["anchor_id"] = anchors_tuffgraben_["anchor_id"].str.replace('"', '')

# %%
# anchor load over time for all individual anchors at a structure
display(anchors_df)
#display(anchors_chuebalm_)
#display(anchors_tuffgraben_)

#display(anchors_df[anchors_df.structure_id.isin(['Bruecke Tuffgraben'])])

# NaN values taken as zero if Aggregation -> SUM used !!!
# NaN values omitted if Aggregation -> AVG used
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
