# %% [markdown]
# # Production Data Loading
#
#  1. Access Couchbase Database
#  1. Load CSV files and convert into JSON structure
#  1. Store the JSON data in Couchbase

# %% [markdown]
# ## Access Couchbase Database
#
#   * Created new Couchbase _bucket_ called _geotechnical_ using the Couchbase web browser interface

# %%
from couchbase.bucket import Bucket
cb = Bucket('couchbase://localhost/geotechnical')  # If no errors then the access works

# %% [markdown]
# ## Load CSV Data

# %%
# modified JK 2017.06.22

import json

from GeopyUtils import CsvDataReader

##projects_cdr = CsvDataReader('project', 'data/NEM/projects.csv')
##projects = projects_cdr.read()

##borehole_cdr = CsvDataReader('borehole', 'data/NEM/boreholes.csv')
##boreholes = borehole_cdr.read()

parameter_cdr = CsvDataReader('parameter', 'data/NT1/2017.06.23.NT1.DataOrganiser.Parameters.csv')
parameters = parameter_cdr.read()

print "Record counts: "
##print "  projects:   " + str(len(projects))
##print "  boreholes:  " + str(len(boreholes))
print "  parameters: " + str(len(parameters))
##print "TOTAL: "+str(len(projects)+len(boreholes)+len(parameters))
##print "\nExample JSON data: project[0]"
##print json.dumps(projects[0], indent=2)

##print "\nExample JSON data: borehole[0]"
##print json.dumps(boreholes[0], indent=2)

print "\nExample JSON data: parameters[180]"
print json.dumps(parameters[180], indent=2)
# Out:
# Record counts:
#   parameters: 181
#
# Example JSON data: parameters[180]
# {
#   "sample_description": "Construction Design",
#   "measurement_convention": "Residual strength",
#   "test_standard": "ASTM D3080",
#   "sample_code": "SM-4-3",
#   "test_parameters": [
#     {
#       "units": "MPa",
#       "description": "s3",
#       "value": "0.80"
#     },
#     {
#       "units": "",
#       "description": "",
#       "value": ""
#     }
#   ],
#   "laboratory": "KhonKaen University",
#   "test_comment": "",
#   "id": "parameter-20170623-113652-81361166",
#   "laboratory_test_code": "132",
#   "test_type": "Direct shear",
#   "value_scale": "Laboratory",
#   "project_code": "NT1",
#   "type": "parameter",
#   "lithology": "Sheared Mudstone",
#   "sample_depth_top_m": "",
#   "value_likelihood": "Data point",
#   "parameter": "tau",
#   "data_source": "Laboratory",
#   "borehole_code": "Diversion Tunnel",
#   "value": "0.49",
#   "test_date": "19.06.2017",
#   "value_unit": "MPa"
# }

# %% [markdown]
# # Store in Couchbase
#
#  * Only run this once!
#  * Then comment out the *cb.insert* statement

# %%
from couchbase.bucket import Bucket
cb = Bucket('couchbase://localhost/geotechnical')

def load_records(records):
    for record in records:
        id = record['id']
        ##cb.upsert(id,record)  # DISABLED!!!
        print "record: "+id+" ..inserted"

##print "\nLoading: projects"
##load_records(projects)

##print "\nLoading: boreholes"
##load_records(boreholes)

print "\nLoading: parameters"
load_records(parameters)
# Out:
# Loading: parameters
# record: parameter-20170623-113652-29511277 ..inserted
# record: parameter-20170623-113652-13473875 ..inserted
# record: parameter-20170623-113652-34827438 ..inserted
# record: parameter-20170623-113652-61542168 ..inserted
# record: parameter-20170623-113652-93210479 ..inserted
# record: parameter-20170623-113652-04909185 ..inserted
# record: parameter-20170623-113652-00863466 ..inserted
# record: parameter-20170623-113652-96504576 ..inserted
# record: parameter-20170623-113652-60239583 ..inserted
# record: parameter-20170623-113652-55118766 ..inserted
# record: parameter-20170623-113652-53180035 ..inserted
# record: parameter-20170623-113652-84273305 ..inserted
# record: parameter-20170623-113652-80614325 ..inserted
# record: parameter-20170623-113652-81390094 ..inserted
# record: parameter-20170623-113652-28942314 ..inserted
# record: parameter-20170623-113652-36742382 ..inserted
# record: parameter-20170623-113652-81672186 ..inserted
# record: parameter-20170623-113652-27674139 ..inserted
# record: parameter-20170623-113652-02535584 ..inserted
# record: parameter-20170623-113652-39217537 ..inserted
# record: parameter-20170623-113652-70363614 ..inserted
# record: parameter-20170623-113652-35936120 ..inserted
# record: parameter-20170623-113652-77830084 ..inserted
# record: parameter-20170623-113652-65840822 ..inserted
# record: parameter-20170623-113652-06854709 ..inserted
# record: parameter-20170623-113652-46898444 ..inserted
# record: parameter-20170623-113652-72382643 ..inserted
# record: parameter-20170623-113652-17603665 ..inserted
# record: parameter-20170623-113652-67181664 ..inserted
# record: parameter-20170623-113652-49498414 ..inserted
# record: parameter-20170623-113652-72777208 ..inserted
# record: parameter-20170623-113652-22994157 ..inserted
# record: parameter-20170623-113652-80721277 ..inserted
# record: parameter-20170623-113652-07345877 ..inserted
# record: parameter-20170623-113652-61671957 ..inserted
# record: parameter-20170623-113652-70327257 ..inserted
# record: parameter-20170623-113652-29495936 ..inserted
# record: parameter-20170623-113652-47284474 ..inserted
# record: parameter-20170623-113652-93799657 ..inserted
# record: parameter-20170623-113652-42059651 ..inserted
# record: parameter-20170623-113652-82313965 ..inserted
# record: parameter-20170623-113652-79612425 ..inserted
# record: parameter-20170623-113652-80567072 ..inserted
# record: parameter-20170623-113652-67044853 ..inserted
# record: parameter-20170623-113652-02095544 ..inserted
# record: parameter-20170623-113652-56262288 ..inserted
# record: parameter-20170623-113652-55727945 ..inserted
# record: parameter-20170623-113652-81980682 ..inserted
# record: parameter-20170623-113652-08843289 ..inserted
# record: parameter-20170623-113652-51698054 ..inserted
# record: parameter-20170623-113652-61438604 ..inserted
# record: parameter-20170623-113652-75794412 ..inserted
# record: parameter-20170623-113652-01349891 ..inserted
# record: parameter-20170623-113652-57805266 ..inserted
# record: parameter-20170623-113652-54957786 ..inserted
# record: parameter-20170623-113652-55478456 ..inserted
# record: parameter-20170623-113652-85589889 ..inserted
# record: parameter-20170623-113652-73602803 ..inserted
# record: parameter-20170623-113652-37472211 ..inserted
# record: parameter-20170623-113652-99520296 ..inserted
# record: parameter-20170623-113652-28840370 ..inserted
# record: parameter-20170623-113652-22012654 ..inserted
# record: parameter-20170623-113652-21944881 ..inserted
# record: parameter-20170623-113652-03138355 ..inserted
# record: parameter-20170623-113652-36978835 ..inserted
# record: parameter-20170623-113652-19278061 ..inserted
# record: parameter-20170623-113652-59620213 ..inserted
# record: parameter-20170623-113652-20405694 ..inserted
# record: parameter-20170623-113652-91142522 ..inserted
# record: parameter-20170623-113652-05968960 ..inserted
# record: parameter-20170623-113652-04302236 ..inserted
# record: parameter-20170623-113652-90800586 ..inserted
# record: parameter-20170623-113652-60212625 ..inserted
# record: parameter-20170623-113652-26898262 ..inserted
# record: parameter-20170623-113652-24505999 ..inserted
# record: parameter-20170623-113652-54372001 ..inserted
# record: parameter-20170623-113652-53804639 ..inserted
# record: parameter-20170623-113652-58153537 ..inserted
# record: parameter-20170623-113652-87536099 ..inserted
# record: parameter-20170623-113652-02168058 ..inserted
# record: parameter-20170623-113652-76462281 ..inserted
# record: parameter-20170623-113652-85388945 ..inserted
# record: parameter-20170623-113652-90709938 ..inserted
# record: parameter-20170623-113652-65143508 ..inserted
# record: parameter-20170623-113652-14322671 ..inserted
# record: parameter-20170623-113652-95754669 ..inserted
# record: parameter-20170623-113652-61352644 ..inserted
# record: parameter-20170623-113652-16995638 ..inserted
# record: parameter-20170623-113652-89315786 ..inserted
# record: parameter-20170623-113652-72611527 ..inserted
# record: parameter-20170623-113652-39481713 ..inserted
# record: parameter-20170623-113652-52658620 ..inserted
# record: parameter-20170623-113652-94608282 ..inserted
# record: parameter-20170623-113652-30501390 ..inserted
# record: parameter-20170623-113652-80933959 ..inserted
# record: parameter-20170623-113652-45845237 ..inserted
# record: parameter-20170623-113652-63608223 ..inserted
# record: parameter-20170623-113652-66362082 ..inserted
# record: parameter-20170623-113652-86190515 ..inserted
# record: parameter-20170623-113652-37339637 ..inserted
# record: parameter-20170623-113652-76019843 ..inserted
# record: parameter-20170623-113652-24703639 ..inserted
# record: parameter-20170623-113652-86198163 ..inserted
# record: parameter-20170623-113652-14783115 ..inserted
# record: parameter-20170623-113652-57037604 ..inserted
# record: parameter-20170623-113652-38532373 ..inserted
# record: parameter-20170623-113652-96419850 ..inserted
# record: parameter-20170623-113652-02191185 ..inserted
# record: parameter-20170623-113652-94107296 ..inserted
# record: parameter-20170623-113652-91174471 ..inserted
# record: parameter-20170623-113652-79098538 ..inserted
# record: parameter-20170623-113652-72345423 ..inserted
# record: parameter-20170623-113652-68068508 ..inserted
# record: parameter-20170623-113652-18049378 ..inserted
# record: parameter-20170623-113652-36179392 ..inserted
# record: parameter-20170623-113652-53159154 ..inserted
# record: parameter-20170623-113652-05153818 ..inserted
# record: parameter-20170623-113652-86194285 ..inserted
# record: parameter-20170623-113652-08989148 ..inserted
# record: parameter-20170623-113652-69812656 ..inserted
# record: parameter-20170623-113652-49521494 ..inserted
# record: parameter-20170623-113652-61621265 ..inserted
# record: parameter-20170623-113652-14768240 ..inserted
# record: parameter-20170623-113652-12864769 ..inserted
# record: parameter-20170623-113652-07483194 ..inserted
# record: parameter-20170623-113652-00381130 ..inserted
# record: parameter-20170623-113652-03579610 ..inserted
# record: parameter-20170623-113652-19090192 ..inserted
# record: parameter-20170623-113652-23017727 ..inserted
# record: parameter-20170623-113652-46904896 ..inserted
# record: parameter-20170623-113652-60086500 ..inserted
# record: parameter-20170623-113652-41635238 ..inserted
# record: parameter-20170623-113652-55715420 ..inserted
# record: parameter-20170623-113652-77311333 ..inserted
# record: parameter-20170623-113652-71579959 ..inserted
# record: parameter-20170623-113652-05449860 ..inserted
# record: parameter-20170623-113652-56835765 ..inserted
# record: parameter-20170623-113652-81039230 ..inserted
# record: parameter-20170623-113652-77059054 ..inserted
# record: parameter-20170623-113652-09997702 ..inserted
# record: parameter-20170623-113652-26034945 ..inserted
# record: parameter-20170623-113652-29759566 ..inserted
# record: parameter-20170623-113652-17939140 ..inserted
# record: parameter-20170623-113652-98810829 ..inserted
# record: parameter-20170623-113652-49001674 ..inserted
# record: parameter-20170623-113652-08268932 ..inserted
# record: parameter-20170623-113652-08394228 ..inserted
# record: parameter-20170623-113652-08798837 ..inserted
# record: parameter-20170623-113652-85531047 ..inserted
# record: parameter-20170623-113652-74240552 ..inserted
# record: parameter-20170623-113652-13946593 ..inserted
# record: parameter-20170623-113652-69974975 ..inserted
# record: parameter-20170623-113652-53579831 ..inserted
# record: parameter-20170623-113652-67591021 ..inserted
# record: parameter-20170623-113652-60264072 ..inserted
# record: parameter-20170623-113652-12945270 ..inserted
# record: parameter-20170623-113652-23201739 ..inserted
# record: parameter-20170623-113652-33633919 ..inserted
# record: parameter-20170623-113652-45848568 ..inserted
# record: parameter-20170623-113652-07164096 ..inserted
# record: parameter-20170623-113652-63155806 ..inserted
# record: parameter-20170623-113652-26544766 ..inserted
# record: parameter-20170623-113652-38405249 ..inserted
# record: parameter-20170623-113652-89514969 ..inserted
# record: parameter-20170623-113652-57534808 ..inserted
# record: parameter-20170623-113652-73862182 ..inserted
# record: parameter-20170623-113652-88496408 ..inserted
# record: parameter-20170623-113652-66813093 ..inserted
# record: parameter-20170623-113652-47056769 ..inserted
# record: parameter-20170623-113652-82611932 ..inserted
# record: parameter-20170623-113652-40731415 ..inserted
# record: parameter-20170623-113652-15050435 ..inserted
# record: parameter-20170623-113652-84306555 ..inserted
# record: parameter-20170623-113652-67339866 ..inserted
# record: parameter-20170623-113652-70898766 ..inserted
# record: parameter-20170623-113652-18113447 ..inserted
# record: parameter-20170623-113652-41934865 ..inserted
# record: parameter-20170623-113652-24401898 ..inserted
# record: parameter-20170623-113652-99848916 ..inserted
# record: parameter-20170623-113652-43748294 ..inserted
# record: parameter-20170623-113652-81361166 ..inserted

# %% [markdown]
# # Read Some Data

# %% [markdown]
# ## Create Default Index
#
#  * Required for querying. If you don't do this you get an error when you run queries
#  * This should only be run once. Note yet sure how to ensure that happend
#  * For now, run it once and then comment out the *cb.n1ql_query* statement

# %%
from couchbase.bucket import Bucket

# create a primary index on geotechnical bucket in couchbase
cb = Bucket('couchbase://localhost/geotechnical')
##cb.n1ql_query('CREATE PRIMARY INDEX ON geotechnical').execute()  # TODO this should only be run one time!
# running above query gave HTTPError: ... http_status=500. Primry Index was however created (couchbase browser).

# %%
import json

# check new data stored
from DataOrganizer import CouchbaseSelector

# -- Open the database

db = CouchbaseSelector('localhost','geotechnical')

##fields = ['parameter', 'type', 'value', 'value_unit']
##where = {'project_code':'NT1', 'type': 'parameter', 'parameter': 'E','data_source': 'Laboratory'}
##db.getParameter(parameter_name, fields, where)

recs = []
for rec in db.select(None, None):
##for rec in db.select(fields, where):
    print json.dumps(rec, indent=2)
    recs.append(rec)
    
print json.dumps(recs[0],indent=2)
print "\nTotal records: "+str(len(recs))
# Out:
# {
#   "geotechnical": {
#     "borehole_code": "NE1-05",
#     "collar_elevation_masl": "",
#     "y_project_coordinate": "1721741.8",
#     "x_project_coordinate": "712184.8",
#     "type": "borehole",
#     "id": "borehole-20170622-174516-05582985"
#   }
# }
# {
#   "geotechnical": {
#     "borehole_code": "NE1-12",
#     "collar_elevation_masl": "",
#     "y_project_coordinate": "1719777.5",
#     "x_project_coordinate": "717089.3",
#     "type": "borehole",
#     "id": "borehole-20170622-174516-11300620"
#   }
# }
# {
#   "geotechnical": {
#     "borehole_code": "NE1-08",
#     "collar_elevation_masl": "",
#     "y_project_coordinate": "1708099.92",
#     "x_project_coordinate": "716316.28",
#     "type": "borehole",
#     "id": "borehole-20170622-174516-23912291"
#   }
# }
# {
#   "geotechnical": {
#     "borehole_code": "NE1-07",
#     "collar_elevation_masl": "",
#     "y_project_coordinate": "1722689",
#     "x_project_coordinate": "711228.7",
#     "type": "borehole",
#     "id": "borehole-20170622-174516-27653986"
#   }
# }
# {
#   "geotechnical": {
#     "borehole_code": "NE1-10a",
#     "collar_elevation_masl": "",
#     "y_project_coordinate": "1708049.1",
#     "x_project_coordinate": "716348.7",
#     "type": "borehole",
#     "id": "borehole-20170622-174516-32247481"
#   }
# }
# {
#   "geotechnical": {
#     "borehole_code": "NE1-02",
#     "collar_elevation_masl": "",
#     "y_project_coordinate": "1720937.67",
#     "x_project_coordinate": "717213.76",
#     "type": "borehole",
#     "id": "borehole-20170622-174516-36599884"
#   }
# }
# {
#   "geotechnical": {
#     "borehole_code": "NE1-06",
#     "collar_elevation_masl": "",
#     "y_project_coordinate": "",
#     "x_project_coordinate": "",
#     "type": "borehole",
#     "id": "borehole-20170622-174516-37573956"
#   }
# }
# {
#   "geotechnical": {
#     "borehole_code": "NE1-01",
#     "collar_elevation_masl": "",
#     "y_project_coordinate": "1720999.33",
#     "x_project_coordinate": "717190.06",
#     "type": "borehole",
#     "id": "borehole-20170622-174516-39266317"
#   }
# }
# {
#   "geotechnical": {
#     "borehole_code": "NE1-14",
#     "collar_elevation_masl": "",
#     "y_project_coordinate": "1719738.4",
#     "x_project_coordinate": "717507.3",
#     "type": "borehole",
#     "id": "borehole-20170622-174516-40630348"
#   }
# }
# {
#   "geotechnical": {
#     "borehole_code": "NE1-13",
#     "collar_elevation_masl": "",
#     "y_project_coordinate": "1719550.5",
#     "x_project_coordinate": "716495.7",
#     "type": "borehole",
#     "id": "borehole-20170622-174516-48544201"
#   }
# }
# {
#   "geotechnical": {
#     "borehole_code": "NE1-15",
#     "collar_elevation_masl": "",
#     "y_project_coordinate": "1720916.13",
#     "x_project_coordinate": "717333.47",
#     "type": "borehole",
#     "id": "borehole-20170622-174516-48740477"
#   }
# }
# {
#   "geotechnical": {
#     "borehole_code": "NE1-11",
#     "collar_elevation_masl": "",
#     "y_project_coordinate": "1720838.8",
#     "x_project_coordinate": "717289.4",
#     "type": "borehole",
#     "id": "borehole-20170622-174516-60302042"
#   }
# }
# {
#   "geotechnical": {
#     "borehole_code": "NE1-03",
#     "collar_elevation_masl": "",
#     "y_project_coordinate": "1720882.06",
#     "x_project_coordinate": "717094.05",
#     "type": "borehole",
#     "id": "borehole-20170622-174516-66318427"
#   }
# }
# {
#   "geotechnical": {
#     "borehole_code": "NE1-04",
#     "collar_elevation_masl": "",
#     "y_project_coordinate": "1720943.4",
#     "x_project_coordinate": "713446.7",
#     "type": "borehole",
#     "id": "borehole-20170622-174516-66574135"
#   }
# }
# {
#   "geotechnical": {
#     "borehole_code": "NE1-09",
#     "collar_elevation_masl": "",
#     "y_project_coordinate": "1708082.75",
#     "x_project_coordinate": "716250.92",
#     "type": "borehole",
#     "id": "borehole-20170622-174516-85469632"
#   }
# }
# {
#   "geotechnical": {
#     "borehole_code": "NE1-10b",
#     "collar_elevation_masl": "",
#     "y_project_coordinate": "1708061.97",
#     "x_project_coordinate": "716360.1",
#     "type": "borehole",
#     "id": "borehole-20170622-174516-94840249"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "",
#     "test_standard": "ASTM 2166",
#     "laboratory": "LTEC",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE09",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "29",
#     "test_type": "Uniaxial compression",
#     "sample_description": "dry",
#     "id": "parameter-20170622-174516-01332636",
#     "type": "parameter",
#     "lithology": "Sericite",
#     "sample_depth_top_m": "19.15-19.25",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-09",
#     "value": "115.72",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "",
#     "test_standard": "",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "MPa",
#         "description": "s3",
#         "value": "1"
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE01-1",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "4",
#     "test_type": "Triaxial compression",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-01582750",
#     "type": "parameter",
#     "lithology": "Diorite",
#     "sample_depth_top_m": "13.45-13.55",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-01",
#     "value": "93.13",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "",
#     "test_standard": "ASTM 2166",
#     "laboratory": "LTEC",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE08",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "31",
#     "test_type": "Uniaxial compression",
#     "sample_description": "dry",
#     "id": "parameter-20170622-174516-01792118",
#     "type": "parameter",
#     "lithology": "Sericite",
#     "sample_depth_top_m": "16.3-16.45 ",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-08",
#     "value": "28.58",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "Es",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE07",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "17",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-03247360",
#     "type": "parameter",
#     "lithology": "Sandstone",
#     "sample_depth_top_m": "32.60-33.00",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-07",
#     "value": "13300",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE03",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "14",
#     "test_type": "Uniaxial compression",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-04690191",
#     "type": "parameter",
#     "lithology": "Pegmatite",
#     "sample_depth_top_m": "19.50-19.60",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-03",
#     "value": "122.42",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE12",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "21",
#     "test_type": "Uniaxial compression",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-05413451",
#     "type": "parameter",
#     "lithology": "Granodiorite",
#     "sample_depth_top_m": "34.05-34.20",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-12",
#     "value": "204.34",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "E50",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE07",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "19",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-06506482",
#     "type": "parameter",
#     "lithology": "Sandstone",
#     "sample_depth_top_m": "44.80-45.00",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-07",
#     "value": "44310",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE12",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "23",
#     "test_type": "Uniaxial compression",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-08514231",
#     "type": "parameter",
#     "lithology": "Diorite",
#     "sample_depth_top_m": "99.80-99.90",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-12",
#     "value": "183.13",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "E50",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE02",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "12",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-10001617",
#     "type": "parameter",
#     "lithology": "Pegmatite",
#     "sample_depth_top_m": "25.15-25.25",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-02",
#     "value": "52930",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "",
#     "test_standard": "ASTM 2166",
#     "laboratory": "LTEC",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE04",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "27",
#     "test_type": "Uniaxial compression",
#     "sample_description": "dry",
#     "id": "parameter-20170622-174516-10977084",
#     "type": "parameter",
#     "lithology": "Granodiorite",
#     "sample_depth_top_m": "24.1-24.25",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-04",
#     "value": "9.71",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "",
#     "test_standard": "",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "MPa",
#         "description": "s3",
#         "value": "1"
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE07-1",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "1",
#     "test_type": "Triaxial compression",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-11063381",
#     "type": "parameter",
#     "lithology": "Sandstone",
#     "sample_depth_top_m": "26.75-27.80",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-07",
#     "value": "140.66",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "Es",
#     "test_standard": "ASTM 2166",
#     "laboratory": "LTEC",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE04",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "26",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "dry",
#     "id": "parameter-20170622-174516-11720192",
#     "type": "parameter",
#     "lithology": "Granodiorite",
#     "sample_depth_top_m": "100.45-100.55",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-04",
#     "value": "5769.2",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "Et",
#     "test_standard": "ASTM 2166",
#     "laboratory": "LTEC",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE04",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "26",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "dry",
#     "id": "parameter-20170622-174516-12987005",
#     "type": "parameter",
#     "lithology": "Granodiorite",
#     "sample_depth_top_m": "100.45-100.55",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-04",
#     "value": "8475",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "Es",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE02",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "12",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-13476027",
#     "type": "parameter",
#     "lithology": "Pegmatite",
#     "sample_depth_top_m": "25.15-25.25",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-02",
#     "value": "29700",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "Es",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE07",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "15",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-13644660",
#     "type": "parameter",
#     "lithology": "Sandstone",
#     "sample_depth_top_m": "28.00-28.25",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-07",
#     "value": "14600",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "Es",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE03",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "14",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-14605015",
#     "type": "parameter",
#     "lithology": "Pegmatite",
#     "sample_depth_top_m": "19.50-19.60",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-03",
#     "value": "5650",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE07",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "17",
#     "test_type": "Uniaxial compression",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-19326049",
#     "type": "parameter",
#     "lithology": "Sandstone",
#     "sample_depth_top_m": "32.60-33.00",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-07",
#     "value": "134.33",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "E50",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE02",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "11",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-19616714",
#     "type": "parameter",
#     "lithology": "Diorite",
#     "sample_depth_top_m": "19.80-20.00",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-02",
#     "value": "24630",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "Es",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE07",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "18",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-20164395",
#     "type": "parameter",
#     "lithology": "Sandstone",
#     "sample_depth_top_m": "34.05-34.20",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-07",
#     "value": "30500",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "Es",
#     "test_standard": "ASTM 2166",
#     "laboratory": "LTEC",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE08",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "31",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "dry",
#     "id": "parameter-20170622-174516-21963802",
#     "type": "parameter",
#     "lithology": "Sericite",
#     "sample_depth_top_m": "16.3-16.45 ",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-08",
#     "value": "3891.9",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "E50",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE07",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "15",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-23959907",
#     "type": "parameter",
#     "lithology": "Sandstone",
#     "sample_depth_top_m": "28.00-28.25",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-07",
#     "value": "21290",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "Es",
#     "test_standard": "ASTM 2166",
#     "laboratory": "LTEC",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE08",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "32",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "dry",
#     "id": "parameter-20170622-174516-24266828",
#     "type": "parameter",
#     "lithology": "Sericite",
#     "sample_depth_top_m": "24.25-25.37",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-08",
#     "value": "6375",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE07",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "18",
#     "test_type": "Uniaxial compression",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-26399717",
#     "type": "parameter",
#     "lithology": "Sandstone",
#     "sample_depth_top_m": "34.05-34.20",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-07",
#     "value": "153.02",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "Es",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE01",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "10",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-26523617",
#     "type": "parameter",
#     "lithology": "Diorite",
#     "sample_depth_top_m": "22.80-23.10",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-01",
#     "value": "12800",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "",
#     "test_standard": "",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "MPa",
#         "description": "s3",
#         "value": "5"
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE07-3",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "3",
#     "test_type": "Triaxial compression",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-27424226",
#     "type": "parameter",
#     "lithology": "Sandstone",
#     "sample_depth_top_m": "31.00-31.15",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-07",
#     "value": "215.07",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "",
#     "test_standard": "",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "MPa",
#         "description": "s3",
#         "value": "3"
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE02-2",
#     "test_comment": "Marked as wrong, to be repeated",
#     "project_code": "NEM",
#     "laboratory_test_code": "8",
#     "test_type": "Triaxial compression",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-28164635",
#     "type": "parameter",
#     "lithology": "Diorite",
#     "sample_depth_top_m": "23.00-23.70",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-02",
#     "value": "172.15",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "E50",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE02",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "13",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-28570457",
#     "type": "parameter",
#     "lithology": "Diorite",
#     "sample_depth_top_m": "28.80-28.90",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-02",
#     "value": "21560",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "Et",
#     "test_standard": "ASTM 2166",
#     "laboratory": "LTEC",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE09",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "29",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "dry",
#     "id": "parameter-20170622-174516-30875116",
#     "type": "parameter",
#     "lithology": "Sericite",
#     "sample_depth_top_m": "19.15-19.25",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-09",
#     "value": "14813.1",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE12",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "20",
#     "test_type": "Uniaxial compression",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-32939424",
#     "type": "parameter",
#     "lithology": "Granodiorite",
#     "sample_depth_top_m": "46.75-46.85",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-12",
#     "value": "268.27",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "",
#     "test_standard": "ASTM 2166",
#     "laboratory": "LTEC",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE08",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "32",
#     "test_type": "Uniaxial compression",
#     "sample_description": "dry",
#     "id": "parameter-20170622-174516-33514021",
#     "type": "parameter",
#     "lithology": "Sericite",
#     "sample_depth_top_m": "24.25-25.37",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-08",
#     "value": "41.28",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "Et",
#     "test_standard": "ASTM 2166",
#     "laboratory": "LTEC",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE09",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "30",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "dry",
#     "id": "parameter-20170622-174516-34260199",
#     "type": "parameter",
#     "lithology": "Sericite",
#     "sample_depth_top_m": "23.45-23.55",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-09",
#     "value": "11893.5",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "",
#     "test_standard": "",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "MPa",
#         "description": "s3",
#         "value": "3"
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE07-2",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "2",
#     "test_type": "Triaxial compression",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-34915031",
#     "type": "parameter",
#     "lithology": "Sandstone",
#     "sample_depth_top_m": "27.60-27.80",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-07",
#     "value": "151.22",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "E50",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE12",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "20",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-35375071",
#     "type": "parameter",
#     "lithology": "Granodiorite",
#     "sample_depth_top_m": "46.75-46.85",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-12",
#     "value": "71420",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE07",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "16",
#     "test_type": "Uniaxial compression",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-36513529",
#     "type": "parameter",
#     "lithology": "Sandstone",
#     "sample_depth_top_m": "32.60-33.00",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-07",
#     "value": "158.28",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE02",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "13",
#     "test_type": "Uniaxial compression",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-36933370",
#     "type": "parameter",
#     "lithology": "Diorite",
#     "sample_depth_top_m": "28.80-28.90",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-02",
#     "value": "167.37",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "Et",
#     "test_standard": "ASTM 2166",
#     "laboratory": "LTEC",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE08",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "32",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "dry",
#     "id": "parameter-20170622-174516-37971614",
#     "type": "parameter",
#     "lithology": "Sericite",
#     "sample_depth_top_m": "24.25-25.37",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-08",
#     "value": "9053.3",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE07",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "15",
#     "test_type": "Uniaxial compression",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-39429883",
#     "type": "parameter",
#     "lithology": "Sandstone",
#     "sample_depth_top_m": "28.00-28.25",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-07",
#     "value": "104.25",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "Es",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE07",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "19",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-41139440",
#     "type": "parameter",
#     "lithology": "Sandstone",
#     "sample_depth_top_m": "44.80-45.00",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-07",
#     "value": "22100",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "Es",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE12",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "24",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-41645070",
#     "type": "parameter",
#     "lithology": "Granodiorite",
#     "sample_depth_top_m": "33.40-33.50",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-12",
#     "value": "21500",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "Et",
#     "test_standard": "ASTM 2166",
#     "laboratory": "LTEC",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE04",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "27",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "dry",
#     "id": "parameter-20170622-174516-42645633",
#     "type": "parameter",
#     "lithology": "Granodiorite",
#     "sample_depth_top_m": "24.1-24.25",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-04",
#     "value": "4799.2",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "Es",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE02",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "11",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-44189476",
#     "type": "parameter",
#     "lithology": "Diorite",
#     "sample_depth_top_m": "19.80-20.00",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-02",
#     "value": "18100",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "E50",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE12",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "22",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-46972923",
#     "type": "parameter",
#     "lithology": "Granodiorite",
#     "sample_depth_top_m": "87.15-87.25",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-12",
#     "value": "20940",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "E50",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE07",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "16",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-47263802",
#     "type": "parameter",
#     "lithology": "Sandstone",
#     "sample_depth_top_m": "32.60-33.00",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-07",
#     "value": "20800",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE12",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "22",
#     "test_type": "Uniaxial compression",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-49356757",
#     "type": "parameter",
#     "lithology": "Granodiorite",
#     "sample_depth_top_m": "87.15-87.25",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-12",
#     "value": "117.59",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE02",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "11",
#     "test_type": "Uniaxial compression",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-51489069",
#     "type": "parameter",
#     "lithology": "Diorite",
#     "sample_depth_top_m": "19.80-20.00",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-02",
#     "value": "153.5",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE07",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "19",
#     "test_type": "Uniaxial compression",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-52980020",
#     "type": "parameter",
#     "lithology": "Sandstone",
#     "sample_depth_top_m": "44.80-45.00",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-07",
#     "value": "193.46",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "Es",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE07",
#     "test_comment": "",
#     "project_code": "NEM",
#     "laboratory_test_code": "16",
#     "test_type": "E measured during uniaxial compressio",
#     "sample_description": "",
#     "id": "parameter-20170622-174516-53140229",
#     "type": "parameter",
#     "lithology": "Sandstone",
#     "sample_depth_top_m": "32.60-33.00",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NE1-07",
#     "value": "16800",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "Es",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "NE15",
# ...
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "",
#     "test_comment": "",
#     "project_code": "NT1",
#     "laboratory_test_code": "80",
#     "test_type": "Uniaxial compression",
#     "sample_description": "Construction Design",
#     "id": "parameter-20170623-113652-89315786",
#     "type": "parameter",
#     "lithology": "Siltstone",
#     "sample_depth_top_m": "",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NT1-A21",
#     "value": "45.90",
#     "test_date": "19.05.2017",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "Peak strength",
#     "test_standard": "ASTM D3080",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "MPa",
#         "description": "s3",
#         "value": "0.20"
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "SM-2-1",
#     "test_comment": "",
#     "project_code": "NT1",
#     "laboratory_test_code": "121",
#     "test_type": "Direct shear",
#     "sample_description": "Construction Design",
#     "id": "parameter-20170623-113652-89514969",
#     "type": "parameter",
#     "lithology": "Sheared Mudstone",
#     "sample_depth_top_m": "",
#     "value_likelihood": "Data point",
#     "parameter": "tau",
#     "data_source": "Laboratory",
#     "borehole_code": "Diversion Tunnel",
#     "value": "0.14",
#     "test_date": "17.06.2017",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "E50",
#     "test_standard": "ASTM D7012 B",
#     "laboratory": "",
#     "test_parameters": [
#       {
#         "units": "MPa",
#         "description": "s3",
#         "value": "2.10"
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "Mud",
#     "test_comment": "",
#     "project_code": "NT1",
#     "laboratory_test_code": "74",
#     "test_type": "E measured during triaxial compression",
#     "sample_description": "Basic Design",
#     "id": "parameter-20170623-113652-90709938",
#     "type": "parameter",
#     "lithology": "Siltstone",
#     "sample_depth_top_m": "22.00",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NT1-LB-ExpAdit",
#     "value": "1600.00",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "",
#     "test_standard": "ASTM D7012 B",
#     "laboratory": "",
#     "test_parameters": [
#       {
#         "units": "MPa",
#         "description": "s3",
#         "value": "2.10"
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "",
#     "test_comment": "",
#     "project_code": "NT1",
#     "laboratory_test_code": "72",
#     "test_type": "Triaxial compression",
#     "sample_description": "Basic Design",
#     "id": "parameter-20170623-113652-90800586",
#     "type": "parameter",
#     "lithology": "Siltstone",
#     "sample_depth_top_m": "70.38",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NT1-4",
#     "value": "43.80",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "",
#     "test_comment": "",
#     "project_code": "NT1",
#     "laboratory_test_code": "69",
#     "test_type": "E measured during uniaxial compression",
#     "sample_description": "Basic Design",
#     "id": "parameter-20170623-113652-91142522",
#     "type": "parameter",
#     "lithology": "Sandstone",
#     "sample_depth_top_m": "94.38",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NT1-9",
#     "value": "4594.00",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "",
#     "test_standard": "ASTM D7012 B",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "MPa",
#         "description": "s3",
#         "value": "1.00"
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "19-1",
#     "test_comment": "",
#     "project_code": "NT1",
#     "laboratory_test_code": "87",
#     "test_type": "Triaxial compression",
#     "sample_description": "Construction Design",
#     "id": "parameter-20170623-113652-91174471",
#     "type": "parameter",
#     "lithology": "Siltstone",
#     "sample_depth_top_m": "58.60",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NT1-19",
#     "value": "59.00",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "14-5",
#     "test_comment": "",
#     "project_code": "NT1",
#     "laboratory_test_code": "37",
#     "test_type": "Uniaxial compression",
#     "sample_description": "Construction Design",
#     "id": "parameter-20170623-113652-93210479",
#     "type": "parameter",
#     "lithology": "Red Sandstone",
#     "sample_depth_top_m": "56.80",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NT1-14",
#     "value": "105.35",
#     "test_date": "12.05.2017",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "",
#     "test_standard": "ASTM D7012 B",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "MPa",
#         "description": "s3",
#         "value": "3.00"
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "14-5",
#     "test_comment": "",
#     "project_code": "NT1",
#     "laboratory_test_code": "54",
#     "test_type": "Triaxial compression",
#     "sample_description": "Construction Design",
#     "id": "parameter-20170623-113652-93799657",
#     "type": "parameter",
#     "lithology": "Red Sandstone",
#     "sample_depth_top_m": "57.85",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NT1-14",
#     "value": "87.08",
#     "test_date": "08.05.2017",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "Es",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "",
#     "test_comment": "",
#     "project_code": "NT1",
#     "laboratory_test_code": "86",
#     "test_type": "E measured during uniaxial compression",
#     "sample_description": "Construction Design",
#     "id": "parameter-20170623-113652-94107296",
#     "type": "parameter",
#     "lithology": "Siltstone",
#     "sample_depth_top_m": "",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NT1-A22",
#     "value": "3940.00",
#     "test_date": "19.05.2017",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "",
#     "test_comment": "",
#     "project_code": "NT1",
#     "laboratory_test_code": "84",
#     "test_type": "Uniaxial compression",
#     "sample_description": "Construction Design",
#     "id": "parameter-20170623-113652-94608282",
#     "type": "parameter",
#     "lithology": "Siltstone",
#     "sample_depth_top_m": "",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NT1-A6",
#     "value": "39.38",
#     "test_date": "19.05.2017",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "E50",
#     "test_standard": "ASTM D7012 B",
#     "laboratory": "",
#     "test_parameters": [
#       {
#         "units": "MPa",
#         "description": "s3",
#         "value": "2.10"
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "Mud",
#     "test_comment": "",
#     "project_code": "NT1",
#     "laboratory_test_code": "77",
#     "test_type": "E measured during triaxial compression",
#     "sample_description": "Basic Design",
#     "id": "parameter-20170623-113652-95754669",
#     "type": "parameter",
#     "lithology": "Siltstone",
#     "sample_depth_top_m": "22.00",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NT1-LB-ExpAdit",
#     "value": "2000.00",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "Es",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "",
#     "test_comment": "",
#     "project_code": "NT1",
#     "laboratory_test_code": "84",
#     "test_type": "E measured during uniaxial compression",
#     "sample_description": "Construction Design",
#     "id": "parameter-20170623-113652-96419850",
#     "type": "parameter",
#     "lithology": "Siltstone",
#     "sample_depth_top_m": "",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NT1-A6",
#     "value": "4680.00",
#     "test_date": "19.05.2017",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "18-2",
#     "test_comment": "",
#     "project_code": "NT1",
#     "laboratory_test_code": "40",
#     "test_type": "Uniaxial compression",
#     "sample_description": "Construction Design",
#     "id": "parameter-20170623-113652-96504576",
#     "type": "parameter",
#     "lithology": "Siltstone",
#     "sample_depth_top_m": "23.50",
#     "value_likelihood": "Data point",
#     "parameter": "sigma_c",
#     "data_source": "Laboratory",
#     "borehole_code": "NT1-18",
#     "value": "19.98",
#     "test_date": "12.05.2017",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "Peak strength",
#     "test_standard": "ASTM D5607-95",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "MPa",
#         "description": "s3",
#         "value": "0.93"
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "1",
#     "test_comment": "",
#     "project_code": "NT1",
#     "laboratory_test_code": "104",
#     "test_type": "Direct shear",
#     "sample_description": "Construction Design",
#     "id": "parameter-20170623-113652-98810829",
#     "type": "parameter",
#     "lithology": "Siltstone",
#     "sample_depth_top_m": "23.50",
#     "value_likelihood": "Data point",
#     "parameter": "tau",
#     "data_source": "Laboratory",
#     "borehole_code": "NT1-18",
#     "value": "0.86",
#     "test_date": "14.06.2017",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "",
#     "test_standard": "ASTM D7012 D",
#     "laboratory": "",
#     "test_parameters": [
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "",
#     "test_comment": "",
#     "project_code": "NT1",
#     "laboratory_test_code": "60",
#     "test_type": "E measured during uniaxial compression",
#     "sample_description": "Basic Design",
#     "id": "parameter-20170623-113652-99520296",
#     "type": "parameter",
#     "lithology": "Siltstone",
#     "sample_depth_top_m": "64.70",
#     "value_likelihood": "Data point",
#     "parameter": "E",
#     "data_source": "Laboratory",
#     "borehole_code": "NT1-5",
#     "value": "1902.00",
#     "test_date": "",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "value_scale": "Laboratory",
#     "measurement_convention": "Residual strength",
#     "test_standard": "ASTM D3080",
#     "laboratory": "KhonKaen University",
#     "test_parameters": [
#       {
#         "units": "MPa",
#         "description": "s3",
#         "value": "0.20"
#       },
#       {
#         "units": "",
#         "description": "",
#         "value": ""
#       }
#     ],
#     "sample_code": "SM-4-1",
#     "test_comment": "",
#     "project_code": "NT1",
#     "laboratory_test_code": "130",
#     "test_type": "Direct shear",
#     "sample_description": "Construction Design",
#     "id": "parameter-20170623-113652-99848916",
#     "type": "parameter",
#     "lithology": "Sheared Mudstone",
#     "sample_depth_top_m": "",
#     "value_likelihood": "Data point",
#     "parameter": "tau",
#     "data_source": "Laboratory",
#     "borehole_code": "Diversion Tunnel",
#     "value": "0.17",
#     "test_date": "19.06.2017",
#     "value_unit": "MPa"
#   }
# }
# {
#   "geotechnical": {
#     "project_code": "TAG",
#     "project_coordinate_system": "UTM",
#     "type": "project",
#     "id": "project-20170622-174516-10551702",
#     "name": "Tagoloan"
#   }
# }
# {
#   "geotechnical": {
#     "project_code": "NEM",
#     "project_coordinate_system": "UTM",
#     "type": "project",
#     "id": "project-20170622-174516-52956332",
#     "name": "Nam E-Moun"
#   }
# }
# {
#   "geotechnical": {
#     "project_code": "BUB",
#     "project_coordinate_system": "UTM",
#     "type": "project",
#     "id": "project-20170622-174516-72672078",
#     "name": "Bubunawan"
#   }
# }
# {
#   "geotechnical": {
#     "project_code": "NT1",
#     "project_coordinate_system": "UTM",
#     "type": "project",
#     "id": "project-20170622-174516-76927550",
#     "name": "Nam Theun 1"
#   }
# }
# {
#   "geotechnical": {
#     "borehole_code": "NE1-05",
#     "collar_elevation_masl": "",
#     "y_project_coordinate": "1721741.8",
#     "x_project_coordinate": "712184.8",
#     "type": "borehole",
#     "id": "borehole-20170622-174516-05582985"
#   }
# }
#
# Total records: 279
