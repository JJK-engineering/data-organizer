# %%
# 2020.02.18 ...
# data analysis for ground anchors
# for ASTRA Thun

# %% [markdown]
# # description of anchor data analysis task
#
# (from hangouts chat) <br />
# <br />
# <br />
# <br />
# <br />

# %% [markdown]
# # setup

# %%
# setup for python ecosystem
import json
from math import *
import glob
import pandas as pd
import numpy as np
from IPython.core.display import HTML, display
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from scipy.stats import norm
from scipy.stats import lognorm
from scipy import stats

# %%
# setup for pandas
pd.set_option('display.max_rows', 5000)
pd.set_option('display.max_columns',100)

# %%
# setup for pixiedust data exploration
import pixiedust
from pixiedust.display import *
# installed:
# sudo pip install --user --upgrade pixiedust 
# sudo pip install seaborn
# sudo pip install bokeh

# "Bad 'legend' parameter value: None" when plotting bokeh with pixiedust
# https://github.com/org-arl/arlpy/issues/31 
# appears to be bug with bokeh, fix is to degrade the version of Bokeh 1.3
# sudo pip install bokeh==1.3.0
# Out:
# Pixiedust database opened successfully
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-watson-data-lab/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-watson-data-lab/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 1.1.18</span>
#         </div>

# %%
# define common functions

# function for calculating allowable anchor force
# based on SIA 260 (2013) 
# as documented in https://docs.google.com/spreadsheets/d/17GsuXH_9kubzu-f16cIugCzPtyKBbbA4Jdm00d-uyHU/edit#gid=469557799
#   steel_xsect_area = total steel cross-section, e.g. of steel tendon strands (mm)
#   steel_tensile_strength_char = characteristic tensile strength of anchor steel (N/mm2 = MPa)
#   anchor_load_char = anchor load when characteristic tensile strength of anchor steel is reached (kN)
def anchor_load_char_calc_sia260(steel_xsect_area, steel_tensile_strength_char):
    anchor_load_char = steel_xsect_area * steel_tensile_strength_char /1000.0
    return(anchor_load_char)

# function for determining capacity utilization of an anchor
# based on ASTRA "Risikoanalyse"  
# as documented in https://docs.google.com/spreadsheets/d/17GsuXH_9kubzu-f16cIugCzPtyKBbbA4Jdm00d-uyHU/edit#gid=4695577997
#   measured_anchor_load = measured anchor load during monitoring (kN)
#   measurement_tol = measurement tolerance (%)
#   anchor_capacity_utiliz = pro cent capacity utilization of an anchor (fraction between 0 and 1)
def anchor_capacity_utiliz_calc_astra(measured_anchor_load, measurement_tol, anchor_load_char):
    anchor_capacity_utiliz = measured_anchor_load * (1-measurement_tol/100) / anchor_load_char
    return(anchor_capacity_utiliz) 

# function for calculating change in anchor load to installed anchor load 
# based on ASTRA "Risikoanalyse"  
#   installed_anchor_load = anchor load at time of anchor installation (kN)
#   anchor_load_change = measured anchor load minus installed anchor load (kN, positive value means increase load)
def anchor_load_change_calc_astra(measured_anchor_load, installed_anchor_load):
    anchor_load_change = measured_anchor_load - installed_anchor_load
    return(anchor_load_change)


# TEMP WORK
# function for .... error bars ...
def error_bar_calc(installed_anchor_load):
    error_bars = 0.2 * installed_anchor_load
    return(error_bars)

# %% [markdown]
# # remarks on input data
#
# * data sources
#   * https://drive.google.com/drive/folders/1hg8eD9MrwUcdzMDHcKWOA0V6jrQybA9j
#   * spreadshhets for five example structures
#     * SM 4
#     * SM 1 + B18
#     * Felssicherung Chüebalm
#     * Brücke Tuffgraben
#     * SM 5
#
#
# * the data in the sources cited above were taken by Tosacano AF
#   from various reports and drawings made available from ASTRA; <br />
#   in this data analysis only data from the above five data sources are consdered
#
#
# * data in data sources is partly conflicted in other documents
#     * SM 4 in spreadsheet 'Untersuchung_Ankerkräfte_Risk  SM4' <br />
#       https://docs.google.com/spreadsheets/d/17GsuXH_9kubzu-f16cIugCzPtyKBbbA4Jdm00d-uyHU/edit#gid=1364999228 <br />
#       --> differences in steel area and steel strength
#
#
# * each measurment is a data record, i.e. a spreadshet row in the CSV sheet; <br />
#   having records for all measurements (years) in the same row is not good data practice and is not the data structure expected by dataframes (pandas) <br />
#   [I suppose yearly data could be though of as a time series, but this seems like a convoluted way to work.]
#
#
# * data from the spreadsheets was prepared by linking the original data in each spreadsheet to a CSV worksheet in the same worksheet, <br /> using common headers agreed specifically for this work, and then exporting the CSV worksheet
#
#
# * structure_id and anchor_id
#   * decimals (and spaces) in IDs are bad data practice
#
#
# * the data from the intial anchor measurements (labelled P0 in the source spreadsheets) is enetered both as   installed_anchor_load and measured_anchor_load data; <br />
#  this foresees that the two data sets may difer, e.g. installed_anchor_load may correspond to the intial prescribed load ("Festsetzkraft") and the measured_anchor_load may correspond to the actual installed anchor load (which may differ from the prescribe load if within a specified tolerance)
#
#
# * the data entry sheet, the CSV sheet and the data column headers require additional review and refinement <br />
#   before the collection and preparation of additional anchor data (see also remarks to data table design below)

# %% [markdown]
# # remarks to flat table from CSV sheet in spreadsheet:
#
# * the CSV sheet for anchor data is configured as a single flat table <br />
#   using a common header line with header titles for each data column
# * the data structure suggests that two separate tables (anchor data table, measurment data table) should be used, <br />
#   which would e.g. avoid the repetition of anchor data for each measurment record
# * the anchor data table and measurment data table would then be joined in pandas into a single table
# * a single flat table is used in this preliminary proof-of-concept work to simplify data preparation
# * an appropriate data table design, e.g. using separate anchor data tables and measurment data tables <br />
#   should be completed before additional input data is prepared
# * a separate data entry sheet in the spreadsheet should be designed together with the data table design; <br />
#   the purpose of the data entry sheet is to make data entry as easy and error free as possible, <br />
#   with the CSV sheet being configured separately and structured for data analysis
#
#
# * the first header line is intended for accessing data from python code and is in English using snake_case
# * a second header line is in German text and is intended to be used for figure and table titles
# * additional header lines could be added for other languages
#
#
# * additional data tables to consider are
#   * structures table <br />
#     using an appropriate structures id as a database key
#   * anchor type table (?) <br />
#     considering however that this will complicate data entry and whether anchor detail data is required

# %% [markdown]
# # data input

# %%
# read in csv files containign anchor data
anchors_df = pd.concat([pd.read_csv(f, header=[0,1], encoding='utf-8') for f in glob.glob('data/ASTRA/IN/v0/*.csv')], 
                       ignore_index = True)

# remove second header line (for this work)
anchors_df.columns = anchors_df.columns.droplevel(-1)

#glob.glob('data/ASTRA/*.csv')  #testing
anchors_df.dtypes  #testing
# Out:
# structure_id                            object
# structure_name                          object
# structure_type                          object
# anchor_id                               object
# anchor_type                            float64
# steel_tensile_strength_char            float64
# steel_xsect_area                       float64
# anchor_load_char_calculation_method    float64
# anchor_load_char                       float64
# warning_value_calculation_method       float64
# alarm_value_calculation_method         float64
# warning_value                          float64
# alarm_value                            float64
# installation_date                      float64
# installed_anchor_load                  float64
# measurement_date                         int64
# measured_anchor_load                   float64
# stress_unit                             object
# force_unit                              object
# area_unit                               object
# dtype: object

# %% [markdown]
# # data analysis

# %%
# calculated fields

anchors_df["anchor_load_char"] = anchor_load_char_calc_sia260(anchors_df.steel_xsect_area, 
                                                anchors_df.steel_tensile_strength_char)

measurement_tol = 2.5  # %
anchors_df["anchor_capacity_utiliz"] = anchor_capacity_utiliz_calc_astra(anchors_df.measured_anchor_load, 
                                                measurement_tol, anchors_df.anchor_load_char)

anchors_df["anchor_load_change"] = anchor_load_change_calc_astra(anchors_df.measured_anchor_load, 
                                                anchors_df.installed_anchor_load)


# TEMP WORK
anchors_df["error_bars"] = error_bar_calc(anchors_df.installed_anchor_load)

# %%
#anchors_df[anchors_df.anchor_id.isin(['9a','9b'])]
#anchors_df[anchors_df.structure_id.isin(['SM4'])]
anchors_SM4 = anchors_df[anchors_df.structure_id.isin(['SM4'])]
anchors_SM1 = anchors_df[anchors_df.structure_id.isin(['SM1'])]

# %% [markdown]
# # testing

# %%
# configure date columns
#   dates in original data and csv data are year only
#   year date yyyy will be presumed as yyyy/01/01

# %%
# data validity checking
#   test suite for testing data validity checking 
#   (e.g. string instead of float value, blank lines in csv data, garbled header title, ID fields NaN)

# how to introduce plausibility checking for measurement data?
#   simply omitting out-of-range values is not good, as anchors can conceivably fail e.g. leading to low measured values
#   maybe warning message and a function to manually delete a value, adding a comment to a new comment field?

# how to introduce plausibility checking for calculated data?
#   e.g if suspect capacity utilization in initial measurement

# %%
# function testing

steel_xsect_area = 1116  # mm2
steel_tensile_strength_char = 1770  # MPa
anchor_load_char = anchor_load_char_calc_sia260(steel_xsect_area, steel_tensile_strength_char)
print(anchor_load_char)

measured_anchor_load = 1100.0  #kN
measurement_tol = 2.5  # %
anchor_capacity_utiliz = anchor_capacity_utiliz_calc_astra(measured_anchor_load, measurement_tol, anchor_load_char)
print(anchor_capacity_utiliz)

installed_anchor_load = 1000.0
anchor_load_change = anchor_load_change_calc_astra(measured_anchor_load, installed_anchor_load)
print(anchor_load_change)
# Out:
# 1975.32
# 0.542950003037
# 100.0

# %%
# end-to-end testing
anchors_SM4[anchors_df['measurement_date']==2019].describe()
#anchors_SM4[anchors_df['measurement_date']==2019].sum()
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#        anchor_type  steel_tensile_strength_char  steel_xsect_area  \
# count          0.0                         28.0              28.0
# mean           NaN                       1770.0            1116.0
# std            NaN                          0.0               0.0
# min            NaN                       1770.0            1116.0
# 25%            NaN                       1770.0            1116.0
# 50%            NaN                       1770.0            1116.0
# 75%            NaN                       1770.0            1116.0
# max            NaN                       1770.0            1116.0
#
#        anchor_load_char_calculation_method  anchor_load_char  \
# count                                  0.0             28.00
# mean                                   NaN           1975.32
# std                                    NaN              0.00
# min                                    NaN           1975.32
# 25%                                    NaN           1975.32
# 50%                                    NaN           1975.32
# 75%                                    NaN           1975.32
# max                                    NaN           1975.32
#
#        warning_value_calculation_method  alarm_value_calculation_method  \
# count                               0.0                             0.0
# mean                                NaN                             NaN
# std                                 NaN                             NaN
# min                                 NaN                             NaN
# 25%                                 NaN                             NaN
# 50%                                 NaN                             NaN
# 75%                                 NaN                             NaN
# max                                 NaN                             NaN
#
#        warning_value  alarm_value  installation_date  installed_anchor_load  \
# count            0.0          0.0               20.0              20.000000
# mean             NaN          NaN             1984.0             960.000000
# std              NaN          NaN                0.0             104.629673
# min              NaN          NaN             1984.0             600.000000
# 25%              NaN          NaN             1984.0            1000.000000
# 50%              NaN          NaN             1984.0            1000.000000
# 75%              NaN          NaN             1984.0            1000.000000
# max              NaN          NaN             1984.0            1000.000000
#
#        measurement_date  measured_anchor_load  anchor_capacity_utiliz  \
# count              28.0             28.000000               28.000000
# mean             2019.0            995.750000                0.491493
# std                 0.0             90.342404                0.044592
# min              2019.0            620.000000                0.306026
# 25%              2019.0            992.000000                0.489642
# 50%              2019.0           1013.500000                0.500254
# 75%              2019.0           1044.250000                0.515432
# max              2019.0           1091.000000                0.538508
#
#        anchor_load_change  error_bars
# count           20.000000   20.000000
# mean            31.350000  192.000000
# std             30.014514   20.925935
# min            -24.000000  120.000000
# 25%             14.250000  200.000000
# 50%             40.000000  200.000000
# 75%             48.250000  200.000000
# max             91.000000  200.000000

# %%
# check handling of NaN values by pandas plot -> NaN values are omitted in plot
# plot of anchor loads vs index    
#anchors_SM4.measured_anchor_load
anchors_SM4.measured_anchor_load.plot()

# %% [markdown]
# # dataframe views

# %%
anchors_df
#anchors_df[anchors_df['structure_id']=='SM1']
#anchors_df[anchors_df['anchor_id']=='18b']
# Out:
#                structure_id                       structure_name  \
# 0    Felssicherung Chuebalm            Chüebalmtunnel Westportal
# 1    Felssicherung Chuebalm            Chüebalmtunnel Westportal
# 2    Felssicherung Chuebalm            Chüebalmtunnel Westportal
# 3    Felssicherung Chuebalm            Chüebalmtunnel Westportal
# 4    Felssicherung Chuebalm            Chüebalmtunnel Westportal
# 5    Felssicherung Chuebalm            Chüebalmtunnel Westportal
# 6    Felssicherung Chuebalm            Chüebalmtunnel Westportal
# 7    Felssicherung Chuebalm            Chüebalmtunnel Westportal
# 8    Felssicherung Chuebalm            Chüebalmtunnel Westportal
# 9    Felssicherung Chuebalm            Chüebalmtunnel Westportal
# 10   Felssicherung Chuebalm            Chüebalmtunnel Westportal
# 11   Felssicherung Chuebalm            Chüebalmtunnel Westportal
# 12   Felssicherung Chuebalm            Chüebalmtunnel Westportal
# 13   Felssicherung Chuebalm            Chüebalmtunnel Westportal
# 14   Felssicherung Chuebalm            Chüebalmtunnel Westportal
# 15   Felssicherung Chuebalm            Chüebalmtunnel Westportal
# 16   Felssicherung Chuebalm            Chüebalmtunnel Westportal
# 17   Felssicherung Chuebalm            Chüebalmtunnel Westportal
# 18   Felssicherung Chuebalm            Chüebalmtunnel Westportal
# 19   Felssicherung Chuebalm            Chüebalmtunnel Westportal
# 20   Felssicherung Chuebalm            Chüebalmtunnel Westportal
# 21                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 22                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 23                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 24                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 25                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 26                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 27                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 28                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 29                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 30                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 31                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 32                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 33                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 34                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 35                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 36                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 37                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 38                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 39                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 40                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 41                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 42                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 43                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 44                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 45                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 46                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 47                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 48                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 49                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 50                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 51                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 52                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 53                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 54                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 55                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 56                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 57                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 58                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 59                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 60                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 61                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 62                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 63                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 64                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 65                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 66                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 67                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 68                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 69                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 70                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 71                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 72                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 73                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 74                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 75                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 76                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 77                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 78                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 79                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 80                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 81                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 82                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 83                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 84                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 85                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 86                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 87                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 88                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 89                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 90                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 91                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 92                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 93                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 94                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 95                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 96                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 97                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 98                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 99                      SM5          N8, Bönigen-Iseltwald, Sm 5
# 100                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 101                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 102                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 103                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 104                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 105                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 106                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 107                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 108                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 109                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 110                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 111                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 112                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 113                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 114                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 115                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 116                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 117                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 118                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 119                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 120                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 121                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 122                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 123                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 124                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 125                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 126                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 127                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 128                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 129                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 130                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 131                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 132                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 133                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 134                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 135                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 136                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 137                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 138                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 139                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 140                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 141                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 142                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 143                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 144                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 145                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 146                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 147                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 148                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 149                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 150                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 151                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 152                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 153                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 154                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 155                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 156                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 157                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 158                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 159                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 160                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 161                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 162                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 163                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 164                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 165                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 166                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 167                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 168                     SM5          N8, Bönigen-Iseltwald, Sm 5
# 169                     SM5          N8, Bönigen-Iseltwald, Sm 5
#
# 179     Stützmauer      8A.o          NaN                       1770.0
# 180     Stützmauer      8B.u          NaN                       1770.0
# 181     Stützmauer      8B.o          NaN                       1770.0
# 182     Stützmauer        8C          NaN                       1770.0
# 183     Stützmauer       30a          NaN                       1770.0
# 184     Stützmauer       30b          NaN                       1770.0
# 185     Stützmauer       29a          NaN                       1770.0
# 186     Stützmauer       29b          NaN                       1770.0
# 187     Stützmauer       29c          NaN                       1770.0
# 188     Stützmauer       29d          NaN                       1770.0
# 189     Stützmauer        28          NaN                       1770.0
# 190     Stützmauer        25          NaN                       1770.0
# 191     Stützmauer       24a          NaN                       1770.0
# 192     Stützmauer        24          NaN                       1770.0
# 193     Stützmauer        23          NaN                       1770.0
# 194     Stützmauer       23a          NaN                       1770.0
# 195     Stützmauer      22.1          NaN                       1770.0
# 196     Stützmauer      19.1          NaN                       1770.0
# 197     Stützmauer       18a          NaN                       1770.0
# 198     Stützmauer       18b          NaN                       1770.0
# 199     Stützmauer       18c          NaN                       1770.0
# 200     Stützmauer       18d          NaN                       1770.0
# 201     Stützmauer        17          NaN                       1770.0
# 202     Stützmauer        14          NaN                       1770.0
# 203     Stützmauer       13a          NaN                       1770.0
# 204     Stützmauer       13b          NaN                       1770.0
# 205     Stützmauer       13c          NaN                       1770.0
# 206     Stützmauer       13d          NaN                       1770.0
# 207     Stützmauer        12          NaN                       1770.0
# 208     Stützmauer        10          NaN                       1770.0
# 209     Stützmauer        9a          NaN                       1770.0
# 210     Stützmauer        9b          NaN                       1770.0
# ...
# 216                     NaN                 NaN         NaN
# 217                     NaN                 NaN         NaN
# 218                     NaN                 NaN         NaN
# 219                     NaN                 NaN         NaN
# 220                0.523206                60.0       200.0
# 221                0.525674                65.0       200.0
# 222                     NaN                 NaN         NaN
# 223                0.409680                30.0       160.0
# 224                0.431398                74.0       160.0
# 225                0.528142                70.0       200.0
# 226                0.503956                21.0       200.0
# 227                0.322315                53.0       120.0
# 228                     NaN                 NaN         NaN
# 229                0.497540                 8.0       200.0
# 230                0.508399                30.0       200.0
# 231                0.522219                58.0       200.0
# 232                0.538014                90.0       200.0
# 233                0.520738                55.0       200.0
# 234                     NaN                 NaN         NaN
# 235                0.510867                35.0       200.0
# 236                0.528142                70.0       200.0
# 237                0.523206                60.0       200.0
# 238                0.525674                65.0       200.0
# 239                0.516296                46.0       200.0
# 240                0.509386                32.0       200.0
# 241                0.470886               -46.0       200.0
# 242                0.491617                -4.0       200.0
# 243                     NaN                 NaN         NaN
# 244                     NaN                 NaN         NaN
# 245                     NaN                 NaN         NaN
# 246                     NaN                 NaN         NaN
# 247                     NaN                 NaN         NaN
# 248                0.514322                42.0       200.0
# 249                0.516790                47.0       200.0
# 250                     NaN                 NaN         NaN
# 251                0.410668                32.0       160.0
# 252                0.427450                66.0       160.0
# 253                0.512347                38.0       200.0
# 254                0.490136                -7.0       200.0
# 255                0.296155                 0.0       120.0
# 256                     NaN                 NaN         NaN
# 257                0.488655               -10.0       200.0
# 258                0.490629                -6.0       200.0
# 259                0.489149                -9.0       200.0
# 260                0.512347                38.0       200.0
# 261                0.500995                15.0       200.0
# 262                     NaN                 NaN         NaN
# 263                0.496059                 5.0       200.0
# 264                0.501488                16.0       200.0
# 265                0.527155                68.0       200.0
# 266                0.505931                25.0       200.0
# 267                0.534559                83.0       200.0
# 268                0.520738                55.0       200.0
# 269                0.483719               -20.0       200.0
# 270                0.504450                22.0       200.0
# 271                     NaN                 NaN         NaN
# 272                     NaN                 NaN         NaN
# 273                     NaN                 NaN         NaN
# 274                     NaN                 NaN         NaN
# 275                     NaN                 NaN         NaN
# 276                0.518764                51.0       200.0
# 277                0.522219                58.0       200.0
# 278                     NaN                 NaN         NaN
# 279                0.409680                30.0       160.0
# 280                0.429918                71.0       160.0
# 281                0.519751                53.0       200.0
# 282                0.501488                16.0       200.0
# 283                0.305039                18.0       120.0
# 284                     NaN                 NaN         NaN
# 285                0.490136                -7.0       200.0
# 286                0.493591                 0.0       200.0
# 287                0.520738                55.0       200.0
# 288                0.497540                 8.0       200.0
# 289                0.514322                42.0       200.0
# 290                     NaN                 NaN         NaN
# 291                0.499514                12.0       200.0
# 292                0.478290               -31.0       200.0
# 293                0.529623                73.0       200.0
# 294                0.517283                48.0       200.0
# 295                     NaN                 NaN       200.0
# 296                     NaN                 NaN       200.0
# 297                     NaN                 NaN       200.0
# 298                     NaN                 NaN       200.0
# 299                0.495565                 NaN         NaN
# 300                0.495565                 NaN         NaN
# 301                0.495565                 NaN         NaN
# 302                0.495565                 NaN         NaN
# 303                0.495565                 NaN         NaN
# 304                     NaN                 NaN       200.0
# 305                     NaN                 NaN       200.0
# 306                0.495565                 NaN         NaN
# 307                     NaN                 NaN       160.0
# 308                     NaN                 NaN       160.0
# 309                     NaN                 NaN       200.0
# 310                     NaN                 NaN       200.0
# 311                     NaN                 NaN       120.0
# 312                0.495565                 NaN         NaN
# 313                     NaN                 NaN       200.0
# 314                     NaN                 NaN       200.0
# 315                     NaN                 NaN       200.0
# 316                     NaN                 NaN       200.0
# 317                     NaN                 NaN       200.0
# 318                0.495565                 NaN         NaN
# 319                     NaN                 NaN       200.0
# 320                     NaN                 NaN       200.0
# 321                     NaN                 NaN       200.0
# 322                     NaN                 NaN       200.0
# 323                0.538508                91.0       200.0
# 324                0.521726                57.0       200.0
# 325                0.490629                -6.0       200.0
# 326                0.519258                52.0       200.0
# 327                0.526168                 NaN         NaN
# 328                0.513828                 NaN         NaN
# 329                0.498033                 NaN         NaN
# 330                0.479770                 NaN         NaN
# 331                0.497540                 NaN         NaN
# 332                0.520738                55.0       200.0
# 333                0.512347                38.0       200.0
# 334                0.477302                 NaN         NaN
# 335                0.415604                42.0       160.0
# 336                0.433373                78.0       160.0
# 337                0.514815                43.0       200.0
# 338                0.500995                15.0       200.0
# 339                0.306026                20.0       120.0
# 340                0.490629                 NaN         NaN
# 341                0.486681               -14.0       200.0
# 342                0.492110                -3.0       200.0
# 343                0.516790                47.0       200.0
# 344                0.499514                12.0       200.0
# 345                0.515803                45.0       200.0
# 434                     NaN               160.0       200.0
# 435                     NaN               195.0       200.0
# 436                     NaN                30.0       200.0
# 437                     NaN               218.0       200.0
# 438                     NaN               188.0       200.0
# 439                     NaN                97.0       200.0
# 440                     NaN               105.0       200.0
# 441                     NaN                97.0       150.0
# 442                     NaN               100.0       150.0
# 443                     NaN               304.0       200.0
# 444                     NaN               198.0       200.0
# 445                     NaN               104.0       184.0
# 446                     NaN               156.0       200.0
# 447                     NaN               130.0       200.0
# 448                     NaN               102.0       200.0
# 449                     NaN               138.0       200.0
# 450                     NaN               240.0       200.0
# 451                     NaN               127.0       200.0
# 452                     NaN               102.0       200.0
# 453                     NaN               156.0       200.0
# 454                     NaN               149.0       200.0
# 455                     NaN                55.0       200.0
# 456                     NaN               153.0       200.0
# 457                     NaN               120.0       200.0
# 458                     NaN                66.0       200.0
# 459                     NaN                84.0       200.0
# 460                     NaN                38.0       150.0
# 461                     NaN                81.0       150.0
# 462                     NaN               283.0       200.0
# 463                     NaN               157.0       200.0
# 464                     NaN                97.0       184.0
# 465                     NaN                 0.0       180.0
# 466                     NaN                 0.0       180.0
# 467                     NaN                 0.0       180.0
# 468                     NaN                80.0       180.0
# 469                     NaN                83.0       180.0
# 470                     NaN                60.0       180.0
# 471                     NaN               105.0       180.0
# 472                     NaN               104.0       180.0
# 473                     NaN               110.0       180.0

# %%
anchors_SM1
# Out:
#     structure_id                       structure_name structure_type  \
# 351          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18            NaN
# 352          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 353          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 354          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 355          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 356          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 357          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 358          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 359          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 360          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 361          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 362          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 363          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 364          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 365          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 366          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 367          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 368          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 369          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 370          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 371          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 372          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 373          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 374          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 375          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 376          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 377          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 378          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 379          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 380          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 381          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 382          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 383          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 384          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 385          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 386          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 387          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 388          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 389          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 390          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 391          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 392          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 393          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 394          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 395          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 396          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 397          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 398          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 399          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 400          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 401          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 402          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 403          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 404          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 405          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 406          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 407          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 408          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 409          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 410          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 411          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 412          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 413          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 414          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 415          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 416          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 417          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 418          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 419          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 420          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 421          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 422          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 423          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 424          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 425          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 426          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 427          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 428          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 429          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 430          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 431          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 432          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 433          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 434          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 435          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 436          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 437          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 438          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 439          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 440          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 441          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 442          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 443          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 444          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 445          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 446          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 447          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 448          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 449          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 450          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 451          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 452          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 453          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 454          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 455          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 456          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 457          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 458          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 459          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 460          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 461          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 462          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 463          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
# 464          SM1  N8, Bönigen-Iseltwald, Sm 1 und B18     Stützmauer
#
#     anchor_id  anchor_type  steel_tensile_strength_char  steel_xsect_area  \
# 351     24.1a          NaN                          NaN               NaN
# 352     24.1b          NaN                          NaN               NaN
# 353      20.a          NaN                          NaN               NaN
# 354      20.b          NaN                          NaN               NaN
# 355      19.a          NaN                          NaN               NaN
# 356      19.b          NaN                          NaN               NaN
# 357      18.a          NaN                          NaN               NaN
# 358      18.b          NaN                          NaN               NaN
# 359      17.a          NaN                          NaN               NaN
# 360      17.b          NaN                          NaN               NaN
# 361      16.a          NaN                          NaN               NaN
# 362      16.b          NaN                          NaN               NaN
# 363      15.a          NaN                          NaN               NaN
# 364      15.b          NaN                          NaN               NaN
# 365      14.a          NaN                          NaN               NaN
# 366      14.b          NaN                          NaN               NaN
# 367      10.b          NaN                          NaN               NaN
# 368       9.b          NaN                          NaN               NaN
# 369      18.2          NaN                          NaN               NaN
# 370     24.1a          NaN                          NaN               NaN
# 371     24.1b          NaN                          NaN               NaN
# 372      20.a          NaN                          NaN               NaN
# 373      20.b          NaN                          NaN               NaN
# 374      19.a          NaN                          NaN               NaN
# 375      19.b          NaN                          NaN               NaN
# 376      18.a          NaN                          NaN               NaN
# 377      18.b          NaN                          NaN               NaN
# 378      17.a          NaN                          NaN               NaN
# 379      17.b          NaN                          NaN               NaN
# 380      16.a          NaN                          NaN               NaN
# 381      16.b          NaN                          NaN               NaN
# 382      15.a          NaN                          NaN               NaN
# 383      15.b          NaN                          NaN               NaN
# 384      14.a          NaN                          NaN               NaN
# 385      14.b          NaN                          NaN               NaN
# 386      10.b          NaN                          NaN               NaN
# 387       9.b          NaN                          NaN               NaN
# 388      18.2          NaN                          NaN               NaN
# 389     24.1a          NaN                          NaN               NaN
# 390     24.1b          NaN                          NaN               NaN
# 391      20.a          NaN                          NaN               NaN
# 392      20.b          NaN                          NaN               NaN
# 393      19.a          NaN                          NaN               NaN
# 394      19.b          NaN                          NaN               NaN
# 395      18.a          NaN                          NaN               NaN
# 396      18.b          NaN                          NaN               NaN
# 397      17.a          NaN                          NaN               NaN
# 398      17.b          NaN                          NaN               NaN
# 399      16.a          NaN                          NaN               NaN
# 400      16.b          NaN                          NaN               NaN
# 401      15.a          NaN                          NaN               NaN
# 402      15.b          NaN                          NaN               NaN
# 403      14.a          NaN                          NaN               NaN
# 404      14.b          NaN                          NaN               NaN
# 405      10.b          NaN                          NaN               NaN
# 406       9.b          NaN                          NaN               NaN
# 407      18.2          NaN                          NaN               NaN
# 408     24.1a          NaN                          NaN               NaN
# 409     24.1b          NaN                          NaN               NaN
# 410      20.a          NaN                          NaN               NaN
# 411      20.b          NaN                          NaN               NaN
# 412      19.a          NaN                          NaN               NaN
# 413      19.b          NaN                          NaN               NaN
# 414      18.a          NaN                          NaN               NaN
# 415      18.b          NaN                          NaN               NaN
# 416      17.a          NaN                          NaN               NaN
# 417      17.b          NaN                          NaN               NaN
# 418      16.a          NaN                          NaN               NaN
# 419      16.b          NaN                          NaN               NaN
# 420      15.a          NaN                          NaN               NaN
# 421      15.b          NaN                          NaN               NaN
# 422      14.a          NaN                          NaN               NaN
# 423      14.b          NaN                          NaN               NaN
# 424      10.b          NaN                          NaN               NaN
# 425       9.b          NaN                          NaN               NaN
# 426      18.2          NaN                          NaN               NaN
# 427     24.1a          NaN                          NaN               NaN
# 428     24.1b          NaN                          NaN               NaN
# 429      20.a          NaN                          NaN               NaN
# 430      20.b          NaN                          NaN               NaN
# 431      19.a          NaN                          NaN               NaN
# 432      19.b          NaN                          NaN               NaN
# 433      18.a          NaN                          NaN               NaN
# 434      18.b          NaN                          NaN               NaN
# 435      17.a          NaN                          NaN               NaN
# 436      17.b          NaN                          NaN               NaN
# 437      16.a          NaN                          NaN               NaN
# 438      16.b          NaN                          NaN               NaN
# 439      15.a          NaN                          NaN               NaN
# 440      15.b          NaN                          NaN               NaN
# 441      14.a          NaN                          NaN               NaN
# 442      14.b          NaN                          NaN               NaN
# 443      10.b          NaN                          NaN               NaN
# 444       9.b          NaN                          NaN               NaN
# 445      18.2          NaN                          NaN               NaN
# 446     24.1a          NaN                          NaN               NaN
# 447     24.1b          NaN                          NaN               NaN
# 448      20.a          NaN                          NaN               NaN
# 449      20.b          NaN                          NaN               NaN
# 450      19.a          NaN                          NaN               NaN
# 451      19.b          NaN                          NaN               NaN
# 452      18.a          NaN                          NaN               NaN
# 453      18.b          NaN                          NaN               NaN
# 454      17.a          NaN                          NaN               NaN
# 455      17.b          NaN                          NaN               NaN
# 456      16.a          NaN                          NaN               NaN
# 457      16.b          NaN                          NaN               NaN
# 458      15.a          NaN                          NaN               NaN
# 459      15.b          NaN                          NaN               NaN
# 460      14.a          NaN                          NaN               NaN
# 461      14.b          NaN                          NaN               NaN
# 462      10.b          NaN                          NaN               NaN
# 463       9.b          NaN                          NaN               NaN
# 464      18.2          NaN                          NaN               NaN
#
#      anchor_load_char_calculation_method  anchor_load_char  \
# 351                                  NaN               NaN
# 352                                  NaN               NaN
# 353                                  NaN               NaN
# 354                                  NaN               NaN
# 355                                  NaN               NaN
# 356                                  NaN               NaN
# 357                                  NaN               NaN
# 358                                  NaN               NaN
# 359                                  NaN               NaN
# 360                                  NaN               NaN
# 361                                  NaN               NaN
# 362                                  NaN               NaN
# 363                                  NaN               NaN
# 364                                  NaN               NaN
# 365                                  NaN               NaN
# 366                                  NaN               NaN
# 367                                  NaN               NaN
# 368                                  NaN               NaN
# 369                                  NaN               NaN
# 370                                  NaN               NaN
# 371                                  NaN               NaN
# 372                                  NaN               NaN
# 373                                  NaN               NaN
# 374                                  NaN               NaN
# 375                                  NaN               NaN
# 376                                  NaN               NaN
# 377                                  NaN               NaN
# 378                                  NaN               NaN
# 379                                  NaN               NaN
# 380                                  NaN               NaN
# 381                                  NaN               NaN
# 382                                  NaN               NaN
# 383                                  NaN               NaN
# 384                                  NaN               NaN
# 385                                  NaN               NaN
# 386                                  NaN               NaN
# 387                                  NaN               NaN
# 388                                  NaN               NaN
# 389                                  NaN               NaN
# 390                                  NaN               NaN
# 391                                  NaN               NaN
# 392                                  NaN               NaN
# 393                                  NaN               NaN
# 394                                  NaN               NaN
# 395                                  NaN               NaN
# 396                                  NaN               NaN
# 397                                  NaN               NaN
# 398                                  NaN               NaN
# 399                                  NaN               NaN
# 400                                  NaN               NaN
# 401                                  NaN               NaN
# 402                                  NaN               NaN
# 403                                  NaN               NaN
# 404                                  NaN               NaN
# 405                                  NaN               NaN
# 406                                  NaN               NaN
# 407                                  NaN               NaN
# 408                                  NaN               NaN
# 409                                  NaN               NaN
# 410                                  NaN               NaN
# 411                                  NaN               NaN
# 412                                  NaN               NaN
# 413                                  NaN               NaN
# 414                                  NaN               NaN
# 415                                  NaN               NaN
# 416                                  NaN               NaN
# 417                                  NaN               NaN
# 418                                  NaN               NaN
# 419                                  NaN               NaN
# 420                                  NaN               NaN
# 421                                  NaN               NaN
# 422                                  NaN               NaN
# 423                                  NaN               NaN
# 424                                  NaN               NaN
# 425                                  NaN               NaN
# 426                                  NaN               NaN
# 427                                  NaN               NaN
# 428                                  NaN               NaN
# 429                                  NaN               NaN
# 430                                  NaN               NaN
# 431                                  NaN               NaN
# 432                                  NaN               NaN
# 433                                  NaN               NaN
# 434                                  NaN               NaN
# 435                                  NaN               NaN
# 436                                  NaN               NaN
# 437                                  NaN               NaN
# 438                                  NaN               NaN
# 439                                  NaN               NaN
# 440                                  NaN               NaN
# 441                                  NaN               NaN
# 442                                  NaN               NaN
# 443                                  NaN               NaN
# 444                                  NaN               NaN
# 445                                  NaN               NaN
# 446                                  NaN               NaN
# 447                                  NaN               NaN
# 448                                  NaN               NaN
# 449                                  NaN               NaN
# 450                                  NaN               NaN
# 451                                  NaN               NaN
# 452                                  NaN               NaN
# 453                                  NaN               NaN
# 454                                  NaN               NaN
# 455                                  NaN               NaN
# 456                                  NaN               NaN
# 457                                  NaN               NaN
# 458                                  NaN               NaN
# 459                                  NaN               NaN
# 460                                  NaN               NaN
# 461                                  NaN               NaN
# 462                                  NaN               NaN
# 463                                  NaN               NaN
# 464                                  NaN               NaN
#
#      warning_value_calculation_method  alarm_value_calculation_method  \
# 351                               NaN                             NaN
# 352                               NaN                             NaN
# 353                               NaN                             NaN
# 354                               NaN                             NaN
# 355                               NaN                             NaN
# 356                               NaN                             NaN
# 357                               NaN                             NaN
# 358                               NaN                             NaN
# 359                               NaN                             NaN
# 360                               NaN                             NaN
# 361                               NaN                             NaN
# 362                               NaN                             NaN
# 363                               NaN                             NaN
# 364                               NaN                             NaN
# 365                               NaN                             NaN
# 366                               NaN                             NaN
# 367                               NaN                             NaN
# 368                               NaN                             NaN
# 369                               NaN                             NaN
# 370                               NaN                             NaN
# 371                               NaN                             NaN
# 372                               NaN                             NaN
# 373                               NaN                             NaN
# 374                               NaN                             NaN
# 375                               NaN                             NaN
# 376                               NaN                             NaN
# 377                               NaN                             NaN
# 378                               NaN                             NaN
# 379                               NaN                             NaN
# 380                               NaN                             NaN
# 381                               NaN                             NaN
# 382                               NaN                             NaN
# 383                               NaN                             NaN
# 384                               NaN                             NaN
# 385                               NaN                             NaN
# 386                               NaN                             NaN
# 387                               NaN                             NaN
# 388                               NaN                             NaN
# 389                               NaN                             NaN
# 390                               NaN                             NaN
# 391                               NaN                             NaN
# 392                               NaN                             NaN
# 393                               NaN                             NaN
# 394                               NaN                             NaN
# 395                               NaN                             NaN
# 396                               NaN                             NaN
# 397                               NaN                             NaN
# 398                               NaN                             NaN
# 399                               NaN                             NaN
# 400                               NaN                             NaN
# 401                               NaN                             NaN
# 402                               NaN                             NaN
# 403                               NaN                             NaN
# 404                               NaN                             NaN
# 405                               NaN                             NaN
# 406                               NaN                             NaN
# 448            NaN          NaN             1983.0                 1000.0
# 449            NaN          NaN             1983.0                 1000.0
# 450            NaN          NaN             1983.0                 1000.0
# 451            NaN          NaN             1983.0                 1000.0
# 452            NaN          NaN             1983.0                 1000.0
# 453            NaN          NaN             1983.0                 1000.0
# 454            NaN          NaN             1983.0                 1000.0
# 455            NaN          NaN             1983.0                 1000.0
# 456            NaN          NaN             1983.0                 1000.0
# 457            NaN          NaN             1983.0                 1000.0
# 458            NaN          NaN             1983.0                 1000.0
# 459            NaN          NaN             1983.0                 1000.0
# 460            NaN          NaN             1983.0                  750.0
# 461            NaN          NaN             1983.0                  750.0
# 462            NaN          NaN             1983.0                 1000.0
# 463            NaN          NaN             1983.0                 1000.0
# 464            NaN          NaN             1983.0                  920.0
#
#      measurement_date  measured_anchor_load stress_unit force_unit area_unit  \
# 351              1983                1000.0         MPa         kN        mm
# 352              1983                1000.0         MPa         kN        mm
# 353              1983                1000.0         MPa         kN        mm
# 354              1983                1000.0         MPa         kN        mm
# 355              1983                1000.0         MPa         kN        mm
# 356              1983                1000.0         MPa         kN        mm
# 357              1983                1000.0         MPa         kN        mm
# 358              1983                1000.0         MPa         kN        mm
# 359              1983                1000.0         MPa         kN        mm
# 360              1983                1000.0         MPa         kN        mm
# 361              1983                1000.0         MPa         kN        mm
# 362              1983                1000.0         MPa         kN        mm
# 363              1983                1000.0         MPa         kN        mm
# 364              1983                1000.0         MPa         kN        mm
# 365              1983                 750.0         MPa         kN        mm
# 366              1983                 750.0         MPa         kN        mm
# 367              1983                1000.0         MPa         kN        mm
# 368              1983                1000.0         MPa         kN        mm
# 369              1983                 920.0         MPa         kN        mm
# 370              1993                1200.0         MPa         kN        mm
# 371              1993                1165.0         MPa         kN        mm
# 372              1993                1165.0         MPa         kN        mm
# 373              1993                1160.0         MPa         kN        mm
# 374              1993                1340.0         MPa         kN        mm
# 375              1993                1150.0         MPa         kN        mm
# 376              1993                1155.0         MPa         kN        mm
# 377              1993                1205.0         MPa         kN        mm
# 378              1993                1205.0         MPa         kN        mm
# 379              1993                1215.0         MPa         kN        mm
# 380              1993                1210.0         MPa         kN        mm
# 381              1993                1210.0         MPa         kN        mm
# 382              1993                1140.0         MPa         kN        mm
# 383              1993                1110.0         MPa         kN        mm
# 384              1993                 890.0         MPa         kN        mm
# 385              1993                 870.0         MPa         kN        mm
# 386              1993                1285.0         MPa         kN        mm
# 387              1993                1180.0         MPa         kN        mm
# 388              1993                1040.0         MPa         kN        mm
# 389              1996                1180.0         MPa         kN        mm
# 390              1996                1165.0         MPa         kN        mm
# 391              1996                1165.0         MPa         kN        mm
# 392              1996                1170.0         MPa         kN        mm
# 393              1996                1355.0         MPa         kN        mm
# 394              1996                1158.0         MPa         kN        mm
# 395              1996                1165.0         MPa         kN        mm
# 396              1996                1174.0         MPa         kN        mm
# 397              1996                1210.0         MPa         kN        mm
# 398              1996                1210.0         MPa         kN        mm
# 399              1996                1230.0         MPa         kN        mm
# 400              1996                1210.0         MPa         kN        mm
# 401              1996                1145.0         MPa         kN        mm
# 402              1996                1110.0         MPa         kN        mm
# 403              1996                 885.0         MPa         kN        mm
# 404              1996                 895.0         MPa         kN        mm
# 405              1996                1290.0         MPa         kN        mm
# 406              1996                1175.0         MPa         kN        mm
# 407              1996                1045.0         MPa         kN        mm
# 408              2004                1170.0         MPa         kN        mm
# 409              2004                1152.0         MPa         kN        mm
# 410              2004                1146.0         MPa         kN        mm
# 411              2004                1150.0         MPa         kN        mm
# 412              2004                1296.0         MPa         kN        mm
# 413              2004                1092.0         MPa         kN        mm
# 414              2004                1128.0         MPa         kN        mm
# 415              2004                1130.0         MPa         kN        mm
# 416              2004                1185.0         MPa         kN        mm
# 417              2004                1110.0         MPa         kN        mm
# 418              2004                1210.0         MPa         kN        mm
# 419              2004                1180.0         MPa         kN        mm
# 420              2004                1122.0         MPa         kN        mm
# 421              2004                1082.0         MPa         kN        mm
# 422              2004                 865.0         MPa         kN        mm
# 423              2004                 847.0         MPa         kN        mm
# 424              2004                1278.0         MPa         kN        mm
# 425              2004                1180.0         MPa         kN        mm
# 426              2004                1010.0         MPa         kN        mm
# 427              2010                1165.0         MPa         kN        mm
# 428              2010                1135.0         MPa         kN        mm
# 429              2010                1139.0         MPa         kN        mm
# 430              2010                1148.0         MPa         kN        mm
# 431              2010                1300.0         MPa         kN        mm
# 432              2010                1129.0         MPa         kN        mm
# 433              2010                1142.0         MPa         kN        mm
# 434              2010                1160.0         MPa         kN        mm
# 435              2010                1195.0         MPa         kN        mm
# 436              2010                1030.0         MPa         kN        mm
# 437              2010                1218.0         MPa         kN        mm
# 438              2010                1188.0         MPa         kN        mm
# 439              2010                1097.0         MPa         kN        mm
# 440              2010                1105.0         MPa         kN        mm
# 441              2010                 847.0         MPa         kN        mm
# 442              2010                 850.0         MPa         kN        mm
# 443              2010                1304.0         MPa         kN        mm
# 444              2010                1198.0         MPa         kN        mm
# 445              2010                1024.0         MPa         kN        mm
# 446              2019                1156.0         MPa         kN        mm
# 447              2019                1130.0         MPa         kN        mm
# 448              2019                1102.0         MPa         kN        mm
# 449              2019                1138.0         MPa         kN        mm
# 450              2019                1240.0         MPa         kN        mm
# 451              2019                1127.0         MPa         kN        mm
# 452              2019                1102.0         MPa         kN        mm
# 453              2019                1156.0         MPa         kN        mm
# 454              2019                1149.0         MPa         kN        mm
# 455              2019                1055.0         MPa         kN        mm
# 456              2019                1153.0         MPa         kN        mm
# 457              2019                1120.0         MPa         kN        mm
# 458              2019                1066.0         MPa         kN        mm
# 459              2019                1084.0         MPa         kN        mm
# 460              2019                 788.0         MPa         kN        mm
# 461              2019                 831.0         MPa         kN        mm
# 462              2019                1283.0         MPa         kN        mm
# 463              2019                1157.0         MPa         kN        mm
# 464              2019                1017.0         MPa         kN        mm
#
#      anchor_capacity_utiliz  anchor_load_change  error_bars
# 351                     NaN                 0.0       200.0
# 352                     NaN                 0.0       200.0
# 353                     NaN                 0.0       200.0
# 354                     NaN                 0.0       200.0
# 355                     NaN                 0.0       200.0
# 445                     NaN               104.0       184.0
# 446                     NaN               156.0       200.0
# 447                     NaN               130.0       200.0
# 448                     NaN               102.0       200.0
# 449                     NaN               138.0       200.0
# 450                     NaN               240.0       200.0
# 451                     NaN               127.0       200.0
# 452                     NaN               102.0       200.0
# 453                     NaN               156.0       200.0
# 454                     NaN               149.0       200.0
# 455                     NaN                55.0       200.0
# 456                     NaN               153.0       200.0
# 457                     NaN               120.0       200.0
# 458                     NaN                66.0       200.0
# 459                     NaN                84.0       200.0
# 460                     NaN                38.0       150.0
# 461                     NaN                81.0       150.0
# 462                     NaN               283.0       200.0
# 463                     NaN               157.0       200.0
# 464                     NaN                97.0       184.0

# %% [markdown]
# # data plots
# ### "... tell the (data) story"

# %% [markdown]
# ### data overview

# %%
# basic data check of all measured anchor loads
display(anchors_df)

# anchor 4B in SM5 for 1994 measurment appears invalid!
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#
#         </div>
#     <div id="chartFigure713e13c9" class="pd_save is-viewer-good" style="overflow-x:auto">
#
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-713e13c9")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"4d39d1b2-dee8-42b5-b419-42956b8f75eb":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"1087","type":"BoxAnnotation"},{"attributes":{},"id":"1086","type":"UnionRenderers"},{"attributes":{},"id":"1085","type":"Selection"},{"attributes":{},"id":"1084","type":"BasicTickFormatter"},{"attributes":{},"id":"1082","type":"BasicTickFormatter"},{"attributes":{"text":""},"id":"1080","type":"Title"},{"attributes":{"callback":null,"start":0},"id":"1043","type":"DataRange1d"},{"attributes":{},"id":"1060","type":"WheelZoomTool"},{"attributes":{},"id":"1045","type":"LinearScale"},{"attributes":{},"id":"1050","type":"BasicTicker"},{"attributes":{"ticker":{"id":"1050","type":"BasicTicker"}},"id":"1053","type":"Grid"},{"attributes":{"axis_label":"Frequency","formatter":{"id":"1094","type":"BasicTickFormatter"},"ticker":{"id":"1055","type":"BasicTicker"}},"id":"1054","type":"LinearAxis"},{"attributes":{},"id":"1055","type":"BasicTicker"},{"attributes":{"dimension":1,"ticker":{"id":"1055","type":"BasicTicker"}},"id":"1058","type":"Grid"},{"attributes":{},"id":"1059","type":"PanTool"},{"attributes":{"bottom":{"value":0},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"top":{"field":"top"}},"id":"1074","type":"Quad"},{"attributes":{"data_source":{"id":"1072","type":"ColumnDataSource"},"glyph":{"id":"1073","type":"Quad"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"1074","type":"Quad"},"selection_glyph":null,"view":{"id":"1076","type":"CDSView"}},"id":"1075","type":"GlyphRenderer"},{"attributes":{"callback":null,"data":{"left":{"__ndarray__":"AAAAAABAf0AAAAAAAGiAQAAAAAAAMIFAAAAAAAD4gUAAAAAAAMCCQAAAAAAAiINAAAAAAABQhEAAAAAAABiFQAAAAAAA4IVAAAAAAACohkAAAAAAAHCHQAAAAAAAOIhAAAAAAAAAiUAAAAAAAMiJQAAAAAAAkIpAAAAAAABYi0AAAAAAACCMQAAAAAAA6IxAAAAAAACwjUAAAAAAAHiOQA==","dtype":"float64","shape":[20]},"right":{"__ndarray__":"AAAAAABogEAAAAAAADCBQAAAAAAA+IFAAAAAAADAgkAAAAAAAIiDQAAAAAAAUIRAAAAAAAAYhUAAAAAAAOCFQAAAAAAAqIZAAAAAAABwh0AAAAAAADiIQAAAAAAAAIlAAAAAAADIiUAAAAAAAJCKQAAAAAAAWItAAAAAAAAgjEAAAAAAAOiMQAAAAAAAsI1AAAAAAAB4jkAAAAAAAECPQA==","dtype":"float64","shape":[20]},"top":{"__ndarray__":"/Dw9dsheUz8AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAADTst23USRAPwAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAJzkBIWhynU/AAAAAAAAAAD8PD12yF5TPwAAAAAAAAAA53cNF43BYT8AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA7jMyTejZYPwAAAAAAAAAAAAAAAAAAAADY4nVFhdqcPw==","dtype":"float64","shape":[20]}},"selected":{"id":"1095","type":"Selection"},"selection_policy":{"id":"1096","type":"UnionRenderers"}},"id":"1072","type":"ColumnDataSource"},{"attributes":{"bottom":{"value":0},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_color":{"value":"#cccccc"},"right":{"field":"right"},"top":{"field":"top"}},"id":"1073","type":"Quad"},{"attributes":{"callback":null,"tooltips":[["Frequency","@top{0.00}"],["Interval","@left - @right"]]},"id":"1038","type":"HoverTool"},{"attributes":{"dimension":1,"ticker":{"id":"1016","type":"BasicTicker"}},"id":"1019","type":"Grid"},{"attributes":{"ticker":{"id":"1011","type":"BasicTicker"}},"id":"1014","type":"Grid"},{"attributes":{"callback":null,"data":{"left":{"__ndarray__":"AAAAAAAAXkAAAAAAALhmQAAAAAAAcG5AAAAAAAAUc0AAAAAAAPB2QAAAAAAAzHpAAAAAAACofkAAAAAAAEKBQAAAAAAAMINAAAAAAAAehUAAAAAAAAyHQAAAAAAA+ohAAAAAAADoikAAAAAAANaMQAAAAAAAxI5AAAAAAABZkEAAAAAAAFCRQAAAAAAAR5JAAAAAAAA+k0AAAAAAADWUQA==","dtype":"float64","shape":[20]},"right":{"__ndarray__":"AAAAAAC4ZkAAAAAAAHBuQAAAAAAAFHNAAAAAAADwdkAAAAAAAMx6QAAAAAAAqH5AAAAAAABCgUAAAAAAADCDQAAAAAAAHoVAAAAAAAAMh0AAAAAAAPqIQAAAAAAA6IpAAAAAAADWjEAAAAAAAMSOQAAAAAAAWZBAAAAAAABQkUAAAAAAAEeSQAAAAAAAPpNAAAAAAA ...

# %%
# basic data check of all anchor measurements over time
display(anchors_df)
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#
#         </div>
#     <div id="chartFigure664957d8" class="pd_save is-viewer-good" style="overflow-x:auto">
#
#
#                             <center><img style="max-width:initial !important" src="data:image/png;base64,..." class="pd_save"></center>
#
#
#
#         </div>

# %% [markdown]
# ### data trends

# %%
# scatterplot of anchor capacity utilization vs anchor load change
display(anchors_df)

# careful: anchor_id's are not unique !!
# anchor 18c at SMC4 has low capacity utilization, is data for calc_anchor_load correct ??
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>

# %%
# average of all anchors at each strcuture
display(anchors_df)

#display(anchors_SM1)
#display(anchors_df[anchors_df.structure_id.isin(['Bruecke Tuffgraben'])])
#display(anchors_SM4)

# are NaN values taken as zero??
# e.g. SM1 is not displayed correctly with 'display(anchors_df)', compare with 'display(anchors_SM1)'
#   -> looks more like a bug with pixiedust
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#             AVG of all anchor loads
#         </div>
#     <div id="chartFigurea1925eb6" class="pd_save is-viewer-good" style="overflow-x:auto">
#
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-a1925eb6")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"dfcaf635-34dc-4c1d-8e0f-3aecffb46c72":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"1546","type":"BoxAnnotation"},{"attributes":{},"id":"1544","type":"Selection"},{"attributes":{},"id":"1545","type":"UnionRenderers"},{"attributes":{},"id":"1543","type":"BasicTickFormatter"},{"attributes":{},"id":"1541","type":"BasicTickFormatter"},{"attributes":{},"id":"1526","type":"Selection"},{"attributes":{"axis_label":"measured_anchor_load","formatter":{"id":"1534","type":"BasicTickFormatter"},"ticker":{"id":"1374","type":"BasicTicker"}},"id":"1373","type":"LinearAxis"},{"attributes":{"ticker":{"id":"1369","type":"BasicTicker"}},"id":"1372","type":"Grid"},{"attributes":{},"id":"1374","type":"BasicTicker"},{"attributes":{"dimension":1,"ticker":{"id":"1374","type":"BasicTicker"}},"id":"1377","type":"Grid"},{"attributes":{},"id":"1379","type":"WheelZoomTool"},{"attributes":{},"id":"1464","type":"ResetTool"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_multi":null,"active_scroll":"auto","active_tap":"auto","tools":[{"id":"1460","type":"PanTool"},{"id":"1461","type":"WheelZoomTool"},{"id":"1462","type":"BoxZoomTool"},{"id":"1463","type":"SaveTool"},{"id":"1464","type":"ResetTool"},{"id":"1465","type":"HelpTool"},{"id":"1478","type":"HoverTool"}]},"id":"1466","type":"Toolbar"},{"attributes":{},"id":"1461","type":"WheelZoomTool"},{"attributes":{},"id":"1460","type":"PanTool"},{"attributes":{},"id":"1463","type":"SaveTool"},{"attributes":{"overlay":{"id":"1555","type":"BoxAnnotation"}},"id":"1462","type":"BoxZoomTool"},{"attributes":{"text":"structure_id = Bruecke Tuffgraben"},"id":"1317","type":"Title"},{"attributes":{"below":[{"id":"1327","type":"LinearAxis"}],"center":[{"id":"1331","type":"Grid"},{"id":"1336","type":"Grid"}],"left":[{"id":"1332","type":"LinearAxis"}],"plot_height":298,"plot_width":399,"renderers":[{"id":"1353","type":"GlyphRenderer"}],"title":{"id":"1317","type":"Title"},"toolbar":{"id":"1343","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"1319","type":"DataRange1d"},"x_scale":{"id":"1323","type":"LinearScale"},"y_range":{"id":"1321","type":"DataRange1d"},"y_scale":{"id":"1325","type":"LinearScale"}},"id":"1316","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"1523","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"1319","type":"DataRange1d"},{"attributes":{"axis_label":"measurement_date","formatter":{"id":"1559","type":"BasicTickFormatter"},"ticker":{"id":"1492","type":"BasicTicker"}},"id":"1491","type":"LinearAxis"},{"attributes":{},"id":"1492","type":"BasicTicker"},{"attributes":{"ticker":{"id":"1492","type":"BasicTicker"}},"id":"1495","type":"Grid"},{"attributes":{"axis_label":"measured_anchor_load","formatter":{"id":"1561","type":"BasicTickFormatter"},"ticker":{"id":"1497","type":"BasicTicker"}},"id":"1496","type":"LinearAxis"},{"attributes":{},"id":"1497","type":"BasicTicker"},{"attributes":{"source":{"id":"1391","type":"ColumnDataSource"}},"id":"1395","type":"CDSView"},{"attributes":{},"id":"1550","type":"BasicTickFormatter"},{"attributes":{},"id":"1553","type":"Selection"},{"attributes":{},"id":"1552","type":"BasicTickFormatter"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"1555","type":"BoxAnnotation"},{"attributes":{},"id":"1554","type":"UnionRenderers"},{"attributes":{},"id":"1559","type":"BasicTickFormatter"},{"attributes":{"line_alpha":0.1,"line_color":"#1f77b4","line_width":2," ...

# %% [markdown]
# ### data for indiviudal anchors

# %%
# anchor load over time for individual anchors
display(anchors_df[anchors_df['anchor_id']=='18b'])

# careful: anchor_id's are not unique !!
#          and 18.b and 18.b give same result !!  -> seems to be strange pixiedust behvaior
#            decimals (and spaces) in IDs are bad practice !!
# NaN values are omitted (expected behavior), but why different further below in subplots ??
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#             18b
#         </div>
#     <div id="chartFigureb56ad656" class="pd_save is-viewer-good" style="overflow-x:auto">
#
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-b56ad656")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"6220ccae-f44f-40d5-b990-483740cb3220":{"roots":{"references":[{"attributes":{"axis_label":"measurement_date","formatter":{"id":"1813","type":"BasicTickFormatter"},"ticker":{"id":"1782","type":"BasicTicker"}},"id":"1781","type":"LinearAxis"},{"attributes":{},"id":"1782","type":"BasicTicker"},{"attributes":{"ticker":{"id":"1782","type":"BasicTicker"}},"id":"1785","type":"Grid"},{"attributes":{"axis_label":"measured_anchor_load","formatter":{"id":"1815","type":"BasicTickFormatter"},"ticker":{"id":"1787","type":"BasicTicker"}},"id":"1786","type":"LinearAxis"},{"attributes":{},"id":"1787","type":"BasicTicker"},{"attributes":{"callback":null,"tooltips":[["measurement_date","@x"],["measured_anchor_load","@y{0.00}"],["x","$x"],["y","$y"]]},"id":"1809","type":"HoverTool"},{"attributes":{"toolbar":{"id":"1821","type":"ProxyToolbar"},"toolbar_location":"above"},"id":"1822","type":"ToolbarBox"},{"attributes":{"callback":null},"id":"1775","type":"DataRange1d"},{"attributes":{},"id":"1815","type":"BasicTickFormatter"},{"attributes":{},"id":"1777","type":"LinearScale"},{"attributes":{},"id":"1817","type":"UnionRenderers"},{"attributes":{"below":[{"id":"1781","type":"LinearAxis"}],"center":[{"id":"1785","type":"Grid"},{"id":"1790","type":"Grid"}],"left":[{"id":"1786","type":"LinearAxis"}],"plot_height":373,"plot_width":500,"renderers":[{"id":"1807","type":"GlyphRenderer"}],"title":null,"toolbar":{"id":"1797","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"1773","type":"DataRange1d"},"x_scale":{"id":"1777","type":"LinearScale"},"y_range":{"id":"1775","type":"DataRange1d"},"y_scale":{"id":"1779","type":"LinearScale"}},"id":"1771","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null},"id":"1773","type":"DataRange1d"},{"attributes":{},"id":"1813","type":"BasicTickFormatter"},{"attributes":{},"id":"1779","type":"LinearScale"},{"attributes":{},"id":"1816","type":"Selection"},{"attributes":{"overlay":{"id":"1818","type":"BoxAnnotation"}},"id":"1793","type":"BoxZoomTool"},{"attributes":{},"id":"1792","type":"WheelZoomTool"},{"attributes":{},"id":"1791","type":"PanTool"},{"attributes":{"dimension":1,"ticker":{"id":"1787","type":"BasicTicker"}},"id":"1790","type":"Grid"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_multi":null,"active_scroll":"auto","active_tap":"auto","tools":[{"id":"1791","type":"PanTool"},{"id":"1792","type":"WheelZoomTool"},{"id":"1793","type":"BoxZoomTool"},{"id":"1794","type":"SaveTool"},{"id":"1795","type":"ResetTool"},{"id":"1796","type":"HelpTool"},{"id":"1809","type":"HoverTool"}]},"id":"1797","type":"Toolbar"},{"attributes":{},"id":"1796","type":"HelpTool"},{"attributes":{},"id":"1795","type":"ResetTool"},{"attributes":{},"id":"1794","type":"SaveTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"1818","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"1804","type":"ColumnDataSource"},"glyph":{"id":"1805","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"1806","type":"Line"},"selection_glyph":null,"view":{"id":"1808","type":"CDSView"}},"id":"1807","type":"GlyphRenderer"},{"attributes":{"line_alpha":0.1,"line_color":"#1f77b4","line_width":2,"x":{"field":"x"},"y":{"field":"y"}},"id":"1806","type":"Line"},{"attributes":{"line_color":"#1f77b4","line_width":2,"x":{"field":"x"},"y":{"field":"y"}},"id":"1805","type":"Line"},{"attributes":{"callback":null,"data":{"x":[1984.0,1996.0,2004.0,2010.0,2019.0],"y":[1000.0,1021.0,993.0,1016.0,1015.0]},"selected":{"id":"1816","type":"Selection"},"selection_policy":{"id":"1817","type":"UnionRenderers"}},"id":"1804","type":"ColumnDataSource"},{"attributes":{"tools":[{"id":"1791","type":"PanTool"},{"id":"1792","type":" ...
#           var render_items = [{"docid":"6220ccae-f44f-40d5-b990-483740cb3220","roots":{"1823":"3c3e3e3c-87a6-478a-ace3-6c7192c81472"}}];
#           root.Bokeh.embed.embed_items(docs_json, render_items);
#
#           }
#           if (root.Bokeh !== undefined) {
#             embed_document(root);
#           } else {
#             var attempts = 0;
#             var timer = setInterval(function(root) {
#               if (root.Bokeh !== undefined) {
#                 embed_document(root);
#                 clearInterval(timer);
#               }
#               attempts++;
#               if (attempts > 100) {
#                 console.log("Bokeh: ERROR: Unable to run BokehJS code because BokehJS library is missing");
#                 clearInterval(timer);
#               }
#             }, 10, root)
#           }
#         })(window);
#       });
#     };
#     if (document.readyState != "loading") fn();
#     else document.addEventListener("DOMContentLoaded", fn);
#   })();
# <\/script>`
#                                 var chartscript = el.childNodes[1]
#                                 var s = document.createElement("script")
#                                 s.innerHTML = chartscript.innerHTML
#                                 d.parentNode.insertBefore(s, d)
#                             }
#                         }
#                     }
#                     if (!window.Bokeh && !window.autoload){
#                         window.autoload=true;
#
# (function(root) {
#   function now() {
#     return new Date();
#   }
#
#   var force = 1;
#
#   if (typeof root._bokeh_onload_callbacks === "undefined" || force === true) {
#     root._bokeh_onload_callbacks = [];
#     root._bokeh_is_loading = undefined;
#   }
#
#
#
#
#   if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#     root._bokeh_timeout = Date.now() + 5000;
#     root._bokeh_failed_load = false;
#   }
#
#   var NB_LOAD_WARNING = {'data': {'text/html':
#      "<div style='background-color: #fdd'>\n"+
#      "<p>\n"+
#      "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#      "may be due to a slow or bad network connection. Possible fixes:\n"+
#      "</p>\n"+
#      "<ul>\n"+
#      "<li>re-rerun `output_notebook()` to

# %%
# anchor load over time for all individual anchors at a structure
#display(anchors_SM4)
display(anchors_SM1)
#display(anchors_df[anchors_df.structure_id.isin(['Bruecke Tuffgraben'])])

# NaN values taken as zero if Aggregation -> SUM used
# NaN values omitted if Aggregation -> AVG used
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#             SM1
#         </div>
#     <div id="chartFigure821e8535" class="pd_save is-viewer-good" style="overflow-x:auto">
#
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-821e8535")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"f35168e0-a303-4777-a079-afcb3ccb168b":{"roots":{"references":[{"attributes":{},"id":"2304","type":"ResetTool"},{"attributes":{"data_source":{"id":"1945","type":"ColumnDataSource"},"glyph":{"id":"1946","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"1947","type":"Line"},"selection_glyph":null,"view":{"id":"1949","type":"CDSView"}},"id":"1948","type":"GlyphRenderer"},{"attributes":{"source":{"id":"1945","type":"ColumnDataSource"}},"id":"1949","type":"CDSView"},{"attributes":{"dimension":1,"ticker":{"id":"2066","type":"BasicTicker"}},"id":"2069","type":"Grid"},{"attributes":{"line_color":"#1f77b4","line_width":2,"x":{"field":"x"},"y":{"field":"y"}},"id":"1946","type":"Line"},{"attributes":{"line_alpha":0.1,"line_color":"#1f77b4","line_width":2,"x":{"field":"x"},"y":{"field":"y"}},"id":"1947","type":"Line"},{"attributes":{"callback":null,"data":{"x":[1983,1993,1996,2004,2010,2019],"y":[920.0,1040.0,1045.0,1010.0,1024.0,1017.0]},"selected":{"id":"2755","type":"Selection"},"selection_policy":{"id":"2756","type":"UnionRenderers"}},"id":"1945","type":"ColumnDataSource"},{"attributes":{},"id":"2910","type":"UnionRenderers"},{"attributes":{},"id":"2911","type":"Selection"},{"attributes":{},"id":"2912","type":"UnionRenderers"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"2913","type":"BoxAnnotation"},{"attributes":{},"id":"2917","type":"BasicTickFormatter"},{"attributes":{},"id":"2851","type":"BasicTickFormatter"},{"attributes":{},"id":"2919","type":"BasicTickFormatter"},{"attributes":{},"id":"2853","type":"BasicTickFormatter"},{"attributes":{},"id":"2855","type":"UnionRenderers"},{"attributes":{},"id":"2854","type":"Selection"},{"attributes":{},"id":"2857","type":"UnionRenderers"},{"attributes":{},"id":"2856","type":"Selection"},{"attributes":{"data_source":{"id":"2175","type":"ColumnDataSource"},"glyph":{"id":"2176","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"2177","type":"Line"},"selection_glyph":null,"view":{"id":"2179","type":"CDSView"}},"id":"2178","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"1991","type":"ColumnDataSource"},"glyph":{"id":"1992","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"1993","type":"Line"},"selection_glyph":null,"view":{"id":"1995","type":"CDSView"}},"id":"1994","type":"GlyphRenderer"},{"attributes":{"axis_label":"measured_anchor_load,installed_anchor_load","formatter":{"id":"2941","type":"BasicTickFormatter"},"ticker":{"id":"2710","type":"BasicTicker"}},"id":"2709","type":"LinearAxis"},{"attributes":{},"id":"2070","type":"PanTool"},{"attributes":{"callback":null,"data":{"x":[1983,1993,1996,2004,2010,2019],"y":[1000.0,1000.0,1000.0,1000.0,1000.0,1000.0]},"selected":{"id":"2845","type":"Selection"},"selection_policy":{"id":"2846","type":"UnionRenderers"}},"id":"2318","type":"ColumnDataSource"},{"attributes":{"line_color":"#ff7f0e","line_width":2,"x":{"field":"x"},"y":{"field":"y"}},"id":"2319","type":"Line"},{"attributes":{"data_source":{"id":"2313","type":"ColumnDataSource"},"glyph":{"id":"2314","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"2315","type":"Line"},"selection_glyph":null,"view":{"id":"2317","type":"CDSView"}},"id":"2316","type":"GlyphRenderer"},{"attributes":{"source":{"id":"2313","type":"ColumnDataSource"}},"id":"2317","type":"CDSView"},{"attributes":{"line_color":"#1f77b4","line_width":2,"x":{"field":"x"},"y":{"field":"y"}},"id":"2314","type":"Line"},{"attributes":{"line_alpha":0.1,"line_color":"#1f77b4","line_width":2,"x":{"field":"x"},"y":{"field":"y"}},"id":"2315","type":"Line"},{"attributes":{"callback":null,"data":{"x":[1983,1993,1996,2004,2010,20 ...

# %%
# TEMP WORK

# %%
####fig = plt.figure()

#anchors_df[anchors_df['anchor_id']=='18.b'].measured_anchor_load.plot

anchors_df[anchors_df['anchor_id']=='18.b'].plot(x='measurement_date', 
                                                 y=['measured_anchor_load','installed_anchor_load'], 
                                                 style=['-',':'])

#anchors_df[anchors_df['anchor_id']=='18.b'].plot(x='measurement_date', 
#                                                 y=['measured_anchor_load'], 
#                                                 style=['-'])

#anchors_df[anchors_df['anchor_id']=='18.b'].plot(x='measurement_date', 
#                                                 y=['measured_anchor_load','installed_anchor_load'],
#                                                 style=['-',':'], yerr='error_bars')

#anchors_df[anchors_df['anchor_id']=='18.b'].plot(x='measurement_date', 
#                                                 y=['installed_anchor_load'],
#                                                 style=[':'], yerr='error_bars')

####plt.show()
# Out:
# /usr/local/lib/python2.7/dist-packages/pandas/plotting/_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label
